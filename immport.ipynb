# %%
## imports
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
immport_prefix="/var/datasets/ImmPort/immune_RNAseq/ALLSTUDIES/ALLSTUDIES-DR49.2_Tab/Tab/"

print("STUDY")
print("============================================================")
study = pd.read_table(f"{immport_prefix}/study.txt",sep="\t")
print(study.columns)
print(study.shape)
# study.head()

print("")
print("ARM_OR_COHORT")
print("============================================================")
arm_or_cohort = pd.read_table(f"{immport_prefix}/arm_or_cohort.txt",sep="\t")
print(arm_or_cohort.columns)
print(arm_or_cohort.shape)

print("")
print("ARM_2_SUBJECT")
print("============================================================")
arm_2_subject = pd.read_table(f"{immport_prefix}/arm_2_subject.txt",sep="\t")
print(arm_2_subject.columns)
print(arm_2_subject.shape)

# arm_2_subject.head()

print("")
print("BIOSAMPLE")
print("============================================================")
biosample = pd.read_table(f"{immport_prefix}/biosample.txt",sep="\t")
print(biosample.columns)
print(biosample.shape)

print("============================================================")
lab_test_panel = pd.read_table(f"{immport_prefix}/lab_test_panel.txt",sep="\t")
print(lab_test_panel.columns)
print(lab_test_panel.shape)

print("")
print("LAB_TEST")
print("============================================================")
lab_test = pd.read_table(f"{immport_prefix}/lab_test.txt",sep="\t")
print(lab_test.columns)
print(lab_test.shape)

print("")
print("SUBJECT")
print("============================================================")
subject = pd.read_table(f"{immport_prefix}/subject.txt", sep="\t") 
print(subject.shape)

print("ASSESSMENT_PANEL")
print("============================================================")
assessment_panel = pd.read_table(f"{immport_prefix}/assessment_panel.txt",sep="\t")
print(assessment_panel.columns)
print(assessment_panel.shape)

print("")
print("ASSESSMENT_COMPONENT")
print("============================================================")
assessment_component = pd.read_table(f"{immport_prefix}/assessment_component.txt",sep="\t")
print(assessment_component.columns)
print(assessment_component.shape)
# Out:
# STUDY
# ============================================================
# Index(['STUDY_ACCESSION', 'ACTUAL_COMPLETION_DATE', 'ACTUAL_ENROLLMENT',
#        'ACTUAL_START_DATE', 'AGE_UNIT', 'BRIEF_DESCRIPTION', 'BRIEF_TITLE',
#        'CLINICAL_TRIAL', 'CONDITION_STUDIED', 'DCL_ID', 'DESCRIPTION', 'DOI',
#        'ENDPOINTS', 'GENDER_INCLUDED', 'HYPOTHESIS',
#        'INITIAL_DATA_RELEASE_DATE', 'INITIAL_DATA_RELEASE_VERSION',
#        'INTERVENTION_AGENT', 'LATEST_DATA_RELEASE_DATE',
#        'LATEST_DATA_RELEASE_VERSION', 'MAXIMUM_AGE', 'MINIMUM_AGE',
#        'OBJECTIVES', 'OFFICIAL_TITLE', 'SHARED_STUDY',
#        'SPONSORING_ORGANIZATION', 'TARGET_ENROLLMENT', 'WORKSPACE_ID'],
#       dtype='object')
# (811, 28)
#
# ARM_OR_COHORT
# ============================================================
# Index(['ARM_ACCESSION', 'DESCRIPTION', 'NAME', 'STUDY_ACCESSION',
#        'TYPE_REPORTED', 'TYPE_PREFERRED', 'WORKSPACE_ID'],
#       dtype='object')
# (3296, 7)
#
# ARM_2_SUBJECT
# ============================================================
# Index(['ARM_ACCESSION', 'SUBJECT_ACCESSION', 'AGE_EVENT', 'AGE_EVENT_SPECIFY',
#        'AGE_UNIT', 'MAX_SUBJECT_AGE', 'MIN_SUBJECT_AGE', 'SUBJECT_PHENOTYPE',
#        'SUBJECT_LOCATION', 'MAX_SUBJECT_AGE_IN_YEARS',
#        'MIN_SUBJECT_AGE_IN_YEARS'],
#       dtype='object')
# (99728, 11)
#
# BIOSAMPLE
# ============================================================
# /tmp/ipykernel_99518/869920039.py:29: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   biosample = pd.read_table(f"{immport_prefix}/biosample.txt",sep="\t")
# Index(['BIOSAMPLE_ACCESSION', 'DESCRIPTION', 'NAME', 'PLANNED_VISIT_ACCESSION',
#        'STUDY_ACCESSION', 'STUDY_TIME_COLLECTED', 'STUDY_TIME_COLLECTED_UNIT',
#        'STUDY_TIME_T0_EVENT', 'STUDY_TIME_T0_EVENT_SPECIFY',
#        'SUBJECT_ACCESSION', 'SUBTYPE', 'TYPE', 'WORKSPACE_ID'],
#       dtype='object')
# (482701, 13)
# ============================================================
# Index(['LAB_TEST_PANEL_ACCESSION', 'NAME_PREFERRED', 'NAME_REPORTED',
#        'STUDY_ACCESSION', 'WORKSPACE_ID'],
#       dtype='object')
# (422, 5)
#
# LAB_TEST
# ============================================================
# Index(['LAB_TEST_ACCESSION', 'LAB_TEST_PANEL_ACCESSION', 'BIOSAMPLE_ACCESSION',
#        'NAME_PREFERRED', 'NAME_REPORTED', 'REFERENCE_RANGE_ACCESSION',
#        'RESULT_UNIT_PREFERRED', 'RESULT_UNIT_REPORTED',
#        'RESULT_VALUE_PREFERRED', 'RESULT_VALUE_REPORTED', 'WORKSPACE_ID'],
#       dtype='object')
# (1279882, 11)
#
# SUBJECT
# ============================================================
# /tmp/ipykernel_99518/869920039.py:48: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   subject = pd.read_table(f"{immport_prefix}/subject.txt", sep="\t")
# (94198, 11)
# ASSESSMENT_PANEL
# ============================================================
# Index(['ASSESSMENT_PANEL_ACCESSION', 'ASSESSMENT_TYPE', 'NAME_PREFERRED',
#        'NAME_REPORTED', 'RESULT_SCHEMA', 'STATUS', 'STUDY_ACCESSION',
#        'WORKSPACE_ID'],
#       dtype='object')
# (729, 8)
#
# ASSESSMENT_COMPONENT
# ============================================================
# /tmp/ipykernel_99518/869920039.py:60: DtypeWarning: Columns (2,8,9,15,16,19,25,26) have mixed types. Specify dtype option on import or set low_memory=False.
#   assessment_component = pd.read_table(f"{immport_prefix}/assessment_component.txt",sep="\t")
# Index(['ASSESSMENT_COMPONENT_ACCESSION', 'AGE_AT_ONSET_PREFERRED',
#        'AGE_AT_ONSET_REPORTED', 'AGE_AT_ONSET_UNIT_PREFERRED',
#        'AGE_AT_ONSET_UNIT_REPORTED', 'ASSESSMENT_PANEL_ACCESSION',
#        'IS_CLINICALLY_SIGNIFICANT', 'LOCATION_OF_FINDING_PREFERRED',
#        'LOCATION_OF_FINDING_REPORTED', 'NAME_PREFERRED', 'NAME_REPORTED',
#        'ORGAN_OR_BODY_SYSTEM_PREFERRED', 'ORGAN_OR_BODY_SYSTEM_REPORTED',
#        'PLANNED_VISIT_ACCESSION', 'REFERENCE_RANGE_ACCESSION',
#        'RESULT_UNIT_PREFERRED', 'RESULT_UNIT_REPORTED',
#        'RESULT_VALUE_CATEGORY', 'RESULT_VALUE_PREFERRED',
#        'RESULT_VALUE_REPORTED', 'STUDY_DAY', 'SUBJECT_ACCESSION',
#        'SUBJECT_POSITION_PREFERRED', 'SUBJECT_POSITION_REPORTED',
#        'TIME_OF_DAY', 'VERBATIM_QUESTION', 'WHO_IS_ASSESSED', 'WORKSPACE_ID'],
#       dtype='object')
# (2093159, 28)

# %%
#Helper methods
def lab_test_panels_by_study(study_accession,lab_tests):
    study_lab_tests = lab_tests[lab_tests['STUDY_ACCESSION']==study_accession]
    study_panels = study_lab_tests[['PANEL_NAME','LAB_TEST_NAME']]
    study_panels = study_panels.groupby(['PANEL_NAME','LAB_TEST_NAME']).size().reset_index(name="COUNTS")
    return study_panels
def assessment_panels_by_study(study_accession,assessments):
    study_assessments = assessments[assessments['STUDY_ACCESSION']==study_accession]
    study_panels = study_assessments[['PANEL_NAME','COMPONENT_NAME']]
    study_panels = study_panels.groupby(['PANEL_NAME','COMPONENT_NAME']).size().reset_index(name="COUNTS")
    return study_panels

# %%
## How many Labtests
print(f'Labtests amount: {lab_test.drop_duplicates().shape}')
print(f'Labtest panels amount: {lab_test_panel.drop_duplicates().shape}')

## How many Subjects
subject = subject[subject['SPECIES']=='Homo sapiens']
print(f'Subject amount: {subject.drop_duplicates().shape}')
subject_with_gender = subject[subject['GENDER'].isin(['Male' ,'Female'])].drop_duplicates()
print(f'Subjects male/female amount: {subject_with_gender.shape}')

## How many Studies
print(f'Studies amount: {study.drop_duplicates().shape}')

## Labtests: "Biomarkers", welche
# Out:
# Labtests amount: (1279882, 11)
# Labtest panels amount: (422, 5)
# Subject amount: (80499, 11)
# Subjects male/female amount: (74735, 11)
# Studies amount: (811, 28)

# %%
study['GENDER_INCLUDED'].unique()
arm_2_subject_valid = arm_2_subject[arm_2_subject['SUBJECT_ACCESSION'].isin(subject_with_gender['SUBJECT_ACCESSION'])]
 
duplicates = arm_2_subject_valid[arm_2_subject_valid.duplicated('SUBJECT_ACCESSION', keep='first')] 
## keep says if we want to see every enry just once or all duplicates of it
print(f'Arm 2 Subject duplicates: {duplicates.shape}')
arm_2_subject_valid['AGE_UNIT'].unique() # 'Years', 'Not Specified', 'Weeks', 'Months', 'Days', 'Hours' 
### here we need to see... babys may have a month or days unit ... hours is strange for homo sapiens... 
arm_2_subject_valid = arm_2_subject_valid.dropna(subset=['MAX_SUBJECT_AGE_IN_YEARS', 'MIN_SUBJECT_AGE_IN_YEARS'])
### As we have different age events we should despite track the duplicated subjects!
print(f'Subjects valid aged male/female {arm_2_subject_valid.drop_duplicates('SUBJECT_ACCESSION').shape}')
mismatch_age = arm_2_subject_valid[arm_2_subject_valid['MAX_SUBJECT_AGE_IN_YEARS'] != arm_2_subject_valid['MIN_SUBJECT_AGE_IN_YEARS']]
print(f'Subjects with MIN / MAX age mismatch {mismatch_age.drop_duplicates('SUBJECT_ACCESSION').shape}')

arm_2_subject_valid['AGE_EVENT'].unique() # 'Age at enrollment', 'Other', 'Not Specified', 'Age at initial vaccine administration', 'Age at Study Day 0', 'Age at infection', 'Age at initial treatment'

subject.head()
# Out:
# Arm 2 Subject duplicates: (5493, 11)
# Subjects valid aged male/female (74198, 11)
# Subjects with MIN / MAX age mismatch (3776, 11)
#   SUBJECT_ACCESSION ANCESTRAL_POPULATION DESCRIPTION      ETHNICITY  GENDER  \
# 0          SUB00240                  NaN      Muslim  Not Specified  Female
# 1          SUB00241                  NaN      Muslim  Not Specified    Male
# 2          SUB00242                  NaN      Muslim  Not Specified    Male
# 3          SUB00243                  NaN      Muslim  Not Specified  Female
# 4          SUB00244                  NaN      Muslim  Not Specified  Female
#
#     RACE RACE_SPECIFY       SPECIES STRAIN STRAIN_CHARACTERISTICS  \
# 0  Asian          NaN  Homo sapiens    NaN                    NaN
# 1  Asian          NaN  Homo sapiens    NaN                    NaN
# 2  Asian          NaN  Homo sapiens    NaN                    NaN
# 3  Asian          NaN  Homo sapiens    NaN                    NaN
# 4  Asian          NaN  Homo sapiens    NaN                    NaN
#
#    WORKSPACE_ID
# 0            49
# 1            49
# 2            49
# 3            49
# 4            49

# %%
arm_2_subject_valid.columns
# Out:
# Index(['ARM_ACCESSION', 'SUBJECT_ACCESSION', 'AGE_EVENT', 'AGE_EVENT_SPECIFY',
#        'AGE_UNIT', 'MAX_SUBJECT_AGE', 'MIN_SUBJECT_AGE', 'SUBJECT_PHENOTYPE',
#        'SUBJECT_LOCATION', 'MAX_SUBJECT_AGE_IN_YEARS',
#        'MIN_SUBJECT_AGE_IN_YEARS'],
#       dtype='object')

# %%
subject_w_age = pd.merge(arm_2_subject_valid, subject, on='SUBJECT_ACCESSION', how='left') ### I merge into arm_2_subject_valid as we have duplicated rows here that i probably want to keep whilst in the other its unique
subject_w_age.to_csv('tables/subject_w_age.csv')
subject_w_age.columns
# Out:
# Index(['ARM_ACCESSION', 'SUBJECT_ACCESSION', 'AGE_EVENT', 'AGE_EVENT_SPECIFY',
#        'AGE_UNIT', 'MAX_SUBJECT_AGE', 'MIN_SUBJECT_AGE', 'SUBJECT_PHENOTYPE',
#        'SUBJECT_LOCATION', 'MAX_SUBJECT_AGE_IN_YEARS',
#        'MIN_SUBJECT_AGE_IN_YEARS', 'ANCESTRAL_POPULATION', 'DESCRIPTION',
#        'ETHNICITY', 'GENDER', 'RACE', 'RACE_SPECIFY', 'SPECIES', 'STRAIN',
#        'STRAIN_CHARACTERISTICS', 'WORKSPACE_ID'],
#       dtype='object')

# %%
arm_2_subject['AGE_EVENT'].unique()
# Out:
# array(['Age at enrollment', 'Not Specified', 'Other',
#        'Age at Study Day 0', 'Age at initial vaccine administration',
#        'Age at infection', 'Age at initial treatment'], dtype=object)

# %%
#### LAB TEST PANEL INSIGHTS

lab_test_panel = lab_test_panel.rename(columns={'NAME_REPORTED': 'PANEL_NAME'})
lab_test = lab_test.rename(columns={'NAME_REPORTED': 'LAB_TEST_NAME'})
lab_tests = pd.merge(lab_test_panel,lab_test,
                    left_on='LAB_TEST_PANEL_ACCESSION',right_on='LAB_TEST_PANEL_ACCESSION') 
lab_test.head()
# Out:
#   LAB_TEST_ACCESSION LAB_TEST_PANEL_ACCESSION BIOSAMPLE_ACCESSION  \
# 0                LT1                    LP581            BS235842
# 1               LT10                    LP581            BS235842
# 2              LT100                    LP581            BS235844
# 3             LT1000                    LP581            BS236373
# 4            LT10000                    LP581            BS236064
#
#            NAME_PREFERRED          LAB_TEST_NAME REFERENCE_RANGE_ACCESSION  \
# 0  White Blood Cell Count                    WBC                      RR81
# 1             Eosinophils            EOSINOPHILS                      RR13
# 2  Neutrophils, Segmented  SEGMENTED NEUTROPHILS                      RR75
# 3               Basophils              BASOPHILS                       RR5
# 4              Lymphocyte            LYMPHOCYTES                      RR35
#
#   RESULT_UNIT_PREFERRED RESULT_UNIT_REPORTED  RESULT_VALUE_PREFERRED  \
# 0                   NaN        10*3 cells/uL                     8.5
# 1            percentage                    %                     1.0
# 2            percentage                    %                    53.0
# 3            percentage                    %                     0.0
# 4            percentage                    %                    26.0
#
#   RESULT_VALUE_REPORTED  WORKSPACE_ID
# 0     8.5 10*3 cells/uL           990
# 1                   1 %           990
# 2                  53 %           990
# 3                   0 %           990
# 4                  26 %           990

# %%
lab_tests = pd.merge(lab_test_panel,lab_test,
                    left_on='LAB_TEST_PANEL_ACCESSION',right_on='LAB_TEST_PANEL_ACCESSION')
print(lab_tests.shape)
lab_tests.to_csv('tables/lab_tests.csv')
lab_tests_backup = lab_tests.copy(deep=True)
lab_tests.head()
# Out:
# (1279882, 15)
#   LAB_TEST_PANEL_ACCESSION NAME_PREFERRED_x PANEL_NAME STUDY_ACCESSION  \
# 0                  LP10000   Chemistry Test  CHEMISTRY          SDY354
# 1                  LP10000   Chemistry Test  CHEMISTRY          SDY354
# 2                  LP10000   Chemistry Test  CHEMISTRY          SDY354
# 3                  LP10000   Chemistry Test  CHEMISTRY          SDY354
# 4                  LP10000   Chemistry Test  CHEMISTRY          SDY354
#
#    WORKSPACE_ID_x LAB_TEST_ACCESSION BIOSAMPLE_ACCESSION     NAME_PREFERRED_y  \
# 0            3709           LT100000            BS727101            Uric Acid
# 1            3709           LT100004            BS727102  Blood Urea Nitrogen
# 2            3709           LT100017            BS727106            Uric Acid
# 3            3709           LT100018            BS727106  Blood Urea Nitrogen
# 4            3709           LT100031            BS727110  Blood Urea Nitrogen
#
#     LAB_TEST_NAME REFERENCE_RANGE_ACCESSION RESULT_UNIT_PREFERRED  \
# 0  H_URIC (URATE)                       NaN                 mg/dl
# 1     H_BUN (BUN)                       NaN                 mg/dl
# 2  H_URIC (URATE)                       NaN                 mg/dl
# 3     H_BUN (BUN)                       NaN                 mg/dl
# 4     H_BUN (BUN)                       NaN                 mg/dl
#
#   RESULT_UNIT_REPORTED  RESULT_VALUE_PREFERRED RESULT_VALUE_REPORTED  \
# 0                MG/DL                    12.0              12 MG/DL
# 1                MG/DL                    24.0              24 MG/DL
# 2                MG/DL                     5.4             5.4 MG/DL
# 3                MG/DL                    29.0              29 MG/DL
# 4                MG/DL                    17.0              17 MG/DL
#
#    WORKSPACE_ID_y
# 0            3709
# 1            3709
# 2            3709
# 3            3709
# 4            3709

# %%
#Helper methods
def lab_test_panels(lab_tests):
    study_panels = lab_tests[['PANEL_NAME','LAB_TEST_NAME']]
    study_panels = study_panels.groupby(['PANEL_NAME','LAB_TEST_NAME']).size().reset_index(name="COUNTS")
    return study_panels
def lab_test_panels_prefered_names(lab_tests):
    study_panels = lab_tests[['NAME_PREFERRED_x','NAME_PREFERRED_y']]
    study_panels = study_panels.groupby(['NAME_PREFERRED_x','NAME_PREFERRED_y']).size().reset_index(name="COUNTS")
    return study_panels

lab_tests_PANEL_NAME = lab_test_panels(lab_tests)
lab_tests_NAME_PREFERRED = lab_test_panels_prefered_names(lab_tests)
PANEL_NAMEs_unique = lab_tests_PANEL_NAME['PANEL_NAME'].unique()
LAB_TESTS_unique = lab_tests_PANEL_NAME['LAB_TEST_NAME'].unique()
NAME_PREFERRED_x_unique = lab_tests_NAME_PREFERRED['NAME_PREFERRED_x'].unique()
NAME_PREFERRED_y_unique = lab_tests_NAME_PREFERRED['NAME_PREFERRED_y'].unique()


print('PANEL_NAMEs '  + str(len(PANEL_NAMEs_unique)))
print('LAB_TESTS '  + str(len(LAB_TESTS_unique)))
print('LAB_TEST counts: ' + str(sum(lab_tests_PANEL_NAME['COUNTS'])))
print('PANEL_NAMEs preferred names '  + str(len(NAME_PREFERRED_x_unique)))
print('LAB_TESTS preferred names '  + str(len(NAME_PREFERRED_y_unique)))
print('LAB_TEST preferred counts: ' + str(sum(lab_tests_NAME_PREFERRED['COUNTS'])))


lab_tests_PANEL_NAME.head()
# Out:
# PANEL_NAMEs 105
# LAB_TESTS 1550
# LAB_TEST counts: 1279882
# PANEL_NAMEs preferred names 17
# LAB_TESTS preferred names 185
# LAB_TEST preferred counts: 802211
#                         PANEL_NAME  \
# 0  AD5 neutralizing antibody titer
# 1          AFP (alpha-fetoprotein)
# 2          Act CD8 T Cell Response
# 3             Amniotic Fluid Panel
# 4             Amniotic Fluid Panel
#
#                                        LAB_TEST_NAME  COUNTS
# 0  pre-existing serum ad5 neutralizing antibody t...      20
# 1                            AFP (alpha-fetoprotein)      56
# 2                            Act CD8 T Cell Response      25
# 3                                            Glucose      15
# 4                                      Interleukin 6      15

# %%
print('NA NAME_PREFERRED_x: ' + str(lab_tests['NAME_PREFERRED_x'].isna().sum()))
print('NA NAME_PREFERRED_y: ' + str(lab_tests['NAME_PREFERRED_y'].isna().sum()))
print('NA PANEL_NAME: ' + str(lab_tests['PANEL_NAME'].isna().sum()))
print('NA LAB_TEST_NAME: ' + str(lab_tests['LAB_TEST_NAME'].isna().sum()))
# Out:
# NA NAME_PREFERRED_x: 340701
# NA NAME_PREFERRED_y: 297137
# NA PANEL_NAME: 0
# NA LAB_TEST_NAME: 0

# %%
#### LIST FOR BINNING THE INDIVIDUAL STUDY TYPES!
#grouped = lab_tests_PANEL_NAME.groupby('PANEL_NAME')['LAB_TEST_NAME'].apply(list).reset_index()
#for index, row in grouped.iterrows():
   """  group = row['PANEL_NAME']
    pref_name = lab_tests[lab_tests['PANEL_NAME'] == group]['NAME_PREFERRED_x'].values
    if len(pref_name) > 0:
        pref_name = pref_name[0]
    else: 
        pref_name = ''
        
    items = row['LAB_TEST_NAME'][0]
    
    pref_item = {}
    for i, x in enumerate(row['LAB_TEST_NAME']):
        y = lab_tests[lab_tests['LAB_TEST_NAME'] == row['LAB_TEST_NAME'][i]]['NAME_PREFERRED_y'].values
        if len(y) > 0:
            pref_item[i] = y[0]
        else:
            pref_item[i] = ''
    
    print(f"\n{group} ({pref_name})")
    [print('\t' + str(x) + f' ({pref_item[i]})') for i, x in enumerate(row['LAB_TEST_NAME'])] """
# Out:
#   Cell In[15], line 4
#     """  group = row['PANEL_NAME']
#     ^
# IndentationError: unexpected indent

# %%
### biomarkers
biomarker_PANEL_NAMEs = [
    'Blood Flow Cytometry: ',
    'Protein or Enzyme Type Measurement: ',
    ]

# %%
### Next step: Get all Study accessions related to the biomarker and cell type bins
### Then: Get the subject
biomarker_PANEL_NAMEs_trimmed = [x[:-2] for x in biomarker_PANEL_NAMEs]
biomarker_all_tests = lab_tests[lab_tests['PANEL_NAME'].isin(biomarker_PANEL_NAMEs_trimmed)]
biomarker_all_tests.head()
# Out:
#        LAB_TEST_PANEL_ACCESSION                    NAME_PREFERRED_x  \
# 443504                  LP29065  Protein or Enzyme Type Measurement
# 443505                  LP29065  Protein or Enzyme Type Measurement
# 443506                  LP29065  Protein or Enzyme Type Measurement
# 443507                  LP29065  Protein or Enzyme Type Measurement
# 443508                  LP29065  Protein or Enzyme Type Measurement
#
#                                 PANEL_NAME STUDY_ACCESSION  WORKSPACE_ID_x  \
# 443504  Protein or Enzyme Type Measurement          SDY625            4345
# 443505  Protein or Enzyme Type Measurement          SDY625            4345
# 443506  Protein or Enzyme Type Measurement          SDY625            4345
# 443507  Protein or Enzyme Type Measurement          SDY625            4345
# 443508  Protein or Enzyme Type Measurement          SDY625            4345
#
#        LAB_TEST_ACCESSION BIOSAMPLE_ACCESSION      NAME_PREFERRED_y  \
# 443504           LT594351            BS843065               Protein
# 443505           LT594352            BS843065            Creatinine
# 443506           LT594353            BS843065  Creatinine clearance
# 443507           LT594354            BS843066               Protein
# 443508           LT594355            BS843066            Creatinine
#
#                LAB_TEST_NAME REFERENCE_RANGE_ACCESSION RESULT_UNIT_PREFERRED  \
# 443504               Protein                       NaN                   NaN
# 443505            Creatinine                       NaN                   NaN
# 443506  Creatinine Clearance                       NaN                   NaN
# 443507               Protein                       NaN                   NaN
# 443508            Creatinine                       NaN                   NaN
#
#        RESULT_UNIT_REPORTED  RESULT_VALUE_PREFERRED RESULT_VALUE_REPORTED  \
# 443504               mg/day                     7.0                     7
# 443505               mg/day                    63.6                  63.6
# 443506       mL/min/1.72m^2                   107.0                   107
# 443507               mg/day                     9.0                     9
# 443508               mg/day                    75.3                  75.3
#
#         WORKSPACE_ID_y
# 443504            4345
# 443505            4345
# 443506            4345
# 443507            4345
# 443508            4345

# %%
biomarker_all_studies_array = biomarker_all_tests['STUDY_ACCESSION'].unique()
biomarker_all_studies = study[study['STUDY_ACCESSION'].isin(biomarker_all_studies_array)]
biomarker_all_studies.columns
# Out:
# Index(['STUDY_ACCESSION', 'ACTUAL_COMPLETION_DATE', 'ACTUAL_ENROLLMENT',
#        'ACTUAL_START_DATE', 'AGE_UNIT', 'BRIEF_DESCRIPTION', 'BRIEF_TITLE',
#        'CLINICAL_TRIAL', 'CONDITION_STUDIED', 'DCL_ID', 'DESCRIPTION', 'DOI',
#        'ENDPOINTS', 'GENDER_INCLUDED', 'HYPOTHESIS',
#        'INITIAL_DATA_RELEASE_DATE', 'INITIAL_DATA_RELEASE_VERSION',
#        'INTERVENTION_AGENT', 'LATEST_DATA_RELEASE_DATE',
#        'LATEST_DATA_RELEASE_VERSION', 'MAXIMUM_AGE', 'MINIMUM_AGE',
#        'OBJECTIVES', 'OFFICIAL_TITLE', 'SHARED_STUDY',
#        'SPONSORING_ORGANIZATION', 'TARGET_ENROLLMENT', 'WORKSPACE_ID'],
#       dtype='object')

# %%
subject_w_age.columns ## ALLDATA subjects
# Out:
# Index(['ARM_ACCESSION', 'SUBJECT_ACCESSION', 'AGE_EVENT', 'AGE_EVENT_SPECIFY',
#        'AGE_UNIT', 'MAX_SUBJECT_AGE', 'MIN_SUBJECT_AGE', 'SUBJECT_PHENOTYPE',
#        'SUBJECT_LOCATION', 'MAX_SUBJECT_AGE_IN_YEARS',
#        'MIN_SUBJECT_AGE_IN_YEARS', 'ANCESTRAL_POPULATION', 'DESCRIPTION',
#        'ETHNICITY', 'GENDER', 'RACE', 'RACE_SPECIFY', 'SPECIES', 'STRAIN',
#        'STRAIN_CHARACTERISTICS', 'WORKSPACE_ID'],
#       dtype='object')

# %%
arm_or_cohort.columns
# Out:
# Index(['ARM_ACCESSION', 'DESCRIPTION', 'NAME', 'STUDY_ACCESSION',
#        'TYPE_REPORTED', 'TYPE_PREFERRED', 'WORKSPACE_ID'],
#       dtype='object')

# %%
### I take subject_w_age as I want the duplicates in this position, just need to remember to remove them for the plots
study_arm_subject = pd.merge(subject_w_age, arm_or_cohort, left_on='ARM_ACCESSION',right_on='ARM_ACCESSION')
study_arm_subject.to_csv('tables/study_arm_subject.csv')
### I expect to have the same duplicates number of duplicates as before as we kepts the different time event data: 
duplicates = study_arm_subject[study_arm_subject.duplicated('SUBJECT_ACCESSION', keep='first')] 
study_arm_subject.columns # Here I get GENDER and AGE data for subjects (SUBJECT_ACCESSION).
# Also I get related studies (STUDY_ACCESSION)
# Out:
# Index(['ARM_ACCESSION', 'SUBJECT_ACCESSION', 'AGE_EVENT', 'AGE_EVENT_SPECIFY',
#        'AGE_UNIT', 'MAX_SUBJECT_AGE', 'MIN_SUBJECT_AGE', 'SUBJECT_PHENOTYPE',
#        'SUBJECT_LOCATION', 'MAX_SUBJECT_AGE_IN_YEARS',
#        'MIN_SUBJECT_AGE_IN_YEARS', 'ANCESTRAL_POPULATION', 'DESCRIPTION_x',
#        'ETHNICITY', 'GENDER', 'RACE', 'RACE_SPECIFY', 'SPECIES', 'STRAIN',
#        'STRAIN_CHARACTERISTICS', 'WORKSPACE_ID_x', 'DESCRIPTION_y', 'NAME',
#        'STUDY_ACCESSION', 'TYPE_REPORTED', 'TYPE_PREFERRED', 'WORKSPACE_ID_y'],
#       dtype='object')

# %%
#### Here I want to testwise prinst status for biomarker samples
### SUBJECT extraction
biomarker_study_arm_subject = study_arm_subject[study_arm_subject['STUDY_ACCESSION'].isin(biomarker_all_studies['STUDY_ACCESSION'])]
biomarker_study_arm_subject_no_duplicated = biomarker_study_arm_subject.drop_duplicates('SUBJECT_ACCESSION')
print(f'Amount of Subjects: {biomarker_study_arm_subject.shape}')
print(f'Amount of Subjects no duplicates: {biomarker_study_arm_subject_no_duplicated.shape}')
biomarker_study_arm_subject['AGE_EVENT'].unique() ## 'Age at initial treatment', 'Other', 'Age at enrollment', 'Age at Study Day 0'
## here aprently the age events are several, problbly for the individual studies... 
biomarker_study_arm_subject_no_duplicated
# Out:
# Amount of Subjects: (2577, 27)
# Amount of Subjects no duplicates: (2577, 27)
#       ARM_ACCESSION SUBJECT_ACCESSION                 AGE_EVENT  \
# 22066       ARM2707         SUB151307  Age at initial treatment
# 22067       ARM2707         SUB151308  Age at initial treatment
# 22068       ARM2707         SUB151310  Age at initial treatment
# 22069       ARM2707         SUB151312  Age at initial treatment
# 22070       ARM2707         SUB151313  Age at initial treatment
# ...             ...               ...                       ...
# 71105       ARM6560         SUB259910         Age at enrollment
# 71106       ARM6560         SUB259911         Age at enrollment
# 71107       ARM6560         SUB259912         Age at enrollment
# 71108       ARM6560         SUB259913         Age at enrollment
# 71109       ARM6560         SUB259914         Age at enrollment
#
#       AGE_EVENT_SPECIFY AGE_UNIT  MAX_SUBJECT_AGE  MIN_SUBJECT_AGE  \
# 22066               NaN    Years              7.0              7.0
# 22067               NaN    Years             18.0             18.0
# 22068               NaN    Years              7.0              7.0
# 22069               NaN    Years             13.0             13.0
# 22070               NaN    Years             18.0             18.0
# ...                 ...      ...              ...              ...
# 71105               NaN    Years              1.0              1.0
# 71106               NaN    Years              1.0              1.0
# 71107               NaN    Years              1.0              1.0
# 71108               NaN    Years              1.0              1.0
# 71109               NaN    Years              1.0              1.0
#
#       SUBJECT_PHENOTYPE SUBJECT_LOCATION  MAX_SUBJECT_AGE_IN_YEARS  ...  \
# 22066               NaN              NaN                       7.0  ...
# 22067               NaN              NaN                      18.0  ...
# 22068               NaN              NaN                       7.0  ...
# 22069               NaN              NaN                      13.0  ...
# 22070               NaN              NaN                      18.0  ...
# ...                 ...              ...                       ...  ...
# 71105               NaN        Australia                       1.0  ...
# 71106               NaN        Australia                       1.0  ...
# 71107               NaN        Australia                       1.0  ...
# 71108               NaN        Australia                       1.0  ...
# 71109               NaN        Australia                       1.0  ...
#
#             SPECIES STRAIN STRAIN_CHARACTERISTICS WORKSPACE_ID_x  \
# 22066  Homo sapiens    NaN                    NaN           4117
# 22067  Homo sapiens    NaN                    NaN           4117
# 22068  Homo sapiens    NaN                    NaN           4117
# 22069  Homo sapiens    NaN                    NaN           4117
# 22070  Homo sapiens    NaN                    NaN           4117
# ...             ...    ...                    ...            ...
# 71105  Homo sapiens    NaN                    NaN           6689
# 71106  Homo sapiens    NaN                    NaN           6689
# 71107  Homo sapiens    NaN                    NaN           6689
# 71108  Homo sapiens    NaN                    NaN           6689
# 71109  Homo sapiens    NaN                    NaN           6689
#
#                                            DESCRIPTION_y  \
# 22066  3 cycles, six  months apart, each consisting o...
# 22067  3 cycles, six  months apart, each consisting o...
# 22068  3 cycles, six  months apart, each consisting o...
# 22069  3 cycles, six  months apart, each consisting o...
# 22070  3 cycles, six  months apart, each consisting o...
# ...                                                  ...
# 71105          Non-sensitized, non-food-allergic infants
# 71106          Non-sensitized, non-food-allergic infants
# 71107          Non-sensitized, non-food-allergic infants
# 71108          Non-sensitized, non-food-allergic infants
# 71109          Non-sensitized, non-food-allergic infants
#
#                                      NAME STUDY_ACCESSION    TYPE_REPORTED  \
# 22066  hOKT3gamma1 (Ala-Ala) (teplizumab)          SDY569     Experimental
# 22067  hOKT3gamma1 (Ala-Ala) (teplizumab)          SDY569     Experimental
# 22068  hOKT3gamma1 (Ala-Ala) (teplizumab)          SDY569     Experimental
# 22069  hOKT3gamma1 (Ala-Ala) (teplizumab)          SDY569     Experimental
# 22070  hOKT3gamma1 (Ala-Ala) (teplizumab)          SDY569     Experimental
# ...                                   ...             ...              ...
# 71105                                 NaN         SDY2015  Healthy Control
# 71106                                 NaN         SDY2015  Healthy Control
# 71107                                 NaN         SDY2015  Healthy Control
# 71108                                 NaN         SDY2015  Healthy Control
# 71109                                 NaN         SDY2015  Healthy Control
#
#          TYPE_PREFERRED WORKSPACE_ID_y
# 22066  Experimental Arm           4117
# 22067  Experimental Arm           4117
# 22068  Experimental Arm           4117
# 22069  Experimental Arm           4117
# 22070  Experimental Arm           4117
# ...                 ...            ...
# 71105   Healthy Control           6689
# 71106   Healthy Control           6689
# 71107   Healthy Control           6689
# 71108   Healthy Control           6689
# 71109   Healthy Control           6689
#
# [2577 rows x 27 columns]

# %%
### OVERALL
#sns.violinplot(x='GENDER', y='MAX_SUBJECT_AGE_IN_YEARS', hue='GENDER', data=biomarker_study_arm_subject_no_duplicated[['GENDER', 'MAX_SUBJECT_AGE_IN_YEARS']], split=True)
#plt.show()

# %%
############################################################################
### Letztes meeting mit florian: only bulk Transcriptomics to start with! 
############################################################################
print("")
### Aparently this is the Gene expression data... will dig ito this a bit... 
print("EXPSAMPLE_PLUBLIC_REPOSITORY")
print("============================================================")
gene_expression = pd.read_table(f"{immport_prefix}/expsample_public_repository.txt",sep="\t")
print(gene_expression.columns)
print(gene_expression.shape)

print("EXPSAMPLE")
print("============================================================")
expsample = pd.read_table(f"{immport_prefix}/expsample.txt",sep="\t")
print(expsample.columns)
print(expsample.shape)

print("EXPERIMENT")
print("============================================================")
experiment = pd.read_table(f"{immport_prefix}/experiment.txt",sep="\t")
print(experiment.columns)
print(experiment.shape)

print("BIOSAMPLE")
print("============================================================")
biosample = pd.read_table(f"{immport_prefix}/biosample.txt",sep="\t")
print(biosample.columns)
print(biosample.shape)


print("EXPSAMPLE_2_BIOSAMPLE")
print("============================================================")
expsample_2_biosample = pd.read_table(f"{immport_prefix}/expsample_2_biosample.txt",sep="\t")
print(expsample_2_biosample.columns)
print(expsample_2_biosample.shape)
# Out:
# EXPSAMPLE_PLUBLIC_REPOSITORY
# ============================================================
# Index(['RESULT_ID', 'EXPSAMPLE_ACCESSION', 'REPOSITORY_ACCESSION',
#        'REPOSITORY_NAME'],
#       dtype='object')
# (52404, 4)
# EXPSAMPLE
# ============================================================
# Index(['EXPSAMPLE_ACCESSION', 'DESCRIPTION', 'EXPERIMENT_ACCESSION', 'NAME',
#        'RESULT_SCHEMA', 'UPLOAD_RESULT_STATUS', 'WORKSPACE_ID'],
#       dtype='object')
# (850798, 7)
# EXPERIMENT
# ============================================================
# Index(['EXPERIMENT_ACCESSION', 'DESCRIPTION', 'MEASUREMENT_TECHNIQUE', 'NAME',
#        'STUDY_ACCESSION', 'WORKSPACE_ID'],
#       dtype='object')
# (3047, 6)
# BIOSAMPLE
# ============================================================
# /tmp/ipykernel_99518/197766785.py:26: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   biosample = pd.read_table(f"{immport_prefix}/biosample.txt",sep="\t")
# Index(['BIOSAMPLE_ACCESSION', 'DESCRIPTION', 'NAME', 'PLANNED_VISIT_ACCESSION',
#        'STUDY_ACCESSION', 'STUDY_TIME_COLLECTED', 'STUDY_TIME_COLLECTED_UNIT',
#        'STUDY_TIME_T0_EVENT', 'STUDY_TIME_T0_EVENT_SPECIFY',
#        'SUBJECT_ACCESSION', 'SUBTYPE', 'TYPE', 'WORKSPACE_ID'],
#       dtype='object')
# (482701, 13)
# EXPSAMPLE_2_BIOSAMPLE
# ============================================================
# Index(['BIOSAMPLE_ACCESSION', 'EXPSAMPLE_ACCESSION'], dtype='object')
# (877940, 2)

# %%
## TODO measurement techniques die sinn machen in list ordnen 
####### -> damit DB reduzieren und dann NAME und DESCRIPTION nehmen um weiter zu arbeiten
####### -> ergebniss evtl nochmal kurz mit flo absprechen wenn Zeit...
experiment['MEASUREMENT_TECHNIQUE'].unique()
valid_measurement_techiques = [
    'SNP microarray',
    'Transcription profiling by array',
    'Other',
    'Sequencing',
    'Flow Cytometry',
    'Q-PCR',
    'PCR',
    'CyTOF',
    'Liquid Chromatography',
    'Nanostring',
    'microRNA profiling assay',
    'Array',
    'Transcription profiling assay',
    'Real time polymerase chain reaction assay',
    'LC_MS',
    'in situ Hybridization', 
    'DNA microarray'
                               ]


## aparently DNA microarray can also be used for RNA 
## Liquid Chromatography -> es gibt wohl ne LC technik die RNAseq kann


## Flow Cytometry -> eher protein aber lass ich mal drin... 
## Immunoblot = Westernblot -> Proteine (Northern Blot wäre RNA)
## PCR -> reverse transcription: 
## Real-time PCR, on the other hand, is a more targeted approach to gene expression analysis
## Cytometric Bead Array Assay , SOMAscan assay -> proteins
## Olink assay, Multiplex Bead Array Assay -> protein biomarkers

## EMSA -> Protein - RNA interaction

## Whole Genome Sequencing , DNA microarray -> DNA

# %%
subject['SPECIES'].unique()
# Out:
# array(['Homo sapiens'], dtype=object)

# %%
experiment_transcriptomes = experiment[experiment['MEASUREMENT_TECHNIQUE'].isin(valid_measurement_techiques)]
### ALSO i need to filter for homo sapiens ... 
workspace_ids_homo_sapiens = subject[subject['SPECIES'] == 'Homo sapiens']['WORKSPACE_ID'].unique()
experiment_transcriptomes_human = experiment_transcriptomes[experiment_transcriptomes['WORKSPACE_ID'].isin(workspace_ids_homo_sapiens)]
experiment_transcriptomes_human.shape
# Out:
# (834, 6)

# %%
### Hier wieder ne List aus der ich händisch raus sortien will welche methoden nicht passen
################################
### Ab hier mess ich BULK 
## kein CyTOF, Other -> ich mach mal nur microarray und sequencing und erweitere des stück für stück ... 

experiment_transcriptomes_sorted = experiment_transcriptomes_human.sort_values(by='MEASUREMENT_TECHNIQUE')
for name, group in experiment_transcriptomes_sorted.groupby('MEASUREMENT_TECHNIQUE'):
    print(f"{name}")
    for _, row in group.iterrows():
        print(f"\t {row['NAME']} ({row['DESCRIPTION']})")
    print() 
    
    
sorted_out_measurements = [
    'CyTOF',
    'Other',
    '',
    '',
]

sorted_out_names = [
    'VT2020',
    'Bacterial re-isolation (nan)',
    '',
    '',
]
# Out:
# Array
# 	 Screening Biopsy Gene Expression (nan)
#
# CyTOF
# 	 Immune system mass cytometry Validation set (nan)
# 	 STANEXP_CYTOFCD8PCA_2 (nan)
# 	 CyToF Ligand Panel (nan)
# 	 CyToF NK Panel (nan)
# 	 CyTOF PBMC Year 2017 (nan)
# 	 tissue-resident memory t cells - CyTOF (CyTOF profiling of tissue-resident memory T cells for three post-mortem, healthy donors, across several tissues.)
# 	 NK cells without co-culture (nan)
# 	 NK cells co-cultured with autologous CD4 T cells infected with the Q23 strain of HIV (nan)
# 	 Whole Blood CyTOF (nan)
# 	 Syngeneic murine brain tumors CyTOF staining (nan)
# 	 SLVP017_2010_CyTOF (nan)
# 	 CyTOF (nan)
# 	 CyTOF human GBM and PBMC (nan)
# 	 HN_exp_01 (nan)
# 	 Ligand Staining on Influenza Infected Monocytes (nan)
# 	 CyTOF_Project3_DV2_DV4 (nan)
# 	 Dengue.CyTOF (nan)
# 	 CyTOF analysis (nan)
# 	 exp_60048_DLN (nan)
# 	 STANEXP_CYTOFCD8PCA_1 (nan)
# 	 Ligan Panel Mass cytometry (CyToF) (nan)
# 	 NK Panel Mass cytometry (CyToF) (nan)
# 	 NK CyTOF (nan)
# 	 CyToF & LegendScreen (nan)
# 	 Human Immune Signature of Dengue virus infection-Cytof CD8 (nan)
# 	 Lymph node reservoirs for long-lived memory T cells - CyTOF (nan)
# 	 CyTOF (nan)
# 	 SDY1708_CyTOF (nan)
# 	 CyTOF assays on 2011 flu vaccine samples (CyTOF surface phenotyping, day 0)
# 	 WNV Whole Blood Mass Cytometry Year 2 (nan)
# 	 Human Immune Signature of Dengue virus infection-Cytof Acute CD4 (nan)
# 	 CyTOF_PBMC_ZIKV_DENV2 (nan)
# 	 SLVP018_2013_CyTOF-phenotyping (nan)
# 	 SDM_pCyTOFwholeblood_FluStudy21_2013 (nan)
# 	 CyTOF Panel 1 (nan)
# 	 CyTOF assays on 2010 flu vaccine samples (CyTOF surface phenotyping, day 0)
# 	 Immune system mass cytometry Training set (nan)
# 	 SDM_CyTOF_SLVP017_2011 (nan)
# 	 Single-cell mass cytometry (profilling decidue cell populations)
# 	 CyToF Narrow Bore (nan)
# 	 CyToF Wide Bore (nan)
# 	 CyTOF (nan)
# 	 exp_60049_spleen (nan)
# 	 exp_60050_BM (nan)
# 	 CyTOF (CyTOF surface phenotyping, day 0)
# 	 exp_60068_blood (nan)
# 	 IvisonVendrame1_NK (nan)
# 	 CyTOF surface phenotyping, day 0 (CyTOF surface phenotyping, day 0)
# 	 CyTOF cell surface phenotyping (CyTOF surface phenotyping, day 0)
# 	 CyTOF PBMC Year 2018 (nan)
# 	 pDCs antiviral response - CyTOF (nan)
# 	 PBMC CyTOF OA B cell panel ('Data Quality Check - AMP Synovium Phase 1 CyTOF.immport.xlsx', a quality control reports for samples, is available as a protocol.)
# 	 exp_60062_tumor (nan)
# 	 RA Synovial PMN CyToF Panel normalized ('Data Quality Check - AMP Synovium Phase 1 CyTOF.immport.xlsx', a quality control reports for samples, is available as a protocol.)
# 	 PBMC CyTOF RA Myeloid panel ('Data Quality Check - AMP Synovium Phase 1 CyTOF.immport.xlsx', a quality control reports for samples, is available as a protocol.)
# 	 CyTOF PBMC Stimulated Year 2017 (nan)
# 	 Synovium CyTOF IC ('Data Quality Check - AMP Synovium Phase 1 CyTOF.immport.xlsx', a quality control reports for samples, is available as a protocol.)
# 	 CyTOF surface phenotyping day 0 (CyTOF surface phenotyping day 0)
# 	 Immune cell profiling using CyTOF (nan)
# 	 CyTOF surface phenotyping, day 0 (CyTOF surface phenotyping, day 0)
# 	 RA Arthroplasty Total Leukocyte CyToF Panel normalized ('Data Quality Check - AMP Synovium Phase 1 CyTOF.immport.xlsx', a quality control reports for samples, is available as a protocol.)
# 	 SLE Total Leukocyte CyToF Panel normalized (nan)
# 	 PBMC CyTOF OA T cell panel ('Data Quality Check - AMP Synovium Phase 1 CyTOF.immport.xlsx', a quality control reports for samples, is available as a protocol.)
# 	 SLVP017_2013_CyTOF (nan)
# 	 CyTOF surface phenotyping, day 0 (CyTOF surface phenotyping, day 0)
# 	 julie_cytof (nan)
# 	 CyTOF SLE B cell panel of PBMCs (nan)
# 	 CyTOF analysis of PBMCs for CHIKV IOF (nan)
# 	 CyTOF PBMC Stimulated Year 2018 (nan)
# 	 ACK buffer CyTOF (nan)
# 	 mass cytometry (nan)
# 	 WNV Whole Blood Mass Cytometry Year 1 (nan)
# 	 RC4_cytof (nan)
# 	 Ficoll buffer CyTOF (nan)
# 	 CyTOF SLE Myeloid panel of PBMCs (nan)
# 	 CyTOF SLE T cell panel of PBMCs (nan)
# 	 CyTOF_HIPC2_Flu_Year2 (nan)
# 	 CyTOF surface phenotyping, day 0 (CyTOF surface phenotyping, day 0)
# 	 CyTOF-Human Maternal Immune Response (Characterize the human maternal immune response 6 months or greater post delivery)
# 	 IvisonVendrame1_Ligand (nan)
# 	 PMN CyToF Panel normalized (nan)
#
# DNA microarray
# 	 VT2020 (Influenza / S. aureus superinfection of C57BL/6 mouse)
# 	 RN2021.A (MDDC transduced with control vector)
#
# Flow Cytometry
# 	 RCF (nan)
# 	 FACS_ACS (nan)
# 	 EXP-09-AA1236: BMH71-09,TNF IFNB combination dilution curve triplicate (Title: BMH71-09,TNF IFNB combination dilution curve triplicate; ProjectDate: 06/03/2009; Author: Marjanovic, Nada; Project: AVDC; Primary Contact: Hartmann, Boris (boris.hartmann@mssm.edu))
# 	 Vax005 T-cell FACS (nan)
# 	 EXP-09-AA2428: BMH-14-09 TNFa Rantes ceckup on protein level DCs U937, Mono, KG1 (Title: BMH-14-09 TNFa Rantes ceckup on protein level DCs U937, Mono, KG1; ProjectDate: 01/21/2009; Author: Hartmann, Boris; Project: AVDC; Primary Contact: Hartmann, Boris (boris.hartmann@mssm.edu))
# 	 EXP-09-AA0250: Transfection of dendritic cells with pmax GFP using the nucleofection program FF137 and FF138 (Title: Transfection of dendritic cells with pmax GFP using the nucleofection program FF137 and FF138; ProjectDate: 06/23/2009; Author: Patil, Sonali; Project: siRNA; Primary Contact: Patil, Sonali (sonali.patil@mssm.edu); Related experiments: EXP-09-AA0248 [Optimisation of dendritic cell nucleofection using amaxa nucleofection shuttle system using SE, SF and monocyte nucleofection buffer.])
# 	 EXP-10-AA1838: Inhibition of IL-10 Signaling in DCs Using Receptor Antibody (Title: Inhibition of IL-10 Signaling in DCs Using Receptor Antibody; ProjectDate: 03/09/2010; Author: Braun, David; Project: STAT3 modeling, DC maturation; Related experiments: EXP-09-AA1813, EXP-09-AA0917, EXP-09-AA0922, EXP-09-AA0924, EXP-09-AA1815, EXP-09-AA1815, EXP-10-AA1829)
# 	 EXP-09-AA1235: BMH70-09,TNFa IFNb phosphlow 2.5 min for 1 hr (Title: BMH70-09,TNFa IFNb phosphlow 2.5 min for 1 hr; ProjectDate: 06/02/2009; Author: Marjanovic, Nada; Project: AVDC; Primary Contact: Hartmann, Boris (boris.hartmann@mssm.edu))
# 	 AMP Phase 1 Urine Flow Cytometry Panel (nan)
# 	 Flow Cytometry (nan)
# 	 AMP Phase 1 Kidney Flow Cytometry Panel (nan)
# 	 Early Life TCell Study (nan)
# 	 Flow Cytometry of T cells for CMV study (nan)
# 	 FACS_Tfh (nan)
# 	 EXP-10-AA1178: Deconvolution of Signaling Pathway Activation by LPS in the Presence/Absence of External Cytokine Milieu (Title: Deconvolution of Signaling Pathway Activation by LPS in the Presence/Absence of External Cytokine Milieu; ProjectDate: 08/12/2010; Author: Gonzalez, Joanna; Project: DC maturation; Primary Contact: Gonzalez, Joanna (joanna.gonzalez@mssm.edu))
# 	 EXP-09-AA3524: BMH-110-09 PR8-GFP (Title: BMH-110-09 PR8-GFP; ProjectDate: 10/21/2009; Author: Hartmann, Boris; Project: AVDC; Primary Contact: Hartmann, Boris (boris.hartmann@mssm.edu))
# 	 FACS_innate (nan)
# 	 B cell Panel 2 2013 (nan)
# 	 SDY887_2007_phosphoFlow (The fcs files for this experiment are not available.)
# 	 EXP-10-AA3563: BMH-19-10 U937 TNF IFN synergy flow (Title: BMH-19-10 U937 TNF IFN synergy flow; ProjectDate: 03/03/2010; Author: Hartmann, Boris; Project: experimental setup; Primary Contact: Hartmann, Boris (boris.hartmann@mssm.edu))
# 	 EXP-10-AA1835: cDC (s457) Response to IL-6 / IL-10 +/- SHP2 Inhibitor +/- IL-10Ra Ab (Triplicate) (Title: cDC (s457) Response to IL-6 / IL-10 +/- SHP2 Inhibitor +/- IL-10Ra Ab (Triplicate); ProjectDate: 02/25/2010; Author: Braun, David; Project: STAT3 modeling, DC maturation; Related experiments: EXP-09-AA1813, EXP-09-AA0917, EXP-09-AA0922, EXP-09-AA0924, EXP-09-AA1815, EXP-09-AA1815, EXP-10-AA1829)
# 	 julie_phos (nan)
# 	 EXP-10-AA0268: Testing the phosphorylation profiles of ERK and p38 in DCs in response to LPS and Curdlan stimuli. (Title: Testing the phosphorylation profiles of ERK and p38 in DCs in response to LPS and Curdlan stimuli.; ProjectDate: 01/15/2010; Author: Patil, Sonali; Project: DC maturation; Primary Contact: Patil, Sonali (sonali.patil@mssm.edu))
# 	 EXP-09-AA1233: BMH-69-09 TNFa IFNb phosphlow 10min for 1 hr , different conc of TNFa (Title: BMH-69-09 TNFa IFNb phosphlow 10min for 1 hr , different conc of TNFa; ProjectDate: 05/20/2009; Author: Marjanovic, Nada; Project: AVDC; Primary Contact: Hartmann, Boris (boris.hartmann@mssm.edu))
# 	 Flow Cytometry (nan)
# 	 EXP-08-AA0915: KG1 Dose Response to IL6 -6th with Bar-code (Master) (Title: KG1 Dose Response to IL6 -6th with Bar-code (Master); ProjectDate: 12/03/2008; Author: Seto, Jeremy; Project: STAT3 modeling, DC maturation; Related experiments: EXP-08-AA1805, EXP-08-AA1807, EXP-08-AA1810)
# 	 NCH_2011_FLOW_Tfh (nan)
# 	 NCH_2011_FLOW_DC (nan)
# 	 NCH_2011_FLOW_Mono (nan)
# 	 EXP-09-AA0251: Use 7 new nucleofection programs to optimize DC nucleofection (Title: Use 7 new nucleofection programs to optimize DC nucleofection; ProjectDate: 07/01/2009; Author: Patil, Sonali; Project: siRNA; Primary Contact: Patil, Sonali (sonali.patil@mssm.edu))
# 	 EXP-08-AA0580: BMH-87-08 POC (Title: BMH-87-08 POC; ProjectDate: 10/07/2008; Author: Hartmann, Boris; Project: experimental setup; Primary Contact: Hartmann, Boris (boris.hartmann@mssm.edu))
# 	 EXP-08-AA0217: Transfection of KG1 cells with pmaxGFP (Title: Transfection of KG1 cells with pmaxGFP; ProjectDate: 09/19/2008; Author: Patil, Sonali; Project: DC response to NDV)
# 	 EXP-10-AA3582: BMH-41-10 4 cytokines all combinationsmat marker upregulation (Title: BMH-41-10 4 cytokines all combinationsmat marker upregulation; ProjectDate: 06/14/2010; Author: Hartmann, Boris; Project: AVDC; Primary Contact: Hartmann, Boris (boris.hartmann@mssm.edu))
# 	 EXP-09-AA1148: Measuring  IFNAR1 Internalization after IFN Treatment in DCs (Title: Measuring IFNAR1 Internalization after IFN Treatment in DCs; ProjectDate: 11/03/2009; Author: Gonzalez, Joanna; Project: DC maturation; Related experiments: EXP-09-AA1145 [Measuring IFN Receptor Internalization and SOCS1/3 Induction after IFN Treatment in DCs])
# 	 B7H4 surface upregulation after stimulation of adult and old PBMCs with CLO97 for 24hrs (nan)
# 	 PDL2 surface upregulation after stimulation of adult and old PBMCs with CLO97 for 24hrs (nan)
# 	 PDL1 surface upregulation after stimulation of adult and old PBMCs with CLO97 for 24hrs (nan)
# 	 TLR7 surface upregulation on adult and old PBMCs (nan)
# 	 TLR4 surface upregulation on adult and old PBMCs (nan)
# 	 TLR3 surface upregulation on adult and old PBMCs (nan)
# 	 CTLA4 surface upregulation on adult and old PBMCs (nan)
# 	 PDL2 surface upregulation on adult and old PBMCs (nan)
# 	 CD40 surface upregulation on adult and old PBMCs (nan)
# 	 Dendritic Cells frequency in adult and old PBMCs (nan)
# 	 Allogeneic mixed lymphocyte reaction (nan)
# 	 FCM_JI2014Wertheimer (nan)
# 	 SLVP015_2012_phos (nan)
# 	 SLVP021_2012_phos (nan)
# 	 T cell response to Influenza vaccination in aged populations - Vac2014 (nan)
# 	 EXP-09-AA2485: BMH-58-09 TNFa, IFNb timecourse phosphlow (Title: BMH-58-09 TNFa, IFNb timecourse phosphlow; ProjectDate: 04/15/2009; Author: Hartmann, Boris; Project: AVDC; Primary Contact: Hartmann, Boris (boris.hartmann@mssm.edu))
# 	 Cell Phenotype (The fcs files for this experiment are not available.)
# 	 Figure 1.B Activation of the EGFR pathway in bronchial epithelial cells leads to an immunosuppressive lung microenvironment (nan)
# 	 EXP-10-AA1851: cDC (s520) High Resolution STAT3 Response to IL6 or IL10 (Title: cDC (s520) High Resolution STAT3 Response to IL6 or IL10; ProjectDate: 06/02/2010; Author: Braun, David; Project: STAT3 modeling, DC maturation; Related experiments: EXP-10-AA1836, EXP-10-AA1841)
# 	 EXP-10-AA0958: T cell proliferation and Biasing (Title: T cell proliferation and Biasing; ProjectDate: 08/06/2010; Author: Seto, Jeremy; Project: DC maturation, DC response to NDV)
# 	 EXP-09-AA1823: cDC Treatment with IL6 and TGFb (s339) (Title: cDC Treatment with IL6 and TGFb (s339); ProjectDate: 09/04/2009; Author: Braun, David; Project: DC maturation, STAT3 modeling; Related experiments: EXP-09-AA0257, EXP-09-AA1824)
# 	 Vac2013 T cell Panel3 (nan)
# 	 Vac2013 T cell Panel2 (nan)
# 	 Vac2013 T cell Panel1 (nan)
# 	 Flow cytometry Human Immune Signature of latent Mycobacterium Tuberculosis infection (nan)
# 	 FCM for ASCs (nan)
# 	 B cell Panel 1 2013 (nan)
# 	 EXP-09-AA2451: BMH-31-08 AVDC with PRA and dNS1 (Title: BMH-31-08 AVDC with PRA and dNS1; ProjectDate: 02/25/2009; Author: Hartmann, Boris; Project: AVDC; Related experiments: EXP-08-AA0726 [AVBG-19-08 Effect of PR8 and PR8deltaNS1 on AVDCs generation])
# 	 FCM for B cells (nan)
# 	 EXP-10-AA1843: cDC (s475) Dose Response to IL-6 and IL-10 (Triplicate) (Title: cDC (s475) Dose Response to IL-6 and IL-10 (Triplicate); ProjectDate: 03/23/2010; Author: Braun, David; Project: STAT3 modeling, DC maturation; Related experiments: EXP-10-AA1836, EXP-10-AA1841)
# 	 11092012TAM_001 (Experiments were created based on flow cytometer directory name)
# 	 11092012baseline (Experiments were created based on flow cytometer directory name)
# 	 10202012baseline_001 (Experiments were created based on flow cytometer directory name)
# 	 10202012TAM (Experiments were created based on flow cytometer directory name)
# 	 10202012baseline (Experiments were created based on flow cytometer directory name)
# 	 10192012TAM (Experiments were created based on flow cytometer directory name)
# 	 10192012baseline (Experiments were created based on flow cytometer directory name)
# 	 10162012TAM (Experiments were created based on flow cytometer directory name)
# 	 10162012baseline (Experiments were created based on flow cytometer directory name)
# 	 10112012TAM (Experiments were created based on flow cytometer directory name)
# 	 10112012baseline (Experiments were created based on flow cytometer directory name)
# 	 10102012TAM (Experiments were created based on flow cytometer directory name)
# 	 10102012baseline (Experiments were created based on flow cytometer directory name)
# 	 EXP-10-AA1163: Determining the Signaling and Transcription Factor Activation Profiles in DCs following TLR Stimulation (Title: Determining the Signaling and Transcription Factor Activation Profiles in DCs following TLR Stimulation; ProjectDate: 03/04/2010; Author: Gonzalez, Joanna; Project: DC maturation; Primary Contact: Gonzalez, Joanna (joanna.gonzalez@mssm.edu); Related experiments: EXP-10-AA0277 [s-454- repeat exp- Measuring the phosphorylation profiles of kinases, ERK1/2, p38, JNK, TBK1 and Syk in DCs in response to stimuli LPS from S. minnesota, LPS from E.Coli, Pam3 Curdlan and polic.])
# 	 11092012TAM (Experiments were created based on flow cytometer directory name)
# 	 Antigen-Specific Adaptive Immunity to SARS-CoV-2 in Acute COVID-19-CD4 AIM (nan)
# 	 ICS Revision 2 (Intracellular cytokine staining (with IL8-FITC; re-optimized))
# 	 EXP-09-AA3515: BMH-98-09 IFN TNF IL1a and IL1b in all combinations (Title: BMH-98-09 IFN TNF IL1a and IL1b in all combinations; ProjectDate: 09/16/2009; Author: Hartmann, Boris; Project: AVDC; Primary Contact: Hartmann, Boris (boris.hartmann@mssm.edu))
# 	 Flow Cytometry Myeloid CD15 (nan)
# 	 Flow Cytometry Myeloid CD42b (nan)
# 	 Flow Cytometry Myeloid PDL1 (nan)
# 	 Flow Cytometry Myeloid CD11c (nan)
# 	 Flow Cytometry Tsurf v1 (nan)
# 	 Flow Cytometry TIC v3 (nan)
# 	 Flow Cytometry TIC chemok (nan)
# 	 Flow Cytometry TIC CD14 (nan)
# 	 T and B cell responses to SARS-CoV-2 coronavirus-ICS (nan)
# 	 Supplementary.figure.2 (nan)
# 	 Figure 4 (nan)
# 	 Figure 3 (nan)
# 	 Figure 2 (nan)
# 	 Fig1A-F (nan)
# 	 Fig 9 (A,C,D) (nan)
# 	 Fig 9B (nan)
# 	 Fig 7D (nan)
# 	 Fig 7C (nan)
# 	 Fig 7B (nan)
# 	 Fig 6G (nan)
# 	 Fig 6F (nan)
# 	 Fig 6E (nan)
# 	 Fig 6D (nan)
# 	 Fig 6C (nan)
# 	 Fig 6B (nan)
# 	 151022_TRM (Examination of CD8 T integrin profiles at day 90 post-infection from WT C57BL/6 mice infected with HKx31 influenza A virus)
# 	 170824_D14_CD103 (Examination of CD8 T integrin profiles at day 14 post-infection from HKx31 ovaI infected WT mice with adoptively transferred WT or integrin KO OT-1 GFP B-actin C57BL/6J background cells)
# 	 180612_TRM_aCD103 (Examination of the presence of CD8 T cells and antibody bound to CD103 after in vivo blocking treatment)
# 	 170926_D14_CD49a (Examination of CD8 T integrin profiles at day 14 post-infection from HKx31 ovaI infected WT mice with adoptively transferred WT or integrin KO OT-1 GFP B-actin C57BL/6J background cells)
# 	 Baseline, Batch F , T panel (nan)
# 	 Baseline, Batch F , B panel (nan)
# 	 Susceptibility   Batch F , B panel (nan)
# 	 Baseline, Batch A , T panel (nan)
# 	 Baseline, Batch A , B panel (nan)
# 	 Susceptibility   Batch A , B panel (nan)
# 	 Baseline, Batch D , T panel (nan)
# 	 Baseline, Batch D , B panel (nan)
# 	 Susceptibility   Batch D , B panel (nan)
# 	 Baseline, Batch E , B panel (nan)
# 	 Susceptibility   Batch E , B panel (nan)
# 	 Baseline, Batch E , T panel (nan)
# 	 Fig 6A (nan)
# 	 Baseline, Batch C , T panel (nan)
# 	 Susceptibility   Batch C , B panel (nan)
# 	 Baseline, Batch G , T panel (nan)
# 	 Baseline, Batch B , B panel (nan)
# 	 Baseline, Batch B , T panel (nan)
# 	 Susceptibility   Batch B , B panel (nan)
# 	 191211_OT-I_TRM (Examination of CD8 T integrin profiles at day 90 post-infection from HKx31 ovaI infected WT mice with adoptively transferred OT-1 GFP B-actin C57BL/6J background cells)
# 	 191210_D14_CD103Ig (Examination of the presence of anti-CD103 antibody bound to CD8 T cells through secondary antibody binding)
# 	 191126_D14OTI (Examination of CD8 T integrin profiles at day 14 post-infection from HKx31 ovaI infected WT mice with adoptively transferred OT-1 GFP B-actin C57BL/6J background cells)
# 	 191203_D14 (Examination of CD8 T integrin profiles at day 14 post-infection from HKx31 ovaI infected WT mice with adoptively transferred WT or integrin KO OT-1 GFP B-actin C57BL/6J background cells)
# 	 191105_D14 (Examination of CD8 T integrin profiles at day 14 post-infection from WT C57BL/6 mice infected with HKx31 influenza A virus)
# 	 181031_D14OTI (Examination of CD8 T integrin profiles at day 14 post-infection from HKx31 ovaI infected WT mice with adoptively transferred OT-1 GFP B-actin C57BL/6J background cells)
# 	 180723_TRM_OTI (Examination of CD8 T integrin profiles at day 90 post-infection from HKx31 ovaI infected WT mice with adoptively transferred OT-1 GFP B-actin C57BL/6J background cells)
# 	 Baseline, Batch C , B panel (nan)
# 	 6 hours RV-A16 Stimulation Flow Panel (nan)
# 	 191211_TRM (Examination of CD8 T integrin profiles at day 90 post-infection from WT C57BL/6 mice infected with HKx31 influenza A virus)
# 	 Tissue determinants of human NK cells - flow (nan)
# 	 T phenotyping (T cell phenotyping)
# 	 T ICS (T cell intracellular cytokine)
# 	 NK phenotyping (Natural killer cell phenotyping/ intracellular cytokine)
# 	 DC_Mono phenotyping (dendritic and monocyte phenotyping/intracellular cytokine)
# 	 B mem phenotyping (B memory cell phenotyping)
# 	 Human Immune Signature of Zika virus infection-FACS (nan)
# 	 T_FLOW (nan)
# 	 Experiment - flostdy (Assay the absolute number of the following cell types as enumerated NK cells (CD56 hi and CD56 low), T cells (CD4 and CD8), CD14 positive monocytes, dendritic cells (conventional and plasmacytoid), B cells.)
# 	 Meni2010 FACS (nan)
# 	 APC_FLOW (nan)
# 	 NK_FLOW_protocol (nan)
# 	 Assessment of the Antigen Presenting Capabilities of Subjects Antigen Presenting Cells as Determined by Cell Surface Expression of HLA Class I and Class II (A flow cytometry-based assay of HLA class I and class II cell surface expression by CD4+ and CD8+ cells from a mixture of PBMC restimulated in vitro with inactivated vaccinia virus)
# 	 ICS Revision 1 (Intracellular cytokine staining (with IL8-PE))
# 	 ICS (Intracellular cytokine staining)
# 	 TPHE Revision 2 (T-cell phenotyping (with CD31; with human-specific KLRG1))
# 	 TPHE Revision 1 (T-cell phenotyping (with CD31))
# 	 TPHE (T-cell phenotyping)
# 	 Experiment - 082808 Splenocyte ICC (nan)
# 	 Flow Cytometry (MIFlowCyt for Immune Phenotyping)
# 	 Dendritic Cell Maturation Dynamics (nan)
# 	 EXP-09-AA2491: BMH-73-09 TNFa IFNb phosphlow 10min for 1 hr , different conc of TNFa (Title: BMH-73-09 TNFa IFNb phosphlow 10min for 1 hr , different conc of TNFa; ProjectDate: 06/05/2009; Author: Hartmann, Boris; Project: AVDC; Primary Contact: Hartmann, Boris (boris.hartmann@mssm.edu))
# 	 EXP-09-AA1145: Measuring IFN Receptor Internalization and SOCS1/3 Induction after IFN Treatment in DCs (Title: Measuring IFN Receptor Internalization and SOCS1/3 Induction after IFN Treatment in DCs; ProjectDate: 10/19/2009; Author: Gonzalez, Joanna; Project: DC maturation; Related experiments: EXP-09-AA1129, EXP-09-AA1130)
# 	 RA-Arthroplasty-Flow_Cytometry_primary ('Data Quality Check - AMP Synovium Phase 1 CyTOF.immport.xlsx', a quality control reports for samples, is available as a protocol.)
# 	 EXP-10-AA1168: Measuring the Activation Kinetics of Signaling Pathways and the Translocation of Transcription Factors in DCs treated with CD40L - Attempt #2 (Title: Measuring the Activation Kinetics of Signaling Pathways and the Translocation of Transcription Factors in DCs treated with CD40L - Attempt #2; ProjectDate: 04/01/2010; Author: Gonzalez, Joanna; Project: DC maturation; Primary Contact: Gonzalez, Joanna (joanna.gonzalez@mssm.edu))
# 	 24 hours RV-A16 Stimulation Flow Panel (nan)
# 	 Treg (T regulatory and transcription factors for Th1,2 and 17 T cell phenotyping)
# 	 Flow Cytometry analysis (nan)
# 	 Examine age-related differences in TLR induced cytokine production (Examine cell surface expression of TLRs1-9 by FACS staining and the costimulatory molecules, CD80 and CD86)
# 	 Examine age-related differences in TLR induced cytokine production (Examine age-related differences in surface TLR expression in dendritic cells by FACS.)
# 	 4-color double expressor panel (Hamad et al., 2019) (Panel to assess BCR/TCR double expressor frequency in frozen PBMCs based on the original 4-color flow cytometry panel from Hamad et al., 2019 with the addition of live/dead staining.)
# 	 Flow cytometry of ex vivo stimulated PBMCs (nan)
# 	 HLA-DQ protein level validations on T cells panel 2 (nan)
# 	 HLA-DQ protein level validations on T cells panel 1 (nan)
# 	 HLA-DQ protein level validations on memory B cells panel 2 (nan)
# 	 HLA-DQ protein level validations on memory B cells panel 1 (nan)
# 	 Flow cytometry of PBMCs (nan)
# 	 Cross-reactive SARS-CoV-2 T cell epitopes in unexposed humans-CD4 AIM (nan)
# 	 COVID19_HAARVI_T_cells HAARVI_ICS_B1 (nan)
# 	 COVID19_HAARVI_T_cells HAARVI_ICS_B2 (nan)
# 	 COVID19_HAARVI_T_cells HAARVI_ICS_B3 (nan)
# 	 COVID19_HAARVI_T_cells HAARVI_Surface_Markers_B1 (nan)
# 	 191204_D14 (Examination of CD8 T integrin profiles at day 14 post-infection from WT C57BL/6 mice infected with HKx31 influenza A virus)
# 	 COVID19_HAARVI_T_cells HAARVI_Surface_Markers_B2 (nan)
# 	 T and B cell responses to SARS-CoV-2 coronavirus-AIM CD4 and CD8 (nan)
# 	 Resister TB Antigens ICS (nan)
# 	 Resister NonTB Antigens ICS (nan)
# 	 Vax002_Tfh_FACS_exp (nan)
# 	 Innate and activated B cells immunohenotyping by flow (nan)
# 	 Flow Cytometry Analysis of Human B cell subsets (Delineate the developmental subsets of human B cells based on the expression profiles of 10 different phenotypic markers as analyzed by FACS)
# 	 Direct ex vivo FITC-Dextran Uptake and Multichromatic Phenotyping on Dendritic Cell subsets from Peripheral Blood Mononuclear Cells (PBDC) (Immunofluoresence staining and phagocytosis of ex vivo PBDC)
# 	 Direct ex vivo FITC-Dextran Uptake and Multichromatic Phenotyping on Dendritic Cell subsets from Peripheral Blood Mononuclear Cells (PBDC) (Immunofluoresence staining and phagocytosis of ex vivo PBDC)
# 	 Lymph node reservoirs for long-lived memory T cells (nan)
# 	 22-color double expressor panel (UPenn) (22-color flow cytometry panel for the in-depth assessment of double expressor frequency and phenotype.)
# 	 11-color double expressor panel (UF) (11-color fow cytometry panel for the in-depth assessment of double expressor cell frequency and phenotype.)
# 	 Examine age-related and immunosuppression-related differences in surface TLR expression in PBMCs by FACS (Examine cell surface expression of TLR1, TLR2, TLR4, TLR5 and TLR6 by FACS staining.  Monocytes will be gated for CD4 dim population)
# 	 COVID19_HAARVI_T_cells HAARVI_Surface_Markers_B3 (nan)
# 	 CD4 T cell Kinetics Following TIV Seasonal Vaccination (To measure the kinetics of cytokine expression by T cells responding to seasonal Influenza vaccination.)
# 	 09-H1-0239 flow cytometry B2 (CHI flow team (Phil McCoy and Angelique Biancotto) indicated that due to the 15-color nature of the data and complex compensation required to properly work with the raw fcs data, they preferred to release the processed files, which is already on our ftp site as Foo had previously indicated.)
# 	 Kinetics of B Cell Subsets Following TIV Seasonal Vaccination (To study activation and maturation of human B cell subpopulations after Influenza vaccination to build and validate immune response model using flow cytometry.)
# 	 Flow Cytometry (nan)
# 	 EXP-09-AA1232: BMH-64-09 TNFa IFNb phosphlow 10min for 1 hr , different conc of TNFa (Title: BMH-64-09 TNFa IFNb phosphlow 10min for 1 hr , different conc of TNFa; ProjectDate: 05/13/2009; Author: Marjanovic, Nada; Project: AVDC; Primary Contact: Hartmann, Boris (boris.hartmann@mssm.edu))
# 	 intracellular_P62_Flow (nan)
# 	 mitochondrial_ROS_Flow (nan)
# 	 HP42 Flow (This file is split up into Spleen and Gastric LPL data, then subdivided into the 4 panels run.)
# 	 EXP-08-AA0591: BMH-97-08 FLOW (Title: BMH-97-08 FLOW; ProjectDate: 10/24/2008; Author: Hartmann, Boris; Project: AVDC; Primary Contact: Hartmann, Boris (boris.hartmann@mssm.edu))
# 	 EXP-08-AA1222: NM101 STAT1 phosphorylation  -IFNa and b (Title: NM101 STAT1 phosphorylation -IFNa and b; ProjectDate: 11/10/2008; Author: Marjanovic, Nada; Project: DC response to INFa/b; Primary Contact: Hartmann, Boris (boris.hartmann@mssm.edu))
# 	 Kinetics of B Cell Subsets Following Influenza Seasonal Vaccination (To study activation and maturation of human B cell subpopulations after Influenza vaccination to build and validate immune response model using flow cytometry.)
# 	 Flow cytometry (nan)
# 	 VRC304 ICS 2 (This experiment in conjunction with VRC304 ICS 1, EXP13572, contains the VRC304 flow cytometry analyzed results. This experiment does not include the raw data FCS files for its subset of experiment samples because they are not available. VRC304 ICS 1 does include the FCS files for its subset of experiment samples.)
# 	 Figure-S1 FCM (Foxp3DTR mice (2 mice/group) were immunized with peptide/IFA emulsions containing OVA peptide. Mice were administered DT at days 3 and 4 post immunization. At day 10 post immunization, CD4 T cells from pooled LNs were assessed for Foxp3DTR-GFP expression.)
# 	 Figure-5 FCM (Tregs were flowsorted from pooled popliteal LNs of Foxp3GFP mice (2 mice/group) that were immunized 6 days prior. Tregs were co-cultured with irradiated APCs and CFSE-labeled target T cells (Thy1.1) in the presence of 1mg/ml anti-CD3 for 72 hrs. The change in the frequency of Thy1.1+ responder CD4 T cells that have proliferated in cocultures with Tregs sorted from the OVA +Competitors group is assessed compared to cocultures with Tregs sorted from the OVA alone group.)
# 	 Figure-4 FCM (Foxp3GFP mice were immunized with peptide/IFA emulsions containing OVA peptide alone or in combination with dominant MalE and Myo peptides (+Competitors). Frequency of Foxp3+ CD4 T cells in unfractionated popliteal LNs from a representative mouse of two is shown for each group over time.)
# 	 Figure-3 FCM (BALB/c mice (4-5 mice/group) were immunized with CFSE-labeled DC loaded with no antigen, OVA peptide alone, or OVA peptide in combination with dominant MalE and Myo peptides. Expression of ICAM-1 and I-Ad on gated CFSE+ cells in pooled dLNs and absolute number of CFSE bright cells per LN are presented.)
# 	 Leukocyte Subset Frequency Determination (Comprehensive baseline characterization of young and older individuals blood using high-resolution immune phenotyping for 15 immune cell subsets)
# 	 ModCD4-07 (RAG2-/- recipients were adoptively reconstituted with naive CD4+ T cells extracted from wild type mice. After disease activity index was detected, spleen, colon and mesenteric lymph nodes were collected for Th17 detection (baseline). At that point, a treatment was started with either Pioglitazone (70mg/Kg) or PBS. After 14 days, spleen, colon, and MLNs were collected for immunophenotyping.)
# 	 ModCD4-01 (SCID recipients were adoptively reconstituted with naive CD4+ T cells extracted from wild type or CD4-specific PPARg knockout mice. After disease activity index was detected, spleen, colon and mesenteric lympho nodes were collected for immunophenotyping.)
# 	 Phosphorylation of intracellular proteins by pFlow (Measurement of antibody responses to TIV and signaling responses to cytokines in various cell subsets from peripheral blood using antibodies to phosphorylated STAT proteins)
# 	 EXP-09-AA3534: BMH-117-09 Triple comb TNFa IFNb IL1b dilutions in triplicates (Title: BMH-117-09 Triple comb TNFa IFNb IL1b dilutions in triplicates; ProjectDate: 11/17/2009; Author: Hartmann, Boris; Project: AVDC; Primary Contact: Hartmann, Boris (boris.hartmann@mssm.edu))
# 	 B-Cell Flow Panel (nan)
# 	 EXP-09-AA1112: Activation of NF-kB in Response to NDV in DCs - Attempt #3 (Title: Activation of NF-kB in Response to NDV in DCs - Attempt #3; ProjectDate: 01/12/2009; Author: Gonzalez, Joanna; Project: DC maturation; Related experiments: EXP-08-AA1108, EXP-08-AA1109)
# 	 OMRF Flow Cytometry, Proliferation (nan)
# 	 OMRF Flow Cytometry, Phospho Flow (nan)
# 	 OMRF Flow Cytometry, Proliferation (nan)
# 	 OMRF Flow Cytometry, Phospho Flow (nan)
# 	 OMRF Flow Cytometry, Proliferation (nan)
# 	 OMRF Flow Cytometry, Phospho Flow (nan)
# 	 Immune Phenotyping (nan)
# 	 SWHP03_EXP01 (Characterization of immune cell subsets in blood over time and in spleen, GLN as well as gastric lamina propria two months post-infection)
# 	 Whole blood Flow cytomtery (This is a flow cytometric assay on whole blood collected from infants on day 0, 1, 3 or 7 of life. It provides data on immune cell composition during the first few days)
# 	 FCM analysis of IgA, IgG and IgM plasmablasts from 2008 TIV and LAIV (Frequency of influenza-specific plasmablasts)
# 	 NCH_2011_FLOW_Bcell (nan)
# 	 EXP-09-AA0923 (ProjectDate: 05/14/2009; Author: Seto, Jeremy; Project: STAT3 modeling, DC maturation)
# 	 EXP-08-AA1109: Activation and Translocation of NF-kB in Response to NDV in DCs - Attempt #2 (Title: Activation and Translocation of NF-kB in Response to NDV in DCs - Attempt #2; ProjectDate: 12/22/2008; Author: Gonzalez, Joanna; Project: DC maturation; Related experiments: EXP-08-AA1108 [Activation and Translocation of NFkB in Response to NDV in DCs])
# 	 EXP-09-AA0924: STAT3 and NFkB translocation from IL6 and IL10 (multispectral imaging flow) S281 (Title: STAT3 and NFkB translocation from IL6 and IL10 (multispectral imaging flow) S281; ProjectDate: 05/14/2009; Author: Seto, Jeremy; Project: STAT3 modeling, DC maturation; Related experiments: EXP-09-AA0922 [STAT3 and NFkB translocation from IL6 and IL10 (multispectral imaging flow)])
# 	 EXP-09-AA0918: TLR Synergism (Title: TLR Synergism; ProjectDate: 01/08/2009; Author: Seto, Jeremy; Project: DC maturation; Related experiments: EXP-08-AA0904, EXP-08-AA0905, EXP-08-AA0206, EXP-08-AA0903, EXP-09-AA0918)
# 	 EXP-10-AA1829: cDC (S440) Response to Treatment with IL-6 or IL-10 with or without Orthovanadate (Title: cDC (S440) Response to Treatment with IL-6 or IL-10 with or without Orthovanadate; ProjectDate: 02/02/2010; Author: Braun, David; Project: STAT3 modeling, DC maturation; Related experiments: EXP-09-AA1813, EXP-09-AA0917, EXP-09-AA0922, EXP-09-AA0924, EXP-09-AA1815, EXP-09-AA1815)
# 	 SDY144-FlowCytometry_Bcell (nan)
# 	 EXP-08-AA1107: Activation and Translocation of NF-kB in Response to NDV in KG1 (Title: Activation and Translocation of NF-kB in Response to NDV in KG1; ProjectDate: 12/18/2008; Author: Gonzalez, Joanna; Project: DC maturation)
# 	 HP_IL21 CFU count (CFU quantification with plate dilutions)
# 	 HP_IL21 FACS (FACS)
# 	 EXP-10-AA1169: Measuring the Activation Kinetics of Signaling Pathways in DCs treated with C3a and C5a - Attempt #2 (Title: Measuring the Activation Kinetics of Signaling Pathways in DCs treated with C3a and C5a - Attempt #2; ProjectDate: 04/01/2010; Author: Gonzalez, Joanna; Project: DC maturation; Primary Contact: Gonzalez, Joanna (joanna.gonzalez@mssm.edu))
# 	 AIRFV Flow Cytometry (nan)
# 	 EXP-08-AA0579: BMH-82-08 FLOW (Title: BMH-82-08 FLOW; ProjectDate: 10/07/2008; Author: Hartmann, Boris; Project: AVDC; Primary Contact: Hartmann, Boris (boris.hartmann@mssm.edu))
# 	 OMRF Flow Cytometry, Proliferation (nan)
# 	 Engerix Flowcytometry (nan)
# 	 EXP-09-AA2444: BMH-26-09 TNFa Rantes ceckup on protein level (Title: BMH-26-09 TNFa Rantes ceckup on protein level; ProjectDate: 02/11/2009; Author: Hartmann, Boris; Project: AVDC; Primary Contact: Hartmann, Boris (boris.hartmann@mssm.edu))
# 	 EXP-09-AA2486: BMH-59-09 TNFa IFNb phosphlow 2.5 min for 1 hr (Title: BMH-59-09 TNFa IFNb phosphlow 2.5 min for 1 hr; ProjectDate: 04/20/2009; Author: Hartmann, Boris; Project: AVDC; Primary Contact: Hartmann, Boris (boris.hartmann@mssm.edu))
# 	 AIRFV Flow Cytometry (nan)
# 	 AIRFV Flow Cytometry (nan)
# 	 AIRFV Flow Cytometry (nan)
# 	 EXP-09-AA1122: Concentration Dependence of NFkB and STAT3 Activation by sCD40L in DC and KG1 Cells - Attempt #3 (Title: Concentration Dependence of NFkB and STAT3 Activation by sCD40L in DC and KG1 Cells - Attempt #3; ProjectDate: 02/23/2009; Author: Gonzalez, Joanna; Project: DC maturation; Related experiments: EXP-09-AA1117, EXP-09-AA1119, EXP-09-AA1120)
# 	 VRC304 ICS 1 (This experiment in conjunction with VRC304 ICS 2, EXP13429, contains the VRC304 flow cytometry analyzed results. This experiment includes the raw data FCS files for its subset of experiment samples. VRC304 ICS 2 does not include the FCS files for its subset of experiment samples because they are not available.)
# 	 Multifunctional ICS panel (nan)
# 	 Flow Cytometry for ASCs (nan)
# 	 Basophil Flow Cytometry Studies (Allergen desensitization has been shown to induce basophil hyporesponsiveness to allergen-induced degranulation, however, chronic exposure to allergens is also associated with constitutively activated basophils. We will use flow cytometry-based assessment of basophil activation/ degranulation longitudinally with and without in vitro stimulation to track changes induced by OIT and their relationship to clinical desensitization and tolerance.)
# 	 Immune memory to COVID-19 vaccines - Tcell AIM (nan)
# 	 Immune memory to COVID-19 vaccines - Tcell ICS (nan)
# 	 EXP-10-AA1849: cDC STAT3 and Gene Response to IL6 or IL10 (S511) (Title: cDC STAT3 and Gene Response to IL6 or IL10 (S511); ProjectDate: 05/18/2010; Author: Braun, David; Project: STAT3 modeling, DC maturation; Related experiments: EXP-10-AA1836, EXP-10-AA1841)
# 	 EXP-10-AA1159: Activation Kinetics of Signaling Proteins in DCs by Different TLR Agonists (Title: Activation Kinetics of Signaling Proteins in DCs by Different TLR Agonists; ProjectDate: 02/16/2010; Author: Gonzalez, Joanna; Project: DC maturation)
# 	 Flow cytometry surface phenotyping, day 0 (Flow cytometry surface phenotyping, day 0)
# 	 OMRF Flow Cytometry, Phospho Flow (nan)
# 	 OMRF Flow Cytometry, Phospho Flow (nan)
# 	 Experiment - Determining the Signaling Profiles in DCs following TLR Stimulation (DCs were treated with different TLR agonists and the activation kinetics of signaling proteins were measured using flow cytometry)
# 	 Testing the phosphorylation profiles of ERK and p38 in DCs in response to LPS and Curdlan stimuli ( In this experiment 2 different stimuli were used to activated DCs  LPS and Curdlan.   A time course experiment was conducted for 2 hr to measure the phosphorylation profiles of MAPKs, ERK1/2 and p38.   )
# 	 Testing the phosphorylation profiles of ERK and p38 in DCs in response to LPS and Curdlan stimuli ( In this experiment 2 different stimuli were used to activated DCs  LPS and Curdlan.   A time course experiment was conducted for 2 hr to measure the phosphorylation profiles of MAPKs, ERK1/2 and p38.   )
# 	 Experiment - TruCount (FCM experiment to measure frequency and phenotypic profile of B and T cell subsets in renal transplant patients and healthy controls)
# 	 Experiment - Tetra (FCM experiment to measure frequency and phenotypic profile of B and T cell subsets in renal transplant patients and healthy controls)
# 	 Flow Cytometry Analysis of Human B cell subsets (Delineate the developmental subsets of human B cells based on the expression profiles of 10 different phenotypic markers as analyzed by FACS)
# 	 B cell Enumeration (Whole blood flow cytometry used to evaluate the development, frequencies, and activation status of B and T cells, natural killer cells, and myeloid and dendritic cells)
# 	 Apheresis Sort (nan)
# 	 Apheresis Sort (nan)
# 	 Immune Modeling Study of Human B and T Cell Kinetics Following Influenza Seasonal Vaccination (Flow cytometry analysis of PBMCs pre and post influenza vaccination.)
# 	 EXP-09-AA1133: Maturation Marker Upregulation Induced by NDV (Title: Maturation Marker Upregulation Induced by NDV; ProjectDate: 07/07/2009; Author: Gonzalez, Joanna; Project: DC maturation)
# 	 T Cell Phenotyping (T cell Subsets (PBMCs are stained for TCR alpha/beta, TCR gamma/delta, CD4 and CD8 T cells),  Memory Subsets ((PBMCs are stained for CD4, CD8, CD45RA, and CD45RO), Activated Subsets ((PBMCs are stained for CD4, CD8, HLA DR, and CD25)  )
# 	 EXP-09-AA2417: BMH-06-09 TNFa Rantes ceckup on protein level (Title: BMH-06-09 TNFa Rantes ceckup on protein level; ProjectDate: 01/12/2009; Author: Hartmann, Boris; Project: AVDC; Primary Contact: Hartmann, Boris (boris.hartmann@mssm.edu))
# 	 EXP-10-AA1158: Measuring the Effect of Inhibiting Different Signaling Molecules on the Cytokine Production and Maturation Marker Upregulation by DCs after PR8 Infection (Title: Measuring the Effect of Inhibiting Different Signaling Molecules on the Cytokine Production and Maturation Marker Upregulation by DCs after PR8 Infection; ProjectDate: 02/04/2010; Author: Gonzalez, Joanna; Project: DC maturation)
# 	 EXP-09-AA1229 (ProjectDate: 04/27/2009; Author: Marjanovic, Nada; Project: AVDC; Primary Contact: Hartmann, Boris (boris.hartmann@mssm.edu))
# 	 Experiment - 6hr ICC adult and neonate FlowCyt Expt (nan)
# 	 Experiment - ASC Stain (FCM experiment to measure frequency and phenotypic profile of B and T cell subsets in renal transplant patients and healthy controls)
# 	 FCM analysis of IgA, IgG and IgM plasmablasts from 2007 TIV and LAIV (Freq of influenza-specific plasmablasts)
# 	 CD11b upregulation flow cytometry assay for the ADVN Registry neutrophil substudy (The upregulation of CD11b on neutrophils is determined by the change(Net and Fold) in MFI (Median, Mean, and Geometric Mean are evaluated) from the baseline expression of CD11b to the increasing concentrations of the chemoattractant CXCL8 (IL-8). Two multichromaticpanels are used for the evaluation with both containing CD11b. CD11b from Abcam recognizes the alpha subunit of the CD11b/CD18 (Mac-1) complex. The CD11b from eBioscience reacts with anactivation specific epitope of this same integrin complex.)
# 	 Inflammatory Dendritic Epidermal Cells (IDEC) Flow Cytometry (Assay IDEC with markers 22E7 , B7H1 , B7H2 , CD111 , CD112 , CD155 , CD1a , CD209 , CD23 , CD40 , CD44 , CD62L , CD74 , CD80 , CD83 , CD86 , CLA , CXCR2 , HSV1gB , IgG1 , IgG2a , IgG2b , MHC-1 , MHC-2 , MHC-II , TLR2 , TLR4)
# 	 Langerhans cells (LC) Flow Cytometry (Assay Langerhans cells with markers 22E7 , CD111 , CD112 , CD14 , CD14PE , CD155 , CD44 , CD74 , CXCR2 , HSV1gB , IDO , IgG1 , IgG2a , IgG2b , IgG2b , MHCII)
# 	 Experiment - 201010060002 (T cell phenotyping)
# 	 Experiment - TruCount (nan)
# 	 Experiment - Phenotypic FCM (FCM experiment to study effects of vaccination on renal allograft in rhesus macaques)
# 	 Experiment - Stim and ICCS (FCM experiment to study effects of vaccination on renal allograft in rhesus macaques)
# 	 Monocyte Flow Cytometry (Assay Monocytes with markers 22E7 , CD111 , CD112 , CD14 , CD14PE , CD155 , CD44 , CD74 , CXCR2 , HSV1gB , IDO , IgG1 , IgG2a , IgG2b , IgG2b , MHCII)
# 	 FCM Analysis of T Cell Responses in AD (Flow cytometry analysis of T cell responses following varicella vaccination in subjects with atopic dermatitis (AD) compared to nonatopic controls.)
# 	 Cdiff09 Flow cytometry (This file is divided into 4 worksheets. The first one contains the results for CD4+ T cells producing RORgt in the spleen. The second contains the results for CD4+ T cells producing RORgt in the colonic lamina propria. The third one the results for CD4+ T cells producing IL-17 in the spleen. Finally, the fourth one contains the results for CD4+ T cells producing IL-17 in the colonic lamina propria.)
# 	 DC Responses to Different Concentrations of Soluble CD40L (DCs were treated with different concentrations of soluble, recombinant CD40L and their activation kinetics of STAT3, MAPKs, and other signaling proteins were measured using flow cytometry)
# 	 FCM assessment of CD8+ T cell immunity to 2009 pandemic and seasonal H1N1 influenza viruses (Flow cytometry was used to measure the expression of IL2, IFN gamma and TNF alpha in CD8+ peripheral blood mononuclear cells isolated from healthy naive donors following stimulation with whole novel and seasonal influenza viruses. Influenza Strains Used: A/New Caledonia/20/99(H1N1), A/California/04/2009(H1N1), A/Aichi/2/68(X31 recomb))
# 	 cDC Respone to Different Doses of IL-6 or IL-10 (Cells were treated with IL6 or IL10 over a two-hour time peiod. STAT3 phosphorylation was measured by flow cytometry)
# 	 OMRF Flow Cytometry, Proliferation (nan)
# 	 EXP-09-AA1231: BMH-63-09 TNFa IFNb phosphlow 10min for 1 hr , different conc of TNFa (Title: BMH-63-09 TNFa IFNb phosphlow 10min for 1 hr , different conc of TNFa; ProjectDate: 05/04/2009; Author: Marjanovic, Nada; Project: AVDC; Primary Contact: Hartmann, Boris (boris.hartmann@mssm.edu))
# 	 Flow Cytometry (nan)
# 	 EXP-09-AA1129: Effect of IFN Treatment on SOCS1 Induction (Title: Effect of IFN Treatment on SOCS1 Induction; ProjectDate: 06/15/2009; Author: Gonzalez, Joanna; Project: DC maturation)
# 	 Assessing the Cell Phenotype During Differentiation of In Vitro Stimulated Human B Cells from the  Peripheral Blood (Flow cytometric characterization of in vitro CpG oligodeoxynucleotide stimulated B cells from the peripheral blood of human subjects using antibodies against CD27 and other cell markers.)
# 	 RPCIFLOW_ITN019AD (The change in T-cell subsets consistent with these hypotheses will be determined by 4 color flow cytometry analyses. Baseline data will be obtained prior to treatment periods and compared for each participant with data acquired at various time points at each treatment, including during ragweed season and after discontinuation of therapy.)
# 	 EXP-10-AA3587: BMH-47-10 MAZ si RNA ijn monocytes TNFIFN mat marker and infectivity (Title: BMH-47-10 MAZ si RNA ijn monocytes TNFIFN mat marker and infectivity; ProjectDate: 07/01/2010; Author: Hartmann, Boris; Project: AVDC; Primary Contact: Hartmann, Boris (boris.hartmann@mssm.edu))
# 	 Vibriocidal Assay in Cholera Vaccine Study (Whole cell killing assay of pathogen using participant serum.)
# 	 Sig8L Binding (nan)
# 	 Lectin Binding (nan)
# 	 Cell Death with DANA (nan)
# 	 Sialidase Pathway (nan)
# 	 MC Viability (nan)
# 	 OMRF Flow Cytometry, Proliferation (nan)
# 	 Figure-7_FCM (The number of Tfh cells, as defined by CD4+ CD44high CXCR5high PD1high cells, enumerated from the cLN, iLN, spleen, or the ear were obtained from unimmunized mice or mice immunized 2, 9, 15, or 26 days prior with MalE-S1 protein. The fraction of Tfh cells present at each site was determined.)
# 	 Figure-1_FCM (Animals were immunized subcutaneously in the pinna of the ear with MalE protein emulsified in IFA. Nine days later, CD4+ cells from draining cervical lymph nodes were analyzed for Tfh cell phenotypic markers. CD4+ CXCR5high BCL6+ cells were analyzed for dual expression of PD1 and ICOS. CD44 expression of CD4+  and CD4+ CXCR5high BCL6+ cells were examined. Expression of ICOS, CD69, BCL6, CD62L, and CCR7 are shown for Tfh, non-Tfh , and CD4+ CD44low populations. Absolute numbers of Tfh  and non-Tfh  cells within the lymph nodes were calculated by multiplying the percent of each cell type by the total number of cells from the harvested lymph nodes.)
# 	 Lectin Binding with DANA (nan)
# 	 2C4 Binding (nan)
# 	 OXSI-2 Inhibition (nan)
# 	 Experiment - Stim and ICCS (FCM experiment to measure frequency and phenotypic profile of B and T cell subsets in renal transplant patients and healthy controls)
# 	 EXP-10-AA1836: cDC (s460) Dose Response to IL-6 and IL-10 (Triplicate) (Title: cDC (s460) Dose Response to IL-6 and IL-10 (Triplicate); ProjectDate: 03/02/2010; Author: Braun, David; Project: STAT3 modeling, DC maturation; Related experiments: EXP-09-AA1813, EXP-09-AA0917, EXP-09-AA0922, EXP-09-AA0924, EXP-09-AA1815, EXP-09-AA1815, EXP-10-AA1829)
# 	 EXP-08-AA0552: BMH-68-08 Timecourse (Title: BMH-68-08 Timecourse; ProjectDate: 07/31/2008; Author: Hartmann, Boris; Project: AVDC)
# 	 Experiment - Phenotypic FCM (FCM experiment to measure frequency and phenotypic profile of B and T cell subsets in renal transplant patients and healthy controls)
# 	 THP1 Response to IL6 or IL10 Treament (THP1 Cells were treated with IL6 or IL10 over a two-hour time peiod. STAT3 phosphorylation was measured by flow cytometry)
# 	 Tissue cell FCM (To identify different immune cell phenotypes within cells from gastric lymph nodes, splenocytes and lamina propria leucocytes, cells were stained with markers recognizing different surface- and intracellular proteins.)
# 	 Whole Blood FCM (To identify different immune cell phenotypes within porcine whole blood, cells were stained with markers recognizing different surface- and intracellular proteins.)
# 	 PBMC FCM (To identify different immune cell phenotypes within PBMC isolated from porcine peripheral blood, cells were stained with markers recognizing different surface- and intracellular proteins.)
# 	 Induction of maturation Marker after combinatorial TNFa and IFNb treatment (Cells were treated with TNFa, IFNb or a combination of both cytokines in increasing concentrations)
# 	 Cell Death with IL-5 (nan)
# 	 EXP-09-AA0248: Optimisation of dendritic cell nucleofection using amaxa nucleofection shuttle system using SE, SF and monocyte nucleofection buffer. (Title: Optimisation of dendritic cell nucleofection using amaxa nucleofection shuttle system using SE, SF and monocyte nucleofection buffer.; ProjectDate: 05/27/2009; Author: Patil, Sonali; Project: siRNA; Primary Contact: Patil, Sonali (sonali.patil@mssm.edu))
# 	 EXP-08-AA0597: BMH-104-08 STAT-1 phosphorylation a and b up to 115 min (not that great) (Title: BMH-104-08 STAT-1 phosphorylation a and b up to 115 min (not that great); ProjectDate: 11/05/2008; Author: Hartmann, Boris; Project: DC response to INFa/b; Primary Contact: Hartmann, Boris (boris.hartmann@mssm.edu))
# 	 EXP-08-AA1105: Internal Protein Activation in Response to Virus Infection - Attempt #2 (Title: Internal Protein Activation in Response to Virus Infection - Attempt #2; ProjectDate: 09/26/2008; Author: Gonzalez, Joanna; Project: DC maturation)
# 	 Kinetics of immunological memory to SARS-CoV-2 / Bmem (nan)
# 	 Immunophenotyping (Characterization of gastric epithelial cells and IL-21 production by different cell types during Helicobacter pylori infection)
# 	 EXP-09-AA1815: STAT3 Activation Dynamics in Response to IL-6 and IL-10 (Title: STAT3 Activation Dynamics in Response to IL-6 and IL-10; ProjectDate: 05/20/2009; Author: Braun, David; Project: STAT3 modeling, DC maturation; Related experiments: EXP-09-AA1813, EXP-09-AA0917, EXP-09-AA0922, EXP-09-AA0924)
# 	 Immunophenotyping (Characterization of macrophages, dendritic cells, neutrophils and CD4+ T cells in the colonic lamina propria and mesenteric lymph nodes during Clostridium difficile infection)
# ...
# 	 PopGen GWAS Results ( To obtain these genotyping results, please follow the process described <a href='https://immport.niaid.nih.gov/docs/GT_Data_Request_Process.pptx'>here</a>. To download the Genotyping Data Request form, click <a href='https://immport.niaid.nih.gov/docs/GT_Data_Request_Form-v-3.docx'>here</a>.)
#
# Sequencing
# 	 IGH repertoire sequencing (Identification of B cell clones based on IGH sequencing)
# 	 Microbiome taxa (16s microbiome measurement)
# 	 B and T cell V(D)J recombination event sequencing (See VDJServer for details on sequencing analysis https://vdjserver.org/community/531076969703215591-242ac11c-0001-012/metadata)
# 	 MOD_DNAseq_cellfree (Cell free DNA sequencing from maternal and cord blood)
# 	 Next Generation Sequencing (Normalized results created using methods from CQN and edgeR packages; results are based on hg19 Genome Build)
# 	 MODSTAN_5 cell-free DNA sequencing (nan)
# 	 Experiment - Genotyping - Pyrosequencing FCGR2A, FCGR2B, FCGR3A, FCGR3B (Assessment of genetic variations associated with immune responses against Anthrax Vaccine Adsorbed (AVA). Medium throughput genotyping for SNP markers in a relatively few selected candidate genes whose specific forms of duplications or sequence variation resist typing with the BeadArrayTM approach will be performed by Pyrosequencing technology. We have successfully developed and performed numerous SNP assays with Pyrosequencing and have determined several thousand genotypes using this technique.  Genes included in these studies included the classical Fc receptor genes including FCGR2A, FCGR2B, FCGR3A and FCGR3B.  These genes are known to be important in regulating Ab responses, and they are found on chromosome 1 in a region of segmental duplication. Because these genes/SNPs are refractory to the high throughput Illumina iSelect chemistry, Pyrosequencing with nested-PCR based amplification strategy was chosen to ensure gene specific amplification followed by the genotyping reaction on the gene-specific amplicon.)
# 	 454-based sequencing for clonal analysis (Clonal analysis of immune responses following naturally occurring pathogens causing tissue specific immune responses in human using 454 sequencing)
# 	 Abrepertoires Sequencing (Profiling the B cell immunoglobulin repertoire in WNV subjects)
# 	 IGH repertoire sequencing (Identification of B cell clones based on IGH sequencing)
# 	 B cell immune repertoire genomic DNA sequencing (nan)
# 	 AIRFV_RNASEQ (nan)
# 	 RNA-seq Analysis of Human PBMC After LAIV Seasonal Vaccination (Transcriptome analysis of  PBMC revealing gene regulatory network in seasonal influenza vaccinated human subjects.)
# 	 RNA-seq Analysis of B cell Subsets After LAIV Seasonal Vaccination in Human (Transcriptome analysis of  seasonal Influenza vaccine activated, class switched human B cells revealing gene regulatory network.)
# 	 PEseq (nan)
# 	 RNA SEQUENCING (nan)
# 	 RNA Sequencing (nan)
# 	 RNA-seq Analysis of Human PBMC After Seasonal Influenza Vaccination (Transcriptome analysis of  PBMC revealing gene regulatory network in seasonal influenza vaccinated human subjects)
# 	 RNA-seq Analysis of B cell Subsets After Seasonal Influenza Vaccination in Human (Transcriptome analysis of  seasonal Influenza vaccine activated, class switched human B cells revealing gene regulatory network)
# 	 314 1M1PBMC8-Cut-2 330 B (1M1PBMC8-Cut-2)
# 	 HP32_EXP01 (BMDM were isolated from WT and LysMcre PPARg-/- mice. Once differentiated, macrophages were infected with Helicobacter pylori at MOI 10 for 15 min. Cells were harvested at different time-points post-infection (0, 60, 120, 240, 360 and 720 min post-infection) and RNA was extrated for RNAseq purposes.Time series analysis of host response to H. pylori infection to macrophages)
# 	 B cell immune repertoire cDNA sequencing (nan)
# 	 Next Generation Sequencing (Normalized results created using methods from CQN and edgeR packages; results are based on hg19 Genome Build)
# 	 SNP analysis on innate and adaptive immunity genes in Typhoid Vaccine Study (SNP analysis (Sequenom and Illumina) of innate and adaptive immunity genes in the Typhoid Vaccine Study based on selection of SNPs by investigator-define algorithm.  Analyses were performed on participants with adequate, high quality DNA available. To obtain these genotyping results, please follow the process described <a href='https://immport.niaid.nih.gov/docs/GT_Data_Request_Process.pptx'>here</a>. To download the Genotyping Data Request form, click <a href='https://immport.niaid.nih.gov/docs/GT_Data_Request_Form-v-3.docx'>here</a>.)
# 	 SNP analysis on innate and adaptive immunity genes in Typhoid Vaccine Study  (SNP analysis (Sequenom and Illumina) of innate and adaptive immunity genes in the Typhoid Vaccine Study based on selection of SNPs by investigator-define algorithm.  Analyses were performed on 997 participants with adequate, high quality DNA available. To obtain these genotyping results, please follow the process described <a href='https://immport.niaid.nih.gov/docs/GT_Data_Request_Process.pptx'>here</a>. To download the Genotyping Data Request form, click <a href='https://immport.niaid.nih.gov/docs/GT_Data_Request_Form-v-3.docx'>here</a>.)
# 	 IBD-Sepsis Transcriptome mRNA sequence analysis (Transcriptome mRNA sequence analysis of 135 deCode IBD-Sepsis case and control subjects.)
# 	 ATAC-seq (open chromatin profiling with Fast-ATAC protocol ( PMC5042844), hyperactive mutant Tn5 Transposase and sequencing of probed DNA tagments.  50000 cells for a library, and amplified with 9 to 12 cycles of PCR.  Header_of_bed_file(chr,start,end,length,abs_summit,pileup,-log10(pvalue),fold_enrichment,-log10(qvalue)))
# 	 AMPLICON (Library layout: SINGLE, Library selection: PCR AMPLICON)
# 	 Somatic hypermutation rate experiment (nan)
# 	 Shotgun metagenomic sequencing (NCBI SRA SRP141397)
# 	 ChIP-seq (ChIP-seq was performed on 10 million cells using antibodies to H3K27ac, H3K4me1, or H3K4me3. All libraries were pooled to 10nM per sample prior to sequencing. Coordinates are from hg19.)
# 	 IgH repertoire sequencing (Amplicon sequencing targeted to IgH(CDR3, V,D,J))
# 	 TCR repertoire sequencing (Amplicon sequencing targeted to TCR beta chain (CDR3, V,D,J))
#
# Transcription profiling assay
# 	 SCOT GEO (nan)
#
# Transcription profiling by array
# 	 NCH_2013_MICROARRAY (nan)
# 	 Gene expression measurement on 2012 subjects at day 0, Whole Blood (Raw (non-normalized) Affymetrix CEL files are provided, one per Experiment Sample.)
# 	 GSE86332 Gene expression signatures to predict T cell responses to zoster vaccination (nan)
# 	 JDM_2011_Microarray (nan)
# 	 2011-12 TIV Fluzone Influenza Vaccine Response Gene Expression (nan)
# 	 Identification of Temporally Associated Gene Expression Clusters at Cellular and Gene Regulatory Network Level (Intensive sampling experiments based on x31 primary influenza infection murine model for transcriptome analysis.)
# 	 Gene expression measurement on 2010 subjects at day 0, Whole Blood (Raw (non-normalized) Illumina data; mapping between Illumina sample ID and subject is provided under Experiment Sample Name.)
# 	 NCH_2012_Microarray (nan)
# 	 Gene expression microarray on 2012 subjects (affymetrix array)
# 	 JDM_2012_Microarray (nan)
# 	 Illumina microarray Expression PBMC Year3 (PBMC, B and T Cell)
# 	 JDM_ 2013_MICROARRAY (nan)
# 	 NCH_2010_Microarray (nan)
# 	 Gene expression microarray (affymetrix array)
# 	 Whole blood transcript quantification (affymetrix array)
# 	 GSE86332 , Gene expression microarray performed on 2011 flu season subjects, day 0 and day 3 (nan)
# 	 Experiment - Gene Chip Analysis (nan)
# 	 VAX001 Microarray results Pulendran (nan)
# 	 Illumina microarray Expression B and T Cell Year2 (B and T Cell)
# 	 Gene expression measurement on 2008 subjects at day 0, whole blood (Raw (non-normalized) Illumina data; several samples, which had no or poor data, have not been included in this data set; mapping between Illumina sample ID and subjects is provided by the included mapping file.)
# 	 SDY144-Microarray (nan)
# 	 AIRFV Microarray (nan)
# 	 Experiment - Gene Chip Analysis (Microarray experiment to define the transcriptional signatures responses to and control of vaccinia in immunosuppressed Rhesus Macaques)
# 	 Mayo_PopGen_Microarray (Assessment of the cell-mediated immune response to Vaccinia immunization)
# 	 Illumina Gene Expressions microarrays (nan)
# 	 Illumina microarray Expression (nan)
# 	 Gene expression in PBMCs and PBMC cell subsets post vaccination 2007 TIV and LAIV (nan)
# 	 Illumina microarray Expression PBMC Year1 (nan)
# 	 Illumina microarray Expression T and B cell Batch1 (nan)
# 	 llumina microarray Expression T and B cell Batch2 (nan)
# 	 09-H1-0239 Gene Expression (nan)
# 	 Gene expression measurement on 2011 subjects at day 0, Whole Blood (Raw (non-normalized) Affymetrix CEL files, one per Experiment Sample.)
# 	 WNV Illumina microarray Expression Year2 (nan)
# 	 Illumina gene expression measurement on D0 subjects (Raw (non-normalized) Illumina data; mapping between Illumina sample ID and subject is provided under Experiment Sample Name. )
# 	 HCV Illumina microarray Expression (nan)
# 	 Gene Expression (nan)
# 	 Illumina microarray Expression PBMC Year2 (nan)
# 	 Whole Blood Microarray (Comprehensive baseline characterization of young and older individuals blood using whole-genome DNA microarrays)
# 	 Microarray study for combinatorial TNFa and IFNb treatment in human dendritic cells (nan)
# 	 Gene Expression Array (nan)
# 	 Gene expression in PBMCs and PBMC cell subsets post vaccination 2008 TIV and LAIV (Gene expression)
# 	 Experiment - Gene Chip Analysis (Microarray experiment to define the transcriptional signatures after flu vaccination in tacrolimus-based and sirolimus-based immunosuprresive regimen)
# 	 HEPLISAV Microarray (nan)
# 	 GSE181757_Immport (nan)
# 	 Compare whole blood (Tempus tube) to PBMC gene expression for a subset of SDY89 subjects in Engerix Microarray experiment EXP14136 (nan)
# 	 Microarray (nan)
# 	 Characterization of Transcriptomic Response to In Vitro Stimulated Human Memory B Cell Subpopulations (Microarray of in vitro stimulated human B cells)
# 	 DNA microarray (nan)
# 	 Microarray (nan)
# 	 Flu-2009 microarray (nan)
# 	 Microarray Gene Expression (nan)
# 	 Miscroarray (nan)
# 	 Low grade astrocytoma transcriptome profiles (78 olfactory bulb and forebrain samples of various genotypes showed oncogenic driver- and astrocyte location-specific transcriptome profiles)
# 	 high-grade astrocytoma transcripome profiles (43 high-grade astrocytoma samples of various genotypes showed oncogenic driver- and astrocyte location-specific transcriptome profiles)
# 	 Glioblastoma Orthotopic Xenograft Transcriptome (Transcriptome profiles of 39 human glioblastoma tumors as orthotopic xenografts in mice)
# 	 CNA of LGA on T or TPhet GEM mice (CGH microarray analysis was completed for 10 low-grade astrocytoma (LGA) dissected from neurollogically asymptomatic mice at least a year after induction. LGA showed few and infrequent CNA)
# 	 CNA of HGA mice with TR (+/- P) genotype group (CGH microarray analysis was completed for 41 high-grade astrocytoma (HGA) dissected from neurollogically symptomatic mice)
# 	 Epigenetics Gene Expression (nan)
# 	 Illumina microarray Expression Year4 - PBMC (nan)
# 	 Illumina microarray Expression Year5 - PBMC (nan)
# 	 nan (nan)
# 	 Microarray (nan)
# 	 In vivo GSMs for GSE13699 'Immune response to the yellow fever vaccine 17D gene expression' (nan)
# 	 Time series of global gene expression after trivalent influenza vaccination in humans (GSE48024)
# 	 Meni2010 microarray (nan)
# 	 GSE89292 Expression data to study temporal transcriptomic changes of immune responses to the Yellow Fever 17D Vaccine (GSE89292)
# 	 DNA microarray (nan)
# 	 Gene expression in vitro stimulation  analysis (GSE40719)
# 	 Gene expression time course analysis of TB vaccine candidate MVA85A (GSE40719)
# 	 Merck Ad5/HIV vaccine transcript expression time course (GSE22768)
# 	 Gene expression of B cell responses to quadrivalent meningococcal conjugate and plain polysaccharide vaccine (GSE92884)
# 	 DNA microarray (nan)
# 	 Next Generation Sequencing RNA Seq data from UKE Phase I rVSV ZEBOV vaccine clinical trial, from full blood samples on Days 0,1,3,7 (GSE97590)
# 	 GSE13699 GSMs from in vitro system mimicing environment in a lymph node (in vitro system mimicing (VaxDesign Mimic experiment) the environment in a lymph node from purified CD4+ T-cells and autologus DC from 3 different donors, YF17D stimulated and unstimulated control samples were analyzed on day 0,3 and 7 after the start of co culturing of T-Cells and DC)
# 	 Expression data from a malaria vaccine trial (HG-U133A2.0 and U133 Plus 2.0) (GSE18323)
# 	 IFN signature (nan)
# 	 Illumina Gene Expression Array 2014 (nan)
# 	 Illumina Gene Expression Array 2013 (nan)
# 	 GSE89292  Microarray (Systems analysis of protective immune responses to RTS,S malaria vaccination in humans)
# 	 DC_MONO_mDC_INVITRO_VAC_MIC (nan)
# 	 Vaccine Year 2012 Gene Expression Illumina HumanHT-12 (nan)
# 	 JDM_ 2014_MICROARRAY (nan)
# 	 Averaged gene expression analysis data for 4hr untreated control cell cultures of increase and prolonged absence subjects vs. control RNA (Averaged gene expression analysis data for 4hr untreated control cell cultures of increase and prolonged absence subjects vs. control RNA)
# 	 Averaged gene expression analysis data for 4hr untreated control cell cultures of Lack of response subjects vs. control RNA (Averaged gene expression analysis data for 4hr untreated control cell cultures of Lack of response subjects vs. control RNA)
# 	 Averaged gene expression analysis data for 4hr vaccinia treated cell cultures of increase and prolonged absence subjects vs. control RNA (Averaged gene expression analysis data for 4hr vaccinia treated cell cultures of increase and prolonged absence subjects vs. control RNA)
# 	 HIPC-PSOR-PPP_MICROARRAY (nan)
# 	 Averaged gene expression analysis data for 4hr vaccinia treated cell cultures of Lack of response subjects vs. control RNA (Averaged gene expression analysis data for 4hr vaccinia treated cell cultures of Lack of response subjects vs. control RNA)
# 	 Averaged gene expression analysis data for 20hr untreated control cell cultures of increase and prolonged absence subjects vs. control RNA (Averaged gene expression analysis data for 20hr untreated control cell cultures of increase and prolonged absence subjects vs. control RNA)
# 	 Engerix Microarray PBMC gene expression (see companion experiment EXP13591) (nan)
# 	 ArrayExpress: microarray data, E-MTAB-2313 (nan)
# 	 RC4_GE_PBMC (nan)
# 	 Averaged gene expression analysis data for 20hr untreated control cell cultures of Lack of response subjects vs. control RNA (Averaged gene expression analysis data for 20hr untreated control cell cultures of Lack of response subjects vs. control RNA)
# 	 Averaged gene expression analysis data for 20hr vaccinia treated cell cultures of increase and prolonged absence subjects vs. control RNA (Averaged gene expression analysis data for 20hr vaccinia treated cell cultures of increase and prolonged absence subjects vs. control RNA)
# 	 Averaged gene expression analysis data for 20hr vaccinia treated cell cultures of Lack of response subjects vs. control RNA (Averaged gene expression analysis data for 20hr vaccinia treated cell cultures of Lack of response subjects vs. control RNA)
# 	 Transplant Gene Expression (nan)
# 	 Gene Expression (nan)
# 	 DC Gene Expression (http://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSE55278)
# 	 julie_GE (nan)
# 	 Gene Expression Microarray (http://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSE22229)
# 	 HIPC_HEPSV_CSORTS_MICROARRAY (nan)
# 	 Microarray (nan)
# 	 Microarray and Bioinformatic analyses (nan)
# 	 YF17D-2006 microarray (https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSE13485)
#
# microRNA profiling assay
# 	 microRNA profiling (nan)
# 	 plasma miRNA profiling (Nanostring nCounter? ~800 human miRNA target expression profiling)

# %%
## Raus nehmen :     'SNP microarray', 'DNA microarray', 
include_measurements = [
    'Transcription profiling by array',
    'Sequencing',
    'Array',
]
experiment_transcriptomes_sorted_ma_seq = experiment_transcriptomes_sorted[experiment_transcriptomes_sorted['MEASUREMENT_TECHNIQUE'].isin(include_measurements)]
experiment_transcriptomes_sorted_ma_seq['MEASUREMENT_TECHNIQUE'].unique()
# Out:
# array(['Array', 'DNA microarray', 'SNP microarray', 'Sequencing',
#        'Transcription profiling by array'], dtype=object)

# %%
experiment_transcriptomes_sorted_ma_seq_experiments = experiment_transcriptomes_sorted_ma_seq['EXPERIMENT_ACCESSION'].unique()
studies_transcriptomes_sorted_ma_seq_experiments = experiment_transcriptomes_sorted_ma_seq['STUDY_ACCESSION'].unique()

print('BULK RNA expression data: ')
print(f'Studies: {len(studies_transcriptomes_sorted_ma_seq_experiments)}')
print(f'Experiments: {len(experiment_transcriptomes_sorted_ma_seq_experiments)}')
print(f'Subjects: ')
# Out:
# BULK RNA expression data:
# Studies: 119
# Experiments: 177
# Subjects:

# %%
expsample_gene_expr = pd.merge(expsample, gene_expression, on='EXPSAMPLE_ACCESSION', how='inner')
expsample_gene_expr.head()
# Out:
#   EXPSAMPLE_ACCESSION DESCRIPTION EXPERIMENT_ACCESSION NAME  \
# 0           ES1008357         NaN             EXP14587  NaN
# 1           ES1008358         NaN             EXP14587  NaN
# 2           ES1008359         NaN             EXP14587  NaN
# 3           ES1008360         NaN             EXP14587  NaN
# 4           ES1008361         NaN             EXP14587  NaN
#
#        RESULT_SCHEMA UPLOAD_RESULT_STATUS  WORKSPACE_ID  RESULT_ID  \
# 0  PUBLIC REPOSITORY               Parsed          3366       7249
# 1  PUBLIC REPOSITORY               Parsed          3366       7230
# 2  PUBLIC REPOSITORY               Parsed          3366       7302
# 3  PUBLIC REPOSITORY               Parsed          3366       7231
# 4  PUBLIC REPOSITORY               Parsed          3366       7262
#
#   REPOSITORY_ACCESSION REPOSITORY_NAME
# 0             GSE62627             GEO
# 1             GSE62627             GEO
# 2             GSE62627             GEO
# 3             GSE62627             GEO
# 4             GSE62627             GEO

# %%
## Filter only for valid experiments! 
expsample_gene_expr_bulk_transriptomes = expsample_gene_expr[expsample_gene_expr['EXPERIMENT_ACCESSION'].isin(experiment_transcriptomes_sorted_ma_seq_experiments)]
print(expsample_gene_expr_bulk_transriptomes.shape)
print(expsample_gene_expr_bulk_transriptomes.columns)
# Out:
# (13306, 10)
# Index(['EXPSAMPLE_ACCESSION', 'DESCRIPTION', 'EXPERIMENT_ACCESSION', 'NAME',
#        'RESULT_SCHEMA', 'UPLOAD_RESULT_STATUS', 'WORKSPACE_ID', 'RESULT_ID',
#        'REPOSITORY_ACCESSION', 'REPOSITORY_NAME'],
#       dtype='object')

# %%
subject_w_age.columns
# Out:
# Index(['ARM_ACCESSION', 'SUBJECT_ACCESSION', 'AGE_EVENT', 'AGE_EVENT_SPECIFY',
#        'AGE_UNIT', 'MAX_SUBJECT_AGE', 'MIN_SUBJECT_AGE', 'SUBJECT_PHENOTYPE',
#        'SUBJECT_LOCATION', 'MAX_SUBJECT_AGE_IN_YEARS',
#        'MIN_SUBJECT_AGE_IN_YEARS', 'ANCESTRAL_POPULATION', 'DESCRIPTION',
#        'ETHNICITY', 'GENDER', 'RACE', 'RACE_SPECIFY', 'SPECIES', 'STRAIN',
#        'STRAIN_CHARACTERISTICS', 'WORKSPACE_ID'],
#       dtype='object')

# %%
### Kills the kernel
""" subject_w_age['WORKSPACE_ID'] = subject_w_age['WORKSPACE_ID'].astype(int)
expsample_gene_expr_bulk_transriptomes_w_age = pd.merge(expsample_gene_expr_bulk_transriptomes, subject_w_age, on='WORKSPACE_ID', how='inner')
print(expsample_gene_expr_bulk_transriptomes_w_age.columns)
expsample_gene_expr_bulk_transriptomes_w_age.head() """
# Out:
# " subject_w_age['WORKSPACE_ID'] = subject_w_age['WORKSPACE_ID'].astype(int)\nexpsample_gene_expr_bulk_transriptomes_w_age = pd.merge(expsample_gene_expr_bulk_transriptomes, subject_w_age, on='WORKSPACE_ID', how='inner')\nprint(expsample_gene_expr_bulk_transriptomes_w_age.columns)\nexpsample_gene_expr_bulk_transriptomes_w_age.head() "

# %%
biosample_subject_accession = biosample[['BIOSAMPLE_ACCESSION', 'SUBJECT_ACCESSION']]
mapping_df_biosample_expsample = pd.merge(expsample_2_biosample, biosample_subject_accession, on='BIOSAMPLE_ACCESSION', how='inner')
print(mapping_df_biosample_expsample.columns)


expsample_gene_expr_bulk_transriptomes_mapping = pd.merge(expsample_gene_expr_bulk_transriptomes, mapping_df_biosample_expsample, on='EXPSAMPLE_ACCESSION', how='inner')
print(expsample_gene_expr_bulk_transriptomes.columns)

subject_w_age['WORKSPACE_ID'] = subject_w_age['WORKSPACE_ID'].astype(int)
expsample_gene_expr_bulk_transriptomes_mapping['WORKSPACE_ID'] = expsample_gene_expr_bulk_transriptomes_mapping['WORKSPACE_ID'].astype(int)
expsample_gene_expr_bulk_transriptomes_w_subjects = pd.merge(expsample_gene_expr_bulk_transriptomes_mapping, subject_w_age, on='SUBJECT_ACCESSION', how='inner') 
print(expsample_gene_expr_bulk_transriptomes_w_subjects.columns)
expsample_gene_expr_bulk_transriptomes_w_subjects.head()

#expsample_gene_expr_bulk_transriptomes_w_subjects_reduced = expsample_gene_expr_bulk_transriptomes_w_subjects[['GENDER', 'RACE', 'SUBJECT_ACCESSION']]
# Out:
# Index(['BIOSAMPLE_ACCESSION', 'EXPSAMPLE_ACCESSION', 'SUBJECT_ACCESSION'], dtype='object')
# Index(['EXPSAMPLE_ACCESSION', 'DESCRIPTION', 'EXPERIMENT_ACCESSION', 'NAME',
#        'RESULT_SCHEMA', 'UPLOAD_RESULT_STATUS', 'WORKSPACE_ID', 'RESULT_ID',
#        'REPOSITORY_ACCESSION', 'REPOSITORY_NAME'],
#       dtype='object')
# Index(['EXPSAMPLE_ACCESSION', 'DESCRIPTION_x', 'EXPERIMENT_ACCESSION', 'NAME',
#        'RESULT_SCHEMA', 'UPLOAD_RESULT_STATUS', 'WORKSPACE_ID_x', 'RESULT_ID',
#        'REPOSITORY_ACCESSION', 'REPOSITORY_NAME', 'BIOSAMPLE_ACCESSION',
#        'SUBJECT_ACCESSION', 'ARM_ACCESSION', 'AGE_EVENT', 'AGE_EVENT_SPECIFY',
#        'AGE_UNIT', 'MAX_SUBJECT_AGE', 'MIN_SUBJECT_AGE', 'SUBJECT_PHENOTYPE',
#        'SUBJECT_LOCATION', 'MAX_SUBJECT_AGE_IN_YEARS',
#        'MIN_SUBJECT_AGE_IN_YEARS', 'ANCESTRAL_POPULATION', 'DESCRIPTION_y',
#        'ETHNICITY', 'GENDER', 'RACE', 'RACE_SPECIFY', 'SPECIES', 'STRAIN',
#        'STRAIN_CHARACTERISTICS', 'WORKSPACE_ID_y'],
#       dtype='object')
#   EXPSAMPLE_ACCESSION DESCRIPTION_x EXPERIMENT_ACCESSION NAME  \
# 0           ES1008357           NaN             EXP14587  NaN
# 1           ES1008357           NaN             EXP14587  NaN
# 2           ES1008358           NaN             EXP14587  NaN
# 3           ES1008358           NaN             EXP14587  NaN
# 4           ES1008359           NaN             EXP14587  NaN
#
#        RESULT_SCHEMA UPLOAD_RESULT_STATUS  WORKSPACE_ID_x  RESULT_ID  \
# 0  PUBLIC REPOSITORY               Parsed            3366       7249
# 1  PUBLIC REPOSITORY               Parsed            3366       7249
# 2  PUBLIC REPOSITORY               Parsed            3366       7230
# 3  PUBLIC REPOSITORY               Parsed            3366       7230
# 4  PUBLIC REPOSITORY               Parsed            3366       7302
#
#   REPOSITORY_ACCESSION REPOSITORY_NAME  ... ANCESTRAL_POPULATION  \
# 0             GSE62627             GEO  ...               Europe
# 1             GSE62627             GEO  ...               Europe
# 2             GSE62627             GEO  ...               Europe
# 3             GSE62627             GEO  ...               Europe
# 4             GSE62627             GEO  ...               Europe
#
#   DESCRIPTION_y           ETHNICITY  GENDER   RACE RACE_SPECIFY       SPECIES  \
# 0           NaN  Hispanic or Latino  Female  White          NaN  Homo sapiens
# 1           NaN  Hispanic or Latino  Female  White          NaN  Homo sapiens
# 2           NaN  Hispanic or Latino  Female  White          NaN  Homo sapiens
# 3           NaN  Hispanic or Latino  Female  White          NaN  Homo sapiens
# 4           NaN  Hispanic or Latino  Female  White          NaN  Homo sapiens
#
#    STRAIN STRAIN_CHARACTERISTICS WORKSPACE_ID_y
# 0     NaN                    NaN           3366
# 1     NaN                    NaN           3366
# 2     NaN                    NaN           3366
# 3     NaN                    NaN           3366
# 4     NaN                    NaN           3366
#
# [5 rows x 32 columns]

# %%
counts = expsample_gene_expr_bulk_transriptomes_w_subjects.groupby('SUBJECT_ACCESSION')['REPOSITORY_ACCESSION'].count()
counts_df = counts.reset_index(name='count')

counts_df.describe()
max_outlier = counts_df[counts_df['count']>= 500]
max_outlier
#expsample_gene_expr_bulk_transriptomes_w_subjects[expsample_gene_expr_bulk_transriptomes_w_subjects['SUBJECT_ACCESSION'] == 'SUB134248']['EXPSAMPLE_ACCESSION'].unique()
# Out:
#     SUBJECT_ACCESSION  count
# 599         SUB134236    679
# 601         SUB134238    784
# 602         SUB134239   1078
# 604         SUB134241    784
# 606         SUB134243   1089
# 608         SUB134245    776
# 609         SUB134246    776
# 610         SUB134247   1078
# 611         SUB134248   1089
# 612         SUB134249    882
# 615         SUB134252    882
# 617         SUB134254   1089
# 619         SUB134256   1089
# 620         SUB134257   1089
# 625         SUB134262    891
# 626         SUB134263    882
# 645         SUB134282    891
# 655         SUB134292    990
# 656         SUB134293    990
# 664         SUB134301    990
# 665         SUB134302    582
# 684         SUB134321    891
# 686         SUB134323    686
# 688         SUB134325    891

# %%
print(f'Shape expsamples {expsample_gene_expr_bulk_transriptomes_w_subjects.shape}')
subjects_unique_df = expsample_gene_expr_bulk_transriptomes_w_subjects.drop_duplicates('SUBJECT_ACCESSION', keep='first')
print(subjects_unique_df.shape)
subjects_unique_list = expsample_gene_expr_bulk_transriptomes_w_subjects['SUBJECT_ACCESSION'].unique()
print(f'Subjects {len(subjects_unique_list)}')
# Out:
# Shape expsamples (35209, 32)
# (2784, 32)
# Subjects 2784

# %%
sns.violinplot(x='GENDER', y='MAX_SUBJECT_AGE_IN_YEARS', hue='GENDER', data=subjects_unique_df[['GENDER', 'MAX_SUBJECT_AGE_IN_YEARS']], split=True)
plt.show()

# %%
### This seems to kill my kernel all over again. 
#expsample_gene_expr_bulk_transriptomes_w_subject = pd.merge(expsample_gene_expr_bulk_transriptomes, subject, on='WORKSPACE_ID', how='left')
#expsample_gene_expr_bulk_transriptomes_w_subject.head()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
expsample_gene_expr_bulk_transriptomes_w_subjects['REPOSITORY_ACCESSION'].unique()
#### GEO: GSM specifies a sample usually
### Test GEO: GSM1885263 ; Test SRA:
# Out:
# array(['GSE62627', 'GSM1133831', 'GSM1133870', ..., 'GSM1885265',
#        'GSM1885266', 'GSM1885267'], dtype=object)

# %%
expsample_gene_expr_bulk_transriptomes_w_subjects['REPOSITORY_NAME'].unique()
# Out:
# array(['GEO', 'SRA'], dtype=object)

# %%
### As we only get GSM IDs i need a script to automatically download stuff from GEO (and maybe the other platforms too  ?)
from Bio import Entrez

# Set your email address for NCBI Entrez
Entrez.email = "elias.schreiner@uni-tuebingen.de"

# Function to search for datasets on GEO
def search_geo(query):
    handle = Entrez.esearch(db="gds", term=query, retmax=10)
    record = Entrez.read(handle)
    handle.close()
    return record["IdList"]

# Function to download datasets by accession number
def download_geo(accession):
    handle = Entrez.efetch(db="gds", id=accession, rettype="xml")
    record = Entrez.read(handle)
    handle.close()
    # Extract download links from the record and download the datasets
    for link in record[0]["EXPERIMENT_PACKAGE"]["SUPPLEMENTARY_FILE"]:
        url = link["@url"]
        filename = os.path.basename(url)
        print(f"Downloading {filename}...")
        os.system(f"wget {url}")

accession_list = search_geo('GSM1885263')
print(accession_list)
#download_geo(accession_list[0])
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File ~/micromamba/envs/merge_env/lib/python3.12/urllib/request.py:1344, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1343 try:
# -> 1344     h.request(req.get_method(), req.selector, req.data, headers,
#    1345               encode_chunked=req.has_header('Transfer-encoding'))
#    1346 except OSError as err: # timeout error
#
# File ~/micromamba/envs/merge_env/lib/python3.12/http/client.py:1327, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1326 """Send a complete request to the server."""
# -> 1327 self._send_request(method, url, body, headers, encode_chunked)
#
# File ~/micromamba/envs/merge_env/lib/python3.12/http/client.py:1373, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1372     body = _encode(body, 'body')
# -> 1373 self.endheaders(body, encode_chunked=encode_chunked)
#
# File ~/micromamba/envs/merge_env/lib/python3.12/http/client.py:1322, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1321     raise CannotSendHeader()
# -> 1322 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File ~/micromamba/envs/merge_env/lib/python3.12/http/client.py:1081, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1080 del self._buffer[:]
# -> 1081 self.send(msg)
#    1083 if message_body is not None:
#    1084
#    1085     # create a consistent interface to message_body
#
# File ~/micromamba/envs/merge_env/lib/python3.12/http/client.py:1025, in HTTPConnection.send(self, data)
#    1024 if self.auto_open:
# -> 1025     self.connect()
#    1026 else:
#
# File ~/micromamba/envs/merge_env/lib/python3.12/http/client.py:1461, in HTTPSConnection.connect(self)
#    1459 "Connect to a host on a given (SSL) port."
# -> 1461 super().connect()
#    1463 if self._tunnel_host:
#
# File ~/micromamba/envs/merge_env/lib/python3.12/http/client.py:991, in HTTPConnection.connect(self)
#     990 sys.audit("http.client.connect", self, self.host, self.port)
# --> 991 self.sock = self._create_connection(
#     992     (self.host,self.port), self.timeout, self.source_address)
#     993 # Might fail in OSs that don't implement TCP_NODELAY
#
# File ~/micromamba/envs/merge_env/lib/python3.12/socket.py:852, in create_connection(address, timeout, source_address, all_errors)
#     851 if not all_errors:
# --> 852     raise exceptions[0]
#     853 raise ExceptionGroup("create_connection failed", exceptions)
#
# File ~/micromamba/envs/merge_env/lib/python3.12/socket.py:837, in create_connection(address, timeout, source_address, all_errors)
#     836     sock.bind(source_address)
# --> 837 sock.connect(sa)
#     838 # Break explicitly a reference cycle
#
# OSError: [Errno 101] Network is unreachable
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# Cell In[57], line 26
#      23         print(f"Downloading {filename}...")
#      24         os.system(f"wget {url}")
# ---> 26 accession_list = search_geo('GSM1885263')
#      27 print(accession_list)
#      28 #download_geo(accession_list[0])
#
# Cell In[57], line 9, in search_geo(query)
#       8 def search_geo(query):
# ----> 9     handle = Entrez.esearch(db="gds", term=query, retmax=10)
#      10     record = Entrez.read(handle)
#      11     handle.close()
#
# File ~/micromamba/envs/merge_env/lib/python3.12/site-packages/Bio/Entrez/__init__.py:235, in esearch(db, term, **keywds)
#     233 variables.update(keywds)
#     234 request = _build_request(cgi, variables)
# --> 235 return _open(request)
#
# File ~/micromamba/envs/merge_env/lib/python3.12/site-packages/Bio/Entrez/__init__.py:623, in _open(request)
#     621 for i in range(max_tries):
#     622     try:
# --> 623         handle = urlopen(request)
#     624     except HTTPError as exception:
#     625         # Reraise if the final try fails
#     626         if i >= max_tries - 1:
#
# File ~/micromamba/envs/merge_env/lib/python3.12/urllib/request.py:215, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     213 else:
#     214     opener = _opener
# --> 215 return opener.open(url, data, timeout)
#
# File ~/micromamba/envs/merge_env/lib/python3.12/urllib/request.py:515, in OpenerDirector.open(self, fullurl, data, timeout)
#     512     req = meth(req)
#     514 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 515 response = self._open(req, data)
#     517 # post-process response
#     518 meth_name = protocol+"_response"
#
# File ~/micromamba/envs/merge_env/lib/python3.12/urllib/request.py:532, in OpenerDirector._open(self, req, data)
#     529     return result
#     531 protocol = req.type
# --> 532 result = self._call_chain(self.handle_open, protocol, protocol +
#     533                           '_open', req)
#     534 if result:
#     535     return result
#
# File ~/micromamba/envs/merge_env/lib/python3.12/urllib/request.py:492, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     490 for handler in handlers:
#     491     func = getattr(handler, meth_name)
# --> 492     result = func(*args)
#     493     if result is not None:
#     494         return result
#
# File ~/micromamba/envs/merge_env/lib/python3.12/urllib/request.py:1392, in HTTPSHandler.https_open(self, req)
#    1391 def https_open(self, req):
# -> 1392     return self.do_open(http.client.HTTPSConnection, req,
#    1393                         context=self._context)
#
# File ~/micromamba/envs/merge_env/lib/python3.12/urllib/request.py:1347, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1344         h.request(req.get_method(), req.selector, req.data, headers,
#    1345                   encode_chunked=req.has_header('Transfer-encoding'))
#    1346     except OSError as err: # timeout error
# -> 1347         raise URLError(err)
#    1348     r = h.getresponse()
#    1349 except:
#
# URLError: <urlopen error [Errno 101] Network is unreachable>

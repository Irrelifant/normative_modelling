# %%
## imports
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
immport_prefix="/var/datasets/ImmPort/immune_RNAseq/ALLSTUDIES/ALLSTUDIES-DR49.2_Tab/Tab/"

print("STUDY")
print("============================================================")
study = pd.read_table(f"{immport_prefix}/study.txt",sep="\t")
print(study.columns)
print(study.shape)
# study.head()

print("")
print("ARM_OR_COHORT")
print("============================================================")
arm_or_cohort = pd.read_table(f"{immport_prefix}/arm_or_cohort.txt",sep="\t")
print(arm_or_cohort.columns)
print(arm_or_cohort.shape)

print("")
print("ARM_2_SUBJECT")
print("============================================================")
arm_2_subject = pd.read_table(f"{immport_prefix}/arm_2_subject.txt",sep="\t")
print(arm_2_subject.columns)
print(arm_2_subject.shape)

# arm_2_subject.head()

print("")
print("BIOSAMPLE")
print("============================================================")
biosample = pd.read_table(f"{immport_prefix}/biosample.txt",sep="\t")
print(biosample.columns)
print(biosample.shape)

print("============================================================")
lab_test_panel = pd.read_table(f"{immport_prefix}/lab_test_panel.txt",sep="\t")
print(lab_test_panel.columns)
print(lab_test_panel.shape)

print("")
print("LAB_TEST")
print("============================================================")
lab_test = pd.read_table(f"{immport_prefix}/lab_test.txt",sep="\t")
print(lab_test.columns)
print(lab_test.shape)

print("")
print("SUBJECT")
print("============================================================")
subject = pd.read_table(f"{immport_prefix}/subject.txt", sep="\t") 
print(subject.shape)

print("ASSESSMENT_PANEL")
print("============================================================")
assessment_panel = pd.read_table(f"{immport_prefix}/assessment_panel.txt",sep="\t")
print(assessment_panel.columns)
print(assessment_panel.shape)

print("")
print("ASSESSMENT_COMPONENT")
print("============================================================")
assessment_component = pd.read_table(f"{immport_prefix}/assessment_component.txt",sep="\t")
print(assessment_component.columns)
print(assessment_component.shape)
# Out:
# STUDY
# ============================================================
# Index(['STUDY_ACCESSION', 'ACTUAL_COMPLETION_DATE', 'ACTUAL_ENROLLMENT',
#        'ACTUAL_START_DATE', 'AGE_UNIT', 'BRIEF_DESCRIPTION', 'BRIEF_TITLE',
#        'CLINICAL_TRIAL', 'CONDITION_STUDIED', 'DCL_ID', 'DESCRIPTION', 'DOI',
#        'ENDPOINTS', 'GENDER_INCLUDED', 'HYPOTHESIS',
#        'INITIAL_DATA_RELEASE_DATE', 'INITIAL_DATA_RELEASE_VERSION',
#        'INTERVENTION_AGENT', 'LATEST_DATA_RELEASE_DATE',
#        'LATEST_DATA_RELEASE_VERSION', 'MAXIMUM_AGE', 'MINIMUM_AGE',
#        'OBJECTIVES', 'OFFICIAL_TITLE', 'SHARED_STUDY',
#        'SPONSORING_ORGANIZATION', 'TARGET_ENROLLMENT', 'WORKSPACE_ID'],
#       dtype='object')
# (811, 28)
#
# ARM_OR_COHORT
# ============================================================
# Index(['ARM_ACCESSION', 'DESCRIPTION', 'NAME', 'STUDY_ACCESSION',
#        'TYPE_REPORTED', 'TYPE_PREFERRED', 'WORKSPACE_ID'],
#       dtype='object')
# (3296, 7)
#
# ARM_2_SUBJECT
# ============================================================
# Index(['ARM_ACCESSION', 'SUBJECT_ACCESSION', 'AGE_EVENT', 'AGE_EVENT_SPECIFY',
#        'AGE_UNIT', 'MAX_SUBJECT_AGE', 'MIN_SUBJECT_AGE', 'SUBJECT_PHENOTYPE',
#        'SUBJECT_LOCATION', 'MAX_SUBJECT_AGE_IN_YEARS',
#        'MIN_SUBJECT_AGE_IN_YEARS'],
#       dtype='object')
# (99728, 11)
#
# BIOSAMPLE
# ============================================================
# /tmp/ipykernel_29618/869920039.py:29: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   biosample = pd.read_table(f"{immport_prefix}/biosample.txt",sep="\t")
# Index(['BIOSAMPLE_ACCESSION', 'DESCRIPTION', 'NAME', 'PLANNED_VISIT_ACCESSION',
#        'STUDY_ACCESSION', 'STUDY_TIME_COLLECTED', 'STUDY_TIME_COLLECTED_UNIT',
#        'STUDY_TIME_T0_EVENT', 'STUDY_TIME_T0_EVENT_SPECIFY',
#        'SUBJECT_ACCESSION', 'SUBTYPE', 'TYPE', 'WORKSPACE_ID'],
#       dtype='object')
# (482701, 13)
# ============================================================
# Index(['LAB_TEST_PANEL_ACCESSION', 'NAME_PREFERRED', 'NAME_REPORTED',
#        'STUDY_ACCESSION', 'WORKSPACE_ID'],
#       dtype='object')
# (422, 5)
#
# LAB_TEST
# ============================================================
# Index(['LAB_TEST_ACCESSION', 'LAB_TEST_PANEL_ACCESSION', 'BIOSAMPLE_ACCESSION',
#        'NAME_PREFERRED', 'NAME_REPORTED', 'REFERENCE_RANGE_ACCESSION',
#        'RESULT_UNIT_PREFERRED', 'RESULT_UNIT_REPORTED',
#        'RESULT_VALUE_PREFERRED', 'RESULT_VALUE_REPORTED', 'WORKSPACE_ID'],
#       dtype='object')
# (1279882, 11)
#
# SUBJECT
# ============================================================
# (94198, 11)
# ASSESSMENT_PANEL
# ============================================================
# /tmp/ipykernel_29618/869920039.py:48: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   subject = pd.read_table(f"{immport_prefix}/subject.txt", sep="\t")
# Index(['ASSESSMENT_PANEL_ACCESSION', 'ASSESSMENT_TYPE', 'NAME_PREFERRED',
#        'NAME_REPORTED', 'RESULT_SCHEMA', 'STATUS', 'STUDY_ACCESSION',
#        'WORKSPACE_ID'],
#       dtype='object')
# (729, 8)
#
# ASSESSMENT_COMPONENT
# ============================================================
# /tmp/ipykernel_29618/869920039.py:60: DtypeWarning: Columns (2,8,9,15,16,19,25,26) have mixed types. Specify dtype option on import or set low_memory=False.
#   assessment_component = pd.read_table(f"{immport_prefix}/assessment_component.txt",sep="\t")
# Index(['ASSESSMENT_COMPONENT_ACCESSION', 'AGE_AT_ONSET_PREFERRED',
#        'AGE_AT_ONSET_REPORTED', 'AGE_AT_ONSET_UNIT_PREFERRED',
#        'AGE_AT_ONSET_UNIT_REPORTED', 'ASSESSMENT_PANEL_ACCESSION',
#        'IS_CLINICALLY_SIGNIFICANT', 'LOCATION_OF_FINDING_PREFERRED',
#        'LOCATION_OF_FINDING_REPORTED', 'NAME_PREFERRED', 'NAME_REPORTED',
#        'ORGAN_OR_BODY_SYSTEM_PREFERRED', 'ORGAN_OR_BODY_SYSTEM_REPORTED',
#        'PLANNED_VISIT_ACCESSION', 'REFERENCE_RANGE_ACCESSION',
#        'RESULT_UNIT_PREFERRED', 'RESULT_UNIT_REPORTED',
#        'RESULT_VALUE_CATEGORY', 'RESULT_VALUE_PREFERRED',
#        'RESULT_VALUE_REPORTED', 'STUDY_DAY', 'SUBJECT_ACCESSION',
#        'SUBJECT_POSITION_PREFERRED', 'SUBJECT_POSITION_REPORTED',
#        'TIME_OF_DAY', 'VERBATIM_QUESTION', 'WHO_IS_ASSESSED', 'WORKSPACE_ID'],
#       dtype='object')
# (2093159, 28)

# %%
#Helper methods
def lab_test_panels_by_study(study_accession,lab_tests):
    study_lab_tests = lab_tests[lab_tests['STUDY_ACCESSION']==study_accession]
    study_panels = study_lab_tests[['PANEL_NAME','LAB_TEST_NAME']]
    study_panels = study_panels.groupby(['PANEL_NAME','LAB_TEST_NAME']).size().reset_index(name="COUNTS")
    return study_panels
def assessment_panels_by_study(study_accession,assessments):
    study_assessments = assessments[assessments['STUDY_ACCESSION']==study_accession]
    study_panels = study_assessments[['PANEL_NAME','COMPONENT_NAME']]
    study_panels = study_panels.groupby(['PANEL_NAME','COMPONENT_NAME']).size().reset_index(name="COUNTS")
    return study_panels

# %%
## How many Labtests
print(f'Labtests amount: {lab_test.drop_duplicates().shape}')
print(f'Labtest panels amount: {lab_test_panel.drop_duplicates().shape}')

## How many Subjects
subject = subject[subject['SPECIES']=='Homo sapiens']
print(f'Subject amount: {subject.drop_duplicates().shape}')
subject_with_gender = subject[subject['GENDER'].isin(['Male' ,'Female'])].drop_duplicates()
print(f'Subjects male/female amount: {subject_with_gender.shape}')

## How many Studies
print(f'Studies amount: {study.drop_duplicates().shape}')

## Labtests: "Biomarkers", welche
# Out:
# Labtests amount: (1279882, 11)
# Labtest panels amount: (422, 5)
# Subject amount: (80499, 11)
# Subjects male/female amount: (74735, 11)
# Studies amount: (811, 28)

# %%
study['GENDER_INCLUDED'].unique()
arm_2_subject_valid = arm_2_subject[arm_2_subject['SUBJECT_ACCESSION'].isin(subject_with_gender['SUBJECT_ACCESSION'])]
 
duplicates = arm_2_subject_valid[arm_2_subject_valid.duplicated('SUBJECT_ACCESSION', keep='first')] 
## keep says if we want to see every enry just once or all duplicates of it
print(f'Arm 2 Subject duplicates: {duplicates.shape}')
arm_2_subject_valid['AGE_UNIT'].unique() # 'Years', 'Not Specified', 'Weeks', 'Months', 'Days', 'Hours' 
### here we need to see... babys may have a month or days unit ... hours is strange for homo sapiens... 
arm_2_subject_valid = arm_2_subject_valid.dropna(subset=['MAX_SUBJECT_AGE_IN_YEARS', 'MIN_SUBJECT_AGE_IN_YEARS'])
### As we have different age events we should despite track the duplicated subjects!
print(f'Subjects valid aged male/female {arm_2_subject_valid.drop_duplicates('SUBJECT_ACCESSION').shape}')
mismatch_age = arm_2_subject_valid[arm_2_subject_valid['MAX_SUBJECT_AGE_IN_YEARS'] != arm_2_subject_valid['MIN_SUBJECT_AGE_IN_YEARS']]
print(f'Subjects with MIN / MAX age mismatch {mismatch_age.drop_duplicates('SUBJECT_ACCESSION').shape}')

arm_2_subject_valid['AGE_EVENT'].unique() # 'Age at enrollment', 'Other', 'Not Specified', 'Age at initial vaccine administration', 'Age at Study Day 0', 'Age at infection', 'Age at initial treatment'

subject.head()
# Out:
# Arm 2 Subject duplicates: (5493, 11)
# Subjects valid aged male/female (74198, 11)
# Subjects with MIN / MAX age mismatch (3776, 11)
#   SUBJECT_ACCESSION ANCESTRAL_POPULATION DESCRIPTION      ETHNICITY  GENDER  \
# 0          SUB00240                  NaN      Muslim  Not Specified  Female
# 1          SUB00241                  NaN      Muslim  Not Specified    Male
# 2          SUB00242                  NaN      Muslim  Not Specified    Male
# 3          SUB00243                  NaN      Muslim  Not Specified  Female
# 4          SUB00244                  NaN      Muslim  Not Specified  Female
#
#     RACE RACE_SPECIFY       SPECIES STRAIN STRAIN_CHARACTERISTICS  \
# 0  Asian          NaN  Homo sapiens    NaN                    NaN
# 1  Asian          NaN  Homo sapiens    NaN                    NaN
# 2  Asian          NaN  Homo sapiens    NaN                    NaN
# 3  Asian          NaN  Homo sapiens    NaN                    NaN
# 4  Asian          NaN  Homo sapiens    NaN                    NaN
#
#    WORKSPACE_ID
# 0            49
# 1            49
# 2            49
# 3            49
# 4            49

# %%
arm_2_subject_valid.columns
# Out:
# Index(['ARM_ACCESSION', 'SUBJECT_ACCESSION', 'AGE_EVENT', 'AGE_EVENT_SPECIFY',
#        'AGE_UNIT', 'MAX_SUBJECT_AGE', 'MIN_SUBJECT_AGE', 'SUBJECT_PHENOTYPE',
#        'SUBJECT_LOCATION', 'MAX_SUBJECT_AGE_IN_YEARS',
#        'MIN_SUBJECT_AGE_IN_YEARS'],
#       dtype='object')

# %%
subject_w_age = pd.merge(arm_2_subject_valid, subject, on='SUBJECT_ACCESSION', how='left') ### I merge into arm_2_subject_valid as we have duplicated rows here that i probably want to keep whilst in the other its unique
subject_w_age.to_csv('subject_w_age.csv')

# %%
subject_with_gender.shape
arm_2_subject['AGE_EVENT'].unique()
# Out:
# array(['Age at enrollment', 'Not Specified', 'Other',
#        'Age at Study Day 0', 'Age at initial vaccine administration',
#        'Age at infection', 'Age at initial treatment'], dtype=object)

# %%
lab_test_panel = lab_test_panel.rename(columns={'NAME_REPORTED': 'PANEL_NAME'})
lab_test = lab_test.rename(columns={'NAME_REPORTED': 'LAB_TEST_NAME'})
lab_tests = pd.merge(lab_test_panel,lab_test,
                    left_on='LAB_TEST_PANEL_ACCESSION',right_on='LAB_TEST_PANEL_ACCESSION') 
lab_test.head()
# Out:
#   LAB_TEST_ACCESSION LAB_TEST_PANEL_ACCESSION BIOSAMPLE_ACCESSION  \
# 0                LT1                    LP581            BS235842
# 1               LT10                    LP581            BS235842
# 2              LT100                    LP581            BS235844
# 3             LT1000                    LP581            BS236373
# 4            LT10000                    LP581            BS236064
#
#            NAME_PREFERRED          LAB_TEST_NAME REFERENCE_RANGE_ACCESSION  \
# 0  White Blood Cell Count                    WBC                      RR81
# 1             Eosinophils            EOSINOPHILS                      RR13
# 2  Neutrophils, Segmented  SEGMENTED NEUTROPHILS                      RR75
# 3               Basophils              BASOPHILS                       RR5
# 4              Lymphocyte            LYMPHOCYTES                      RR35
#
#   RESULT_UNIT_PREFERRED RESULT_UNIT_REPORTED  RESULT_VALUE_PREFERRED  \
# 0                   NaN        10*3 cells/uL                     8.5
# 1            percentage                    %                     1.0
# 2            percentage                    %                    53.0
# 3            percentage                    %                     0.0
# 4            percentage                    %                    26.0
#
#   RESULT_VALUE_REPORTED  WORKSPACE_ID
# 0     8.5 10*3 cells/uL           990
# 1                   1 %           990
# 2                  53 %           990
# 3                   0 %           990
# 4                  26 %           990

# %%
lab_tests = pd.merge(lab_test_panel,lab_test,
                    left_on='LAB_TEST_PANEL_ACCESSION',right_on='LAB_TEST_PANEL_ACCESSION')
print(lab_tests.shape)
lab_tests_backup = lab_tests.copy(deep=True)
lab_tests.head()
# Out:
# (1279882, 15)
#   LAB_TEST_PANEL_ACCESSION NAME_PREFERRED_x PANEL_NAME STUDY_ACCESSION  \
# 0                  LP10000   Chemistry Test  CHEMISTRY          SDY354
# 1                  LP10000   Chemistry Test  CHEMISTRY          SDY354
# 2                  LP10000   Chemistry Test  CHEMISTRY          SDY354
# 3                  LP10000   Chemistry Test  CHEMISTRY          SDY354
# 4                  LP10000   Chemistry Test  CHEMISTRY          SDY354
#
#    WORKSPACE_ID_x LAB_TEST_ACCESSION BIOSAMPLE_ACCESSION     NAME_PREFERRED_y  \
# 0            3709           LT100000            BS727101            Uric Acid
# 1            3709           LT100004            BS727102  Blood Urea Nitrogen
# 2            3709           LT100017            BS727106            Uric Acid
# 3            3709           LT100018            BS727106  Blood Urea Nitrogen
# 4            3709           LT100031            BS727110  Blood Urea Nitrogen
#
#     LAB_TEST_NAME REFERENCE_RANGE_ACCESSION RESULT_UNIT_PREFERRED  \
# 0  H_URIC (URATE)                       NaN                 mg/dl
# 1     H_BUN (BUN)                       NaN                 mg/dl
# 2  H_URIC (URATE)                       NaN                 mg/dl
# 3     H_BUN (BUN)                       NaN                 mg/dl
# 4     H_BUN (BUN)                       NaN                 mg/dl
#
#   RESULT_UNIT_REPORTED  RESULT_VALUE_PREFERRED RESULT_VALUE_REPORTED  \
# 0                MG/DL                    12.0              12 MG/DL
# 1                MG/DL                    24.0              24 MG/DL
# 2                MG/DL                     5.4             5.4 MG/DL
# 3                MG/DL                    29.0              29 MG/DL
# 4                MG/DL                    17.0              17 MG/DL
#
#    WORKSPACE_ID_y
# 0            3709
# 1            3709
# 2            3709
# 3            3709
# 4            3709

# %%
#Helper methods
def lab_test_panels(lab_tests):
    study_panels = lab_tests[['PANEL_NAME','LAB_TEST_NAME']]
    study_panels = study_panels.groupby(['PANEL_NAME','LAB_TEST_NAME']).size().reset_index(name="COUNTS")
    return study_panels
def lab_test_panels_prefered_names(lab_tests):
    study_panels = lab_tests[['NAME_PREFERRED_x','NAME_PREFERRED_y']]
    study_panels = study_panels.groupby(['NAME_PREFERRED_x','NAME_PREFERRED_y']).size().reset_index(name="COUNTS")
    return study_panels

lab_tests_PANEL_NAME = lab_test_panels(lab_tests)
lab_tests_NAME_PREFERRED = lab_test_panels_prefered_names(lab_tests)
PANEL_NAMEs_unique = lab_tests_PANEL_NAME['PANEL_NAME'].unique()
LAB_TESTS_unique = lab_tests_PANEL_NAME['LAB_TEST_NAME'].unique()
NAME_PREFERRED_x_unique = lab_tests_NAME_PREFERRED['NAME_PREFERRED_x'].unique()
NAME_PREFERRED_y_unique = lab_tests_NAME_PREFERRED['NAME_PREFERRED_y'].unique()


print('PANEL_NAMEs '  + str(len(PANEL_NAMEs_unique)))
print('LAB_TESTS '  + str(len(LAB_TESTS_unique)))
print('LAB_TEST counts: ' + str(sum(lab_tests_PANEL_NAME['COUNTS'])))
print('PANEL_NAMEs preferred names '  + str(len(NAME_PREFERRED_x_unique)))
print('LAB_TESTS preferred names '  + str(len(NAME_PREFERRED_y_unique)))
print('LAB_TEST preferred counts: ' + str(sum(lab_tests_NAME_PREFERRED['COUNTS'])))


lab_tests_PANEL_NAME.head()
# Out:
# PANEL_NAMEs 105
# LAB_TESTS 1550
# LAB_TEST counts: 1279882
# PANEL_NAMEs preferred names 17
# LAB_TESTS preferred names 185
# LAB_TEST preferred counts: 802211
#                         PANEL_NAME  \
# 0  AD5 neutralizing antibody titer
# 1          AFP (alpha-fetoprotein)
# 2          Act CD8 T Cell Response
# 3             Amniotic Fluid Panel
# 4             Amniotic Fluid Panel
#
#                                        LAB_TEST_NAME  COUNTS
# 0  pre-existing serum ad5 neutralizing antibody t...      20
# 1                            AFP (alpha-fetoprotein)      56
# 2                            Act CD8 T Cell Response      25
# 3                                            Glucose      15
# 4                                      Interleukin 6      15

# %%
print('NA NAME_PREFERRED_x: ' + str(lab_tests['NAME_PREFERRED_x'].isna().sum()))
print('NA NAME_PREFERRED_y: ' + str(lab_tests['NAME_PREFERRED_y'].isna().sum()))
print('NA PANEL_NAME: ' + str(lab_tests['PANEL_NAME'].isna().sum()))
print('NA LAB_TEST_NAME: ' + str(lab_tests['LAB_TEST_NAME'].isna().sum()))
# Out:
# NA NAME_PREFERRED_x: 340701
# NA NAME_PREFERRED_y: 297137
# NA PANEL_NAME: 0
# NA LAB_TEST_NAME: 0

# %%
#### LIST FOR BINNING THE INDIVIDUAL STUDY TYPES!
grouped = lab_tests_PANEL_NAME.groupby('PANEL_NAME')['LAB_TEST_NAME'].apply(list).reset_index()
for index, row in grouped.iterrows():
    group = row['PANEL_NAME']
    pref_name = lab_tests[lab_tests['PANEL_NAME'] == group]['NAME_PREFERRED_x'].values
    if len(pref_name) > 0:
        pref_name = pref_name[0]
    else: 
        pref_name = ''
        
    items = row['LAB_TEST_NAME'][0]
    
    pref_item = {}
    for i, x in enumerate(row['LAB_TEST_NAME']):
        y = lab_tests[lab_tests['LAB_TEST_NAME'] == row['LAB_TEST_NAME'][i]]['NAME_PREFERRED_y'].values
        if len(y) > 0:
            pref_item[i] = y[0]
        else:
            pref_item[i] = ''
    
    print(f"\n{group} ({pref_name})")
    [print('\t' + str(x) + f' ({pref_item[i]})') for i, x in enumerate(row['LAB_TEST_NAME'])]
# Out:
# AD5 neutralizing antibody titer (nan)
# 	pre-existing serum ad5 neutralizing antibody titer (nan)
#
# AFP (alpha-fetoprotein) (nan)
# 	AFP (alpha-fetoprotein) (nan)
#
# Act CD8 T Cell Response (nan)
# 	Act CD8 T Cell Response (nan)
#
# Amniotic Fluid Panel (nan)
# 	Glucose (Glucose)
# 	Interleukin 6 (Interleukin 6)
# 	Lactate Dehydrogenase (Lactate Dehydrogenase)
# 	White Blood Count (White Blood Cell Count)
#
# Anti-HBc IgM (nan)
# 	Anti-HBc IgM (nan)
#
# Antibodies against Plasmodium falciparum antigens (nan)
# 	Antibodies against PfAMA-1 (nan)
# 	Antibodies against PfCSP (nan)
# 	Antibodies against PfEXP-1 (nan)
# 	Antibodies against PfLSA-1 (nan)
# 	Antibodies against PfMSP-1 (nan)
# 	Antibodies against PfMSP-5 (nan)
# 	Antibodies against PfSSP2 (nan)
#
# Antibody Titers (Immunology Test)
# 	Anti-Diptheria (nan)
# 	Anti-Hepatitis A (Hepatitis A Virus Surface Antibody)
# 	Anti-Hepatitis B (Hepatitis B Virus Surface Antibody)
# 	Anti-Tetanus (nan)
#
# Autoantibodies (Immunology Test)
# 	Anti-Double Stranded DNA (Anti-Double Stranded DNA)
# 	Anti-GAD65 (nan)
# 	Anti-ICA512 (nan)
# 	Anti-Insulin (Insulin Autoantibody)
# 	Antinuclear Antibodies (Antinuclear Antibodies)
# 	Cyclic Citrullinated Peptide Antibody (nan)
# 	Rheumatoid Factor (Rheumatoid Factor)
#
# Autoimmune Liver Disease (Autoimmune liver disease panel)
# 	Anti-Smooth-Muscle Antibody (nan)
# 	Anti-liver-kidney microsome antibody (nan)
# 	Antimitochondrial Antibodies (Antimitochondrial Antibodies)
# 	Antinuclear Antibodies (Antinuclear Antibodies)
# 	Immunoglobulin G (Immunoglobulin G)
#
# BASIC_CHEMISTRY (Chemistry Test)
# 	ALBUMIN (ALB) (Albumin)
# 	ALKPHOS (ALP) (Alkaline Phosphatase)
# 	BUN (BUN) (BUN)
# 	CALCIUM (CA) (Calcium)
# 	CHOL (CHOL) (Cholesterol)
# 	CL (CL) (Chloride)
# 	CO2 (CO2) (Carbon Dioxide)
# 	CREAT (CREAT) (Creatinine)
# 	GLUC (GLUC) (GLUC (GLUC))
# 	HDL (HDL) (HDL Cholesterol)
# 	LDH (LDH) (Lactate Dehydrogenase)
# 	LDL (LDL) (LDL Cholesterol)
# 	MG (MG) (Magnesium)
# 	PHOSP (PHOS) (Phosphate)
# 	POTASS (K) (Potassium)
# 	SGOT (AST) (Aspartate Aminotransferase)
# 	SGPT (ALT) (Alanine Aminotransferase)
# 	SODIUM (SODIUM) (Sodium)
# 	TBILI (BILI) (Bilirubin)
# 	TRIG (TRIG) (Triglyceride)
# 	URIC_A (URATE) (Uric Acid)
#
# BLOOD_CHEMISTRY (Chemistry Test)
# 	BC_ALK (ALP) (blood alkaline phosphatase activity level)
# 	BC_BUN (BUN) (blood urea nitrogen level)
# 	BC_CALC (CA) (blood calcium level)
# 	BC_CHLOR (CL) (blood chloride level)
# 	BC_CO2 (CO2) (blood carbon dioxide level)
# 	BC_CREAT (CREAT) (blood creatinine measurement)
# 	BC_LDH (LDH) (blood lactate dehydrogenase activity level)
# 	BC_MAG (MG) (blood magnesium level)
# 	BC_PHOS (PHOS) (blood phosphate level)
# 	BC_POT (K) (blood potassium level)
# 	BC_SGOT (AST) (blood aspartate aminotransferase activity level)
# 	BC_SGPT (ALT) (blood alanine aminotransferase activity level)
# 	BC_SOD (SODIUM) (blood sodium level)
# 	R_BASEC (CREAT) (Creatinine)
# 	R_CREA1 (CREAT) (Creatinine)
# 	R_CREA14 (CREAT) (Creatinine)
# 	R_CREA2 (CREAT) (Creatinine)
# 	R_CREA28 (CREAT) (Creatinine)
# 	R_CREA3 (CREAT) (Creatinine)
# 	R_CREA4 (CREAT) (Creatinine)
# 	R_CREA5 (CREAT) (Creatinine)
# 	R_CREA6 (CREAT) (Creatinine)
#
# Basophil (Blood Cell Count with Differential)
# 	Antigen1 CD63neg (nan)
# 	Antigen1 CD63neg_CD203_SD (nan)
# 	Antigen1 CD63neg_CD63_CV (nan)
# 	Antigen1 CD63neg_CD63_MFI (nan)
# 	Antigen1 CD63neg_CD63_SD (nan)
# 	Antigen1 CD63neg_COUNT (nan)
# 	Antigen1 CD63pos (nan)
# 	Antigen1 CD63pos_CD203_SD (nan)
# 	Antigen1 CD63pos_CD63_CV (nan)
# 	Antigen1 CD63pos_CD63_MFI (nan)
# 	Antigen1 CD63pos_CD63_SD (nan)
# 	Antigen1 CD63pos_COUNT (nan)
# 	Antigen2 CD63neg (nan)
# 	Antigen2 CD63neg_CD203_SD (nan)
# 	Antigen2 CD63neg_CD63_CV (nan)
# 	Antigen2 CD63neg_CD63_MFI (nan)
# 	Antigen2 CD63neg_CD63_SD (nan)
# 	Antigen2 CD63neg_COUNT (nan)
# 	Antigen2 CD63pos (nan)
# 	Antigen2 CD63pos_CD203_SD (nan)
# 	Antigen2 CD63pos_CD63_CV (nan)
# 	Antigen2 CD63pos_CD63_MFI (nan)
# 	Antigen2 CD63pos_CD63_SD (nan)
# 	Antigen2 CD63pos_COUNT (nan)
# 	Antigen3 CD63neg (nan)
# 	Antigen3 CD63neg_CD203_SD (nan)
# 	Antigen3 CD63neg_CD63_CV (nan)
# 	Antigen3 CD63neg_COUNT (nan)
# 	Antigen3 CD63pos (nan)
# 	Antigen3 CD63pos_CD203_SD (nan)
# 	Antigen3 CD63pos_CD63_CV (nan)
# 	Antigen3 CD63pos_CD63_MFI (nan)
# 	Antigen3 CD63pos_CD63_SD (nan)
# 	Antigen3 CD63pos_COUNT (nan)
# 	Antigen4 CD63neg (nan)
# 	Antigen4 CD63neg_CD203_SD (nan)
# 	Antigen4 CD63neg_CD63_CV (nan)
# 	Antigen4 CD63neg_CD63_MFI (nan)
# 	Antigen4 CD63neg_CD63_SD (nan)
# 	Antigen4 CD63neg_COUNT (nan)
# 	Antigen4 CD63pos (nan)
# 	Antigen4 CD63pos_CD203_SD (nan)
# 	Antigen4 CD63pos_CD63_CV (nan)
# 	Antigen4 CD63pos_CD63_MFI (nan)
# 	Antigen4 CD63pos_CD63_SD (nan)
# 	Antigen4 CD63pos_COUNT (nan)
# 	Antign1 CD63neg_CD203_MFI (nan)
# 	Antign1 CD63pos_CD203_MFI (nan)
# 	Antign2 CD63neg_CD203_MFI (nan)
# 	Antign2 CD63pos_CD203_MFI (nan)
# 	Antign3 CD63neg_CD203_MFI (nan)
# 	Antign3 CD63pos_CD203_MFI (nan)
# 	Antign4 CD63neg_CD203_MFI (nan)
# 	Antign4 CD63pos_CD203_MFI (nan)
# 	IL-3 CD63neg (nan)
# 	IL-3 CD63neg_CD203_MFI (nan)
# 	IL-3 CD63neg_CD203_SD (nan)
# 	IL-3 CD63neg_CD63_CV (nan)
# 	IL-3 CD63neg_CD63_MFI (nan)
# 	IL-3 CD63neg_CD63_SD (nan)
# 	IL-3 CD63neg_COUNT (nan)
# 	IL-3 CD63pos (nan)
# 	IL-3 CD63pos_CD203_MFI (nan)
# 	IL-3 CD63pos_CD203_SD (nan)
# 	IL-3 CD63pos_CD63_CV (nan)
# 	IL-3 CD63pos_CD63_MFI (nan)
# 	IL-3 CD63pos_CD63_SD (nan)
# 	IL-3 CD63pos_COUNT (nan)
# 	Medium CD63neg (nan)
# 	Medium CD63neg_CD203_MFI (nan)
# 	Medium CD63neg_CD203_SD (nan)
# 	Medium CD63neg_CD63_CV (nan)
# 	Medium CD63neg_CD63_MFI (nan)
# 	Medium CD63neg_CD63_SD (nan)
# 	Medium CD63neg_COUNT (nan)
# 	Medium CD63pos (nan)
# 	Medium CD63pos_CD203_MFI (nan)
# 	Medium CD63pos_CD203_SD (nan)
# 	Medium CD63pos_CD63_CV (nan)
# 	Medium CD63pos_CD63_MFI (nan)
# 	Medium CD63pos_CD63_SD (nan)
# 	Medium CD63pos_COUNT (nan)
# 	Unstain CD63neg (nan)
# 	Unstain CD63neg_CD203_MFI (nan)
# 	Unstain CD63neg_CD203_SD (nan)
# 	Unstain CD63neg_CD63_CV (nan)
# 	Unstain CD63neg_CD63_MFI (nan)
# 	Unstain CD63neg_COUNT (nan)
# 	Unstain CD63pos (nan)
# 	Unstain CD63pos_CD203_MFI (nan)
# 	Unstain CD63pos_CD203_SD (nan)
# 	Unstain CD63pos_CD63_CV (nan)
# 	Unstain CD63pos_CD63_MFI (nan)
# 	Unstain CD63pos_CD63_SD (nan)
# 	Unstain CD63pos_COUNT (nan)
# 	___MISSING___ (nan)
# 	antiIGE CD63neg (nan)
# 	antiIGE CD63neg_CD203_MFI (nan)
# 	antiIGE CD63neg_CD203_SD (nan)
# 	antiIGE CD63neg_CD63_CV (nan)
# 	antiIGE CD63neg_CD63_MFI (nan)
# 	antiIGE CD63neg_CD63_SD (nan)
# 	antiIGE CD63neg_COUNT (nan)
# 	antiIGE CD63pos (nan)
# 	antiIGE CD63pos_CD203_MFI (nan)
# 	antiIGE CD63pos_CD203_SD (nan)
# 	antiIGE CD63pos_CD63_CV (nan)
# 	antiIGE CD63pos_CD63_MFI (nan)
# 	antiIGE CD63pos_CD63_SD (nan)
# 	antiIGE CD63pos_COUNT (nan)
# 	fMLP CD63neg (nan)
# 	fMLP CD63neg_CD203_MFI (nan)
# 	fMLP CD63neg_CD203_SD (nan)
# 	fMLP CD63neg_CD63_SD (nan)
# 	fMLP CD63neg_COUNT (nan)
# 	fMLP CD63pos (nan)
# 	fMLP CD63pos_CD203_MFI (nan)
# 	fMLP CD63pos_CD203_SD (nan)
# 	fMLP CD63pos_CD63_CV (nan)
# 	fMLP CD63pos_CD63_MFI (nan)
# 	fMLP CD63pos_COUNT (nan)
#
# Blood Cell Count (Blood Cell Count)
# 	BASOPHIL_NO (Basophils)
# 	BASOPHIL_PERCENT (Basophil % of WBC)
# 	Basophils (Basophils)
# 	Basophils/Leukocytes (Basophils/Leukocytes)
# 	EOSINOPHIL_(PERCENT) (Eosinophil % of WBC)
# 	EOSINOPHIL_NO (Eosinophil)
# 	Eosinophils (Eosinophils)
# 	Eosinophils/Leukocytes (Eosinophils/Leukocytes)
# 	HGB (Hemoglobin)
# 	Hematocrit (Hematocrit)
# 	Hemoglobin (Hemoglobin)
# 	LYMPHOCYTE_(PERCENT) (Lymphocyte % of WBC)
# 	LYMPHOCYTE_NO (Lymphocyte)
# 	Leukocytes (Leukocytes)
# 	Lymphocytes (Lymphocyte)
# 	Lymphocytes/Leukocytes (Lymphocytes/Leukocytes)
# 	Lymphs (Lymphocyte)
# 	MEAN_PLATELET_VOLUME (Platelet)
# 	MONOCYTE_(PERCENT) (Monocyte % of WBC)
# 	MONOCYTE_NO (Monocytes)
# 	Monocytes (Monocytes)
# 	Monocytes/Leukocytes (Monocytes/Leukocytes)
# 	NEUTROPHIL_(PERCENT) (Neutrophil % of WBC)
# 	NEUTROPHIL_NO (Neutrophil)
# 	Neutrophils (Neutrophil)
# 	Neutrophils Band Form/Leukocytes (Neutrophils Band Form/Leukocytes)
# 	Neutrophils, Segmented/Leukocytes (Neutrophils, Segmented/Leukocytes)
# 	Neutrophils/Leukocytes (Neutrophils/Leukocytes)
# 	PLATELET (Platelet)
# 	Platelet Count (Platelet count)
# 	Platelets (Platelet)
# 	RBC (Erythrocytes)
# 	RBC_COUNT (Erythrocytes)
# 	WBC (White Blood Cell Count)
# 	WBC_COUNT (White Blood Cell Count)
# 	WESR (nan)
#
# Blood Cell Count with Differential (Blood Cell Count with Differential)
# 	Activated Partial Thromboplastin Time (Activated Partial Thromboplastin Time)
# 	Antinuclear Antibodies (Antinuclear Antibodies)
# 	BANDS (Neutrophils Band Form)
# 	BASO, % (Basophil % of WBC)
# 	BASO, Abs (Basophils)
# 	BASOPHILS ABSOLUTE (Basophils)
# 	Band (Band)
# 	Bands (Neutrophils Band Form)
# 	Basophil % of WBC (Basophil % of WBC)
# 	Basophils (Basophils)
# 	CD4 (CD4)
# 	CD8 (CD8)
# 	EOS (Eosinophils)
# 	EOS, % (Eosinophils)
# 	EOS, Abs (Eosinophils)
# 	EOSINOPHILS ABSOLUTE (Eosinophil)
# 	Eosinophil (Eosinophil)
# 	Eosinophil % of WBC (Eosinophil % of WBC)
# 	Eosinophils (Eosinophils)
# 	Ery. Mean Corpuscular HGB Concentration (Mean Corpuscular Hemoglobin)
# 	Ery. Mean Corpuscular Hemoglobin (Mean Corpuscular Hemoglobin)
# 	Ery. Mean Corpuscular Volume (Mean Corpuscular Volume)
# 	Erythrocyte Sedimentation Rate (Erythrocyte Sedimentation Rate)
# 	Erythrocytes (Erythrocytes)
# 	Erythrocytes Distribution Width (Erythrocytes Distribution Width)
# 	Glucose (Glucose)
# 	HCT (Hematocrit)
# 	HGB (Hemoglobin)
# 	Hematocrit (Hematocrit)
# 	Hematocrit (HCT) (Hematocrit)
# 	Hemoglobin (Hemoglobin)
# 	Immunoglobulin G (Immunoglobulin G)
# 	Immunoglobulin M (Immunoglobulin M)
# 	KETONES (Ketones)
# 	LYM, % (Lymphocyte % of WBC)
# 	LYM, Abs (Lymphocyte)
# 	LYMPHOCYTES ABSOLUTE (Lymphocyte)
# 	Leukocytes (Leukocytes)
# 	Lmphocytes (Lymphocyte)
# 	Lymphocyte (Lymphocyte)
# 	Lymphocyte % of WBC (Lymphocyte % of WBC)
# 	Lymphocytes (Lymphocyte)
# 	MCH (mean corpuscular hemoglobin level)
# 	MCHC (mean corpuscular hemoglobin concentration)
# 	MCV (Mean Corpuscular Volume)
# 	MONO, % (Monocyte % of WBC)
# 	MONO, Abs (Monocytes)
# 	MONOCYTES ABSOLUTE (Monocytes)
# 	MPV (Mean Platelet Volume)
# 	Mean Platelet Volume (Mean Platelet Volume)
# 	Mean corpuscular hemoglobin concentration (mean corpuscular hemoglobin concentration)
# 	Mean corpuscular volume (Mean Corpuscular Volume)
# 	Monocyte (Monocytes)
# 	Monocyte % of WBC (Monocyte % of WBC)
# 	Monocytes (Monocytes)
# 	NEUT, % (Neutrophil % of WBC)
# 	NEUT, Abs (Neutrophil)
# 	NEUTROPHIL BANDS ABS (Neutrophils Band Form)
# 	NEUTROPHIL, BANDS (Neutrophils Band Form)
# 	NEUTROPHIL, SEGS (Neutrophils, Segmented)
# 	NEUTROPHILS ABSOLUTE (Neutrophil)
# 	NITRITE (Nitrite)
# 	NUCLEATED RBC (Nucleated Erythrocytes)
# 	Neutrophil (Neutrophil)
# 	Neutrophil % of WBC (Neutrophil % of WBC)
# 	Neutrophils (Neutrophil)
# 	Neutrophils Band Form (Neutrophils Band Form)
# 	Neutrophils, Segmented (Neutrophils, Segmented)
# 	PH (pH)
# 	PLATELET (Platelet)
# 	PLATELET COUNT (Platelet count)
# 	PT (Prothrombin time)
# 	PTT (Activated Partial Thromboplastin Time)
# 	Partial Thromboplastin Time (Partial thromboplastin time)
# 	Partial thromboplastin time (Partial thromboplastin time)
# 	Platelet Count (Platelet count)
# 	Platelet count (Platelet count)
# 	Platelets (Platelet)
# 	Potassium (Potassium)
# 	Procalcitonin (nan)
# 	Prothrombin time (Prothrombin time)
# 	RBC (Erythrocytes)
# 	RDW (Erythrocytes Distribution Width)
# 	RED CELL COUNT (Erythrocytes)
# 	Red Blood Cell (Erythrocytes)
# 	Red Blood Cell (RBC) (Erythrocytes)
# 	Reticulocytes (Reticulocytes)
# 	Rheumatoid Factor (Rheumatoid Factor)
# 	SEGMENTED NEUTROPHILS (Neutrophils, Segmented)
# 	Seg (nan)
# 	TOTAL NEUTROPHILS (Neutrophil)
# 	TOTAL NEUTROPHILS AB (Neutrophil)
# 	Total WBC (White Blood Cell Count)
# 	Total basophils (Basophils)
# 	Total eosinophils (Eosinophil)
# 	Total hemoglobin (Hemoglobin)
# 	Total lymphocytes (Lymphocyte)
# 	Total monocytes (Monocytes)
# 	Total neutrophils (Neutrophil)
# 	WBC (White Blood Cell Count)
# 	WHITE CELL COUNT (White Blood Cell Count)
# 	White Blood Cell Count (White Blood Cell Count)
#
# Blood Cell Measurement (nan)
# 	Hematocrit (Hematocrit)
# 	Lymphocyte count (Lymphocyte count)
# 	Lymphocytes (Lymphocyte)
# 	Platelets (Platelet)
# 	WBC (White Blood Cell Count)
#
# Blood Chemistry (nan)
# 	ALT_log2 (nan)
# 	ANION_GAP (nan)
# 	APTT_log2 (nan)
# 	AST_log2 (nan)
# 	Albumin (Albumin)
# 	BASE_EXCESS_ARTERIAL (nan)
# 	BASE_EXCESS_VENOUS (nan)
# 	BRAIN_TRIURETIC_PROTEIN_log2 (nan)
# 	BUN (BUN)
# 	Bilirubin (Bilirubin)
# 	CREATINE_KINASE (Creatine Kinase)
# 	CREATININE_log2 (nan)
# 	CRP_log2 (nan)
# 	Calcium (Calcium)
# 	Chloride (Chloride)
# 	D-DIMER_log2 (nan)
# 	EGFR (nan)
# 	ESR (Erythrocyte Sedimentation Rate)
# 	FERRITIN_log2 (nan)
# 	FIBRINOGEN_log2 (nan)
# 	Glucose (Glucose)
# 	HCO3_ARTERIAL (nan)
# 	HCO3_VENOUS (nan)
# 	HEMATOCRIT_log2 (nan)
# 	Hemoglobin (Hemoglobin)
# 	Hemoglobin in gm% (nan)
# 	INR_log2 (nan)
# 	INTERLEUKIN-6, SERUM_LabCorp_log2 (nan)
# 	LDH_log2 (nan)
# 	O2_SATURATION_ARTERIAL (nan)
# 	O2_SATURATION_VENOUS (nan)
# 	PC02_VENOUS (nan)
# 	PCO2_ARTERIAL (nan)
# 	PH_ARTERIAL (nan)
# 	PH_VENOUS (nan)
# 	PO2_ARTERIAL (nan)
# 	PO2_VENOUS (nan)
# 	PROCALCITONIN_log2 (nan)
# 	PROTHROMBIN_TIME (nan)
# 	Potassium (Potassium)
# 	SARS-CoV-2 PCR (nan)
# 	Sodium (Sodium)
# 	TROPONIN-I_log2 (nan)
# 	URIC_ACID (Uric Acid)
#
# Blood Chemistry Measurement (nan)
# 	Alanine Aminotransferase (Alanine Aminotransferase)
# 	Albumin (Albumin)
# 	Alkaline Phosphatase (Alkaline Phosphatase)
# 	Bilirubin (Bilirubin)
# 	Complement C3 (Complement C3)
# 	Complement C4 (Complement C4)
# 	Complement Total (Complement Total)
# 	Creatinine (Creatinine)
# 	Glomerular Filtration Rate (Glomerular Filtration Rate)
# 	Hemoglobin (Hemoglobin)
# 	Potassium (Potassium)
# 	Sodium (Sodium)
# 	dsDNA (Anti-Double Stranded DNA)
# 	urea (nan)
#
# Blood Chemistry Test (Chemistry Test)
# 	Activated Partial Thromboplastin Time (Activated Partial Thromboplastin Time)
# 	Alanine Aminotransferase (Alanine Aminotransferase)
# 	Albumin (Albumin)
# 	Aspartate Aminotransferase (Aspartate Aminotransferase)
# 	Blood Urea Nitrogen (Blood Urea Nitrogen)
# 	Blood type (nan)
# 	Creatine Kinase (Creatine Kinase)
# 	Creatine kinase-MB (Creatine Kinase)
# 	Creatinine (Creatinine)
# 	D-dimer (nan)
# 	K+ (Potassium)
# 	Lactate Dehydrogenase (Lactate Dehydrogenase)
# 	Myoglobin (Myoglobin)
# 	PaCO2 (nan)
# 	PaO2 (nan)
# 	PaO2:FiO2 (nan)
# 	Peak CRP (nan)
# 	Peak Procalcitonin (nan)
# 	Procalcitonin on admission (nan)
# 	Prothrombin time (Prothrombin time)
# 	WBC (White Blood Cell Count)
# 	erythrocyte sedimentation rate (ESR) (Erythrocyte Sedimentation Rate)
# 	hospital C-reactive protein (CRP) (nan)
#
# Blood Flow Cytometry (Blood Flow Cytometry)
# 	CD20 (CD20 Expressing Cell Measurement)
# 	CD20+/CD52+ (nan)
# 	CD3 (CD3)
# 	CD3+/CD4+ (nan)
# 	CD3+/CD52+ (nan)
# 	CD52 (nan)
# 	CD8 (CD8)
#
# Blood Smear (nan)
# 	COMMENT (nan)
# 	GFALC1 (nan)
# 	GFALCI2 (nan)
# 	GFLCIN1Z (nan)
# 	GFLCINAZ (nan)
# 	GFLCND1Z (nan)
# 	GFLCND2Z (nan)
# 	GFLCNI2Z (nan)
# 	PFALCI (nan)
# 	PFLCIINZ (nan)
# 	PFLCINDZ (nan)
# 	PMAL (nan)
# 	PMALINIZ (nan)
# 	PMALNDZ (nan)
# 	POVALE (nan)
# 	POVALNDZ (nan)
# 	POVLEINZ (nan)
# 	SMEARNDZ (nan)
# 	SMEARPSZ (nan)
#
# Blood cell counts (nan)
# 	Basophils (Basophils)
# 	CD3 counts (CD3)
# 	CD4 counts (CD4)
# 	CD4/CD8 ratio (CD4/CD8)
# 	CD8 counts (CD8)
# 	Eosinophil (Eosinophil)
# 	Haemoglobin (Hemoglobin)
# 	Lymphocyte (Lymphocyte)
# 	Monocyte (Monocytes)
# 	Neutrophil (Neutrophil)
# 	Platelet count (Platelet count)
# 	White blood cell (White Blood Cell Count)
#
# CBC (Blood Cell Count)
# 	HCT (HCT) (Hematocrit)
# 	HGB (HGB) (Hemoglobin)
# 	H_HEMO (HGB) (Hemoglobin)
# 	H_PLAT (PLAT) (Platelet)
# 	H_PLAT2 (PLAT) (Platelet)
# 	H_WBC (WBC) (White Blood Cell Count)
# 	H_WBC2 (WBC) (White Blood Cell Count)
# 	OHEMAT1 (HCT) (Hematocrit)
# 	OHEMAT2 (HCT) (Hematocrit)
# 	OHEMAT3 (HCT) (Hematocrit)
# 	OHEMAT4 (HCT) (Hematocrit)
# 	OHEMAT5 (HCT) (Hematocrit)
# 	OHEMAT6 (HCT) (Hematocrit)
# 	OHEMAT7 (HCT) (Hematocrit)
# 	OHEMAT8 (HCT) (Hematocrit)
# 	OHEMATP (HCT) (Hematocrit)
# 	OHEMOG1 (HGB) (Hemoglobin)
# 	OHEMOG2 (HGB) (Hemoglobin)
# 	OHEMOG3 (HGB) (Hemoglobin)
# 	OHEMOG4 (HGB) (Hemoglobin)
# 	OHEMOG5 (HGB) (Hemoglobin)
# 	OHEMOG6 (HGB) (Hemoglobin)
# 	OHEMOG7 (HGB) (Hemoglobin)
# 	OHEMOG8 (HGB) (Hemoglobin)
# 	OHEMOGP (HGB) (Hemoglobin)
# 	OPLATE1 (PLAT) (Platelet)
# 	OPLATE2 (PLAT) (Platelet)
# 	OPLATE3 (PLAT) (Platelet)
# 	OPLATE4 (PLAT) (Platelet)
# 	OPLATE5 (PLAT) (Platelet)
# 	OPLATE6 (PLAT) (Platelet)
# 	OPLATE7 (PLAT) (Platelet)
# 	OPLATE8 (PLAT) (Platelet)
# 	OPLATEP (PLAT) (Platelet)
# 	ORBC1 (RBC) (Erythrocytes)
# 	ORBC2 (RBC) (Erythrocytes)
# 	ORBC3 (RBC) (Erythrocytes)
# 	ORBC4 (RBC) (Erythrocytes)
# 	ORBC5 (RBC) (Erythrocytes)
# 	ORBC6 (RBC) (Erythrocytes)
# 	ORBC7 (RBC) (Erythrocytes)
# 	ORBC8 (RBC) (Erythrocytes)
# 	ORBCP (RBC) (Erythrocytes)
# 	OWBC1 (WBC) (White Blood Cell Count)
# 	OWBC2 (WBC) (White Blood Cell Count)
# 	OWBC3 (WBC) (White Blood Cell Count)
# 	OWBC4 (WBC) (White Blood Cell Count)
# 	OWBC5 (WBC) (White Blood Cell Count)
# 	OWBC6 (WBC) (White Blood Cell Count)
# 	OWBC7 (WBC) (White Blood Cell Count)
# 	OWBC8 (WBC) (White Blood Cell Count)
# 	OWBCP (WBC) (White Blood Cell Count)
# 	PLATELET (PLAT) (Platelet)
# 	RBC (RBC) (Erythrocytes)
# 	THEMAT1 (HCT) (Hematocrit)
# 	THEMAT2 (HCT) (Hematocrit)
# 	THEMAT3 (HCT) (Hematocrit)
# 	THEMAT4 (HCT) (Hematocrit)
# 	THEMAT5 (HCT) (Hematocrit)
# 	THEMAT6 (HCT) (Hematocrit)
# 	THEMATP (HCT) (Hematocrit)
# 	THEMOG1 (HGB) (Hemoglobin)
# 	THEMOG2 (HGB) (Hemoglobin)
# 	THEMOG3 (HGB) (Hemoglobin)
# 	THEMOG4 (HGB) (Hemoglobin)
# 	THEMOG5 (HGB) (Hemoglobin)
# 	THEMOG6 (HGB) (Hemoglobin)
# 	THEMOGP (HGB) (Hemoglobin)
# 	TPLATE1 (PLAT) (Platelet)
# 	TPLATE2 (PLAT) (Platelet)
# 	TPLATE3 (PLAT) (Platelet)
# 	TPLATE4 (PLAT) (Platelet)
# 	TPLATE5 (PLAT) (Platelet)
# 	TPLATE6 (PLAT) (Platelet)
# 	TPLATEP (PLAT) (Platelet)
# 	TRBC1 (RBC) (White Blood Cell Count)
# 	TRBC2 (RBC) (White Blood Cell Count)
# 	TRBC3 (RBC) (White Blood Cell Count)
# 	TRBC4 (RBC) (White Blood Cell Count)
# 	TRBC5 (RBC) (White Blood Cell Count)
# 	TRBC6 (RBC) (White Blood Cell Count)
# 	TRBCP (RBC) (White Blood Cell Count)
# 	TWBC1 (WBC) (White Blood Cell Count)
# 	TWBC2 (WBC) (White Blood Cell Count)
# 	TWBC3 (WBC) (White Blood Cell Count)
# 	TWBC4 (WBC) (White Blood Cell Count)
# 	TWBC5 (WBC) (White Blood Cell Count)
# 	TWBC6 (WBC) (White Blood Cell Count)
# 	TWBCP (WBC) (White Blood Cell Count)
#
# CBC/Differential Results (Blood Cell Count with Differential)
# 	Eosinophils(x1000/microli (Eosinophil)
# 	Hematocrit(percent) (percent change in hematocrit)
# 	Hemoglobin(g/dl) (Hemoglobin)
# 	Lymphocytes(x1000/microli (Lymphocyte)
# 	Neutrophils(x1000/microli (Neutrophil)
# 	Total WBC(x1000/microlite (White Blood Cell Count)
#
# CBC_DIFFERENTIAL (Blood Cell Count with Differential)
# 	BASO (BASOCE) (Basophils)
# 	EOS (EOSCE) (Eosinophils)
# 	LYMPH (LYMCE) (Lymphocyte)
# 	MONO (MONOCYECE) (Monocytes)
# 	NEUT (NEUTCE) (Neutrophil)
# 	WBC (WBC) (White Blood Cell Count)
#
# CBC_Results (Blood Cell Count)
# 	BASOPHILS (percent) (Basophil % of WBC)
# 	BASOPHILS ABSOLUTE (Basophils)
# 	CD16 positive/CD56 positive (nan)
# 	CD16 positive/CD56 positive percentage (nan)
# 	CD19 positive cells (CD19)
# 	CD19 positive cells percentage (CD19)
# 	CD3 positive cells (CD3 Positive)
# 	CD3 positive cells percentage (CD3 Positive)
# 	CD4 positive cells (CD4 Positive)
# 	CD4 positive cells percentage (CD4 Positive)
# 	CD8 positive cells (CD8 Positive)
# 	CD8 positive cells percentage (CD8 Positive)
# 	EOSINOPHILS (percent) (Eosinophil % of WBC)
# 	EOSINOPHILS 2 (percent) (Eosinophil % of WBC)
# 	EOSINOPHILS BLOOD (blood eosinophil count)
# 	Eosinophils (Eosinophils)
# 	Eosinophils percentage (Eosinophil % of WBC)
# 	HEMATOCRIT (percent) (percent change in hematocrit)
# 	HEMOGLOBIN (g/dL) (Hemoglobin)
# 	HLA-DR positive/CDR4 positive (nan)
# 	HLA-DR positive/CDR4 positive percentage (nan)
# 	HLA-DR positive/CDR8 positive (nan)
# 	HLA-DR positive/CDR8 positive percentage (nan)
# 	LYMPHOCYTES (percent) (Lymphocyte % of WBC)
# 	LYMPHOCYTES ABSOLUTE (Lymphocyte)
# 	Leukocytes (Leukocytes)
# 	Lymphocytes (Lymphocyte)
# 	Lymphocytes percentage (Lymphocyte % of WBC)
# 	MCH (pg) (Mean Corpuscular Hemoglobin)
# 	MCHC (percent) (Mean Corpuscular HGB Concentration)
# 	MCV (fL) (Mean Corpuscular Volume)
# 	MONCYTES ABSOLUTE (Monocytes)
# 	MONOCYTES (percent) (Monocyte % of WBC)
# 	Monocytes (Monocytes)
# 	Monocytes percentage (Monocyte % of WBC)
# 	NEUTROPHIL SEGS (percent) (Neutrophil)
# 	NEUTROPHILS ABSOLUTE (Neutrophil)
# 	Neutrophils (Neutrophil)
# 	Neutrophils percentage (Neutrophil % of WBC)
# 	PLATELET COUNT (per cumm) (Platelet)
# 	RED BLOOD CELL DISTRUBUTION WIDTH (RDW) (Erythrocytes Distribution Width)
# 	RED CELL COUNT (mill/mcL) (Erythrocytes)
# 	Ratio Part 1 (nan)
# 	Ratio Part 2 (nan)
# 	TOTAL NEUTROPHILS (percent) (Neutrophil % of WBC)
# 	TOTAL NEUTROPHILS AB (Neutrophil)
# 	WHITE CELL COUNT (thou/mcL) (White Blood Cell Count)
#
# CHEMISTRY (Chemistry Test)
# 	H_BUN (BUN) (Blood Urea Nitrogen)
# 	H_URIC (URATE) (Uric Acid)
#
# CMV Screen and Titer (nan)
# 	CMV-status (Cytomegalovirus Viral Load Measurement)
#
# CMV Serology (nan)
# 	CMV (Cytomegalovirus Viral Load Measurement)
# 	EBV (nan)
#
# CMV and EBV serology (Immunology Test)
# 	CMV Ab (serum anti-cytomegalovirus (CMV) antibody level)
# 	EBV Ab (serum anti-Epstein-Barr virus (EBV) antibody level)
#
# Calcium test (Chemistry Test)
# 	Calcium test (Calcium)
#
# Chemistry Test (Chemistry Test)
# 	ALP (Alkaline Phosphatase)
# 	ALT (Alanine Aminotransferase)
# 	ALT/SGOT (SGOT)
# 	ALT/SGPT (SGPT)
# 	AST (Aspartate Aminotransferase)
# 	AST/SGOT (SGOT)
# 	Albumin (Albumin)
# 	Alkaline Phosphatase (Alkaline Phosphatase)
# 	Amylase (Amylase)
# 	B/C ratio (Blood Urea Nitrogen)
# 	BUN (BUN)
# 	Bicarbonate (Bicarbonate)
# 	Bilirubin (Bilirubin)
# 	C-Peptide (C-peptide)
# 	CO2 (Carbon Dioxide)
# 	CRP (C Reactive Protein)
# 	Calcium (Calcium)
# 	Calculated Glomerular Filtration Rate (Glomerular Filtration Rate)
# 	Carbon Dioxide (Carbon Dioxide)
# 	Chloride (Chloride)
# 	Creatinine (Creatinine)
# 	Estimated GFR (Glomerular Filtration Rate)
# 	GGT (Gamma Glutamyl Transpeptidase)
# 	Globulin (Globulin)
# 	Glucose (Glucose)
# 	Hemoglobin A1c (Glycosylated Hemoglobin)
# 	IRON BINDING CAPAC (nan)
# 	IRON, TOTAL, SERUM (nan)
# 	LDH (Lactate Dehydrogenase)
# 	Lactate Dehydrogenase (Lactate Dehydrogenase)
# 	Lipase (nan)
# 	Magnesium (Magnesium)
# 	PHOSPHORUS INORGANIC (Phosphate)
# 	Phosphate (Phosphate)
# 	Phosphorus (Phosphate)
# 	Potassium (Potassium)
# 	Protein (Protein)
# 	Sodium (Sodium)
# 	TBIL (Bilirubin)
# 	Total Bilirubin (Bilirubin)
# 	Total Protein (Protein)
# 	URIC ACID (Uric Acid)
# 	Uric Acid (Uric Acid)
#
# Clinical Chemistry (nan)
# 	Alanine Aminotransferase (Alanine Aminotransferase)
# 	Albumin (Albumin)
# 	Alkaline Phosphatase (Alkaline Phosphatase)
# 	Aspartate Aminotransferase (Aspartate Aminotransferase)
# 	Bicarbonate (Bicarbonate)
# 	Blood Urea Nitrogen (Blood Urea Nitrogen)
# 	C Reactive Protein (C Reactive Protein)
# 	Calcium (Calcium)
# 	Chloride (Chloride)
# 	Cholesterol (Cholesterol)
# 	Creatinine (Creatinine)
# 	Glucose (Glucose)
# 	HDL Cholesterol (HDL Cholesterol)
# 	LDL Cholesterol (LDL Cholesterol)
# 	Phosphate (Phosphate)
# 	Potassium (Potassium)
# 	Protein (Protein)
# 	Sodium (Sodium)
# 	Total Bilirubin (Bilirubin)
# 	Triglycerides (Triglyceride)
#
# Coagulation (nan)
# 	INR (nan)
# 	PT (Prothrombin time)
# 	PTT (Activated Partial Thromboplastin Time)
#
# Coagulation Status (nan)
# 	PT (Prothrombin time)
# 	PTT (Activated Partial Thromboplastin Time)
#
# Complete Blood Cell Count (nan)
# 	Basophils (Basophils)
# 	Eosinophils (Eosinophils)
# 	Lymphocytes (Lymphocyte)
# 	Monocytes (Monocytes)
# 	Neutrophils (Neutrophil)
# 	Platelets (Platelet)
# 	haemaglobin (Hemoglobin)
# 	haematocrit (Hematocrit)
# 	mcv (Mean Corpuscular Volume)
# 	wbc (White Blood Cell Count)
#
# Complete blood count (Blood Cell Count)
# 	Basophil (percent) (Basophil % of WBC)
# 	Basophil count (Basophils)
# 	Differential Bands (percent) (Neutrophils Band Form)
# 	Differential Basophils (percent) (Basophil % of WBC)
# 	Differential Eosinophils (Eosinophils)
# 	Differential Lymphocytes (percent) (Lymphocyte % of WBC)
# 	Differential Monocytes (percent) (Monocytes)
# 	Differential Platelet Estimate (Platelet count)
# 	Differential RBC Morphology (nan)
# 	Differential Segment (percent) (Differential Segment (percent))
# 	Eosinophil (percent) (Eosinophil % of WBC)
# 	Eosinophil count (Eosinophil)
# 	HCT/HGB ratio (nan)
# 	Hematocrit (HCT) (Hematocrit)
# 	Hemoglobin (HGB) (Hemoglobin)
# 	Lymphocyte (percent) (Lymphocyte % of WBC)
# 	Lymphocyte count (Lymphocyte count)
# 	Mean cell hemoglobin concentration (MCHC) (mean corpuscular hemoglobin concentration)
# 	Mean corpuscular hemoglobin (MCH) (mean corpuscular hemoglobin level)
# 	Mean corpuscular volume (MCV) (Mean Corpuscular Volume)
# 	Mean platelet volume (Mean Platelet Volume)
# 	Monocyte (percent) (Monocyte % of WBC)
# 	Monocyte count (Monocytes)
# 	Neutrophil (percent) (Neutrophil % of WBC)
# 	Neutrophil count (Neutrophil)
# 	Platelet count (Platelet count)
# 	Red blood cell distribution width (RDW) (Erythrocytes Distribution Width)
# 	Red blood cells (RBC) (Erythrocytes)
# 	White blood cells (WBC) (White Blood Cell Count)
#
# Comprehensive Metabolic Panel (Comprehensive Metabolic Panel)
# 	ALAT (SGPT) (SGPT)
# 	ALT (Alanine Aminotransferase)
# 	ALT (SGPT), Serum/Plasma (SGPT)
# 	ALT/SGPT (SGPT)
# 	ASAT (SGOT) (SGOT)
# 	AST (Aspartate Aminotransferase)
# 	AST (SGOT), Serum/Plasma (Aspartate Aminotransferase)
# 	AST/SGOT (SGOT)
# 	Alanine Aminotransferase (Alanine Aminotransferase)
# 	Albumin (Albumin)
# 	Albumin, Total, Serum/Plasma (Albumin)
# 	Alkaline Phosphatase (Alkaline Phosphatase)
# 	Alkaline Phosphatase, Total, Serum/Plasma (Alkaline Phosphatase)
# 	Anion Gap (Anion Gap)
# 	Aspartate Aminotransferase (Aspartate Aminotransferase)
# 	BANDS (Neutrophils Band Form)
# 	BILIRUBIN, DIRECT (Bilirubin)
# 	BILIRUBIN, INDIRECT (Bilirubin)
# 	BILIRUBIN, TOTAL (Bilirubin)
# 	BLOOD (nan)
# 	BUN (BUN)
# 	BUN/CREAT RATIO (nan)
# 	Basophils (Basophils)
# 	Bicarbonate (Bicarbonate)
# 	Bilirubin (Bilirubin)
# 	Blood Urea - BUN (blood urea nitrogen level)
# 	Blood Urea Nitrogen (Blood Urea Nitrogen)
# 	C-Reactive Protein (C Reactive Protein)
# 	CARBON DIOXIDE (Carbon Dioxide)
# 	CARBON DIOXIDE (CO2) (Carbon Dioxide)
# 	CO2 (Carbon Dioxide)
# 	CO2, Serum/Plasma (Carbon Dioxide)
# 	CPK (blood creatine kinase activity level)
# 	CREA (Creatinine)
# 	Calcium (Calcium)
# 	Calcium, Serum/Plasma (Calcium)
# 	Carbon Dioxide (Carbon Dioxide)
# 	Carbon dioxide (Carbon Dioxide)
# 	Chloride (Chloride)
# 	Chloride, Serum/Plasma (Chloride)
# 	Cholesterol (Cholesterol)
# 	Cholesterol/HDL-Cholesterol (Cholesterol/HDL-Cholesterol)
# 	Creatinine (Creatinine)
# 	Creatinine, Serum/Plasma (Creatinine)
# 	DIRECT BILIRUBIN (Bilirubin)
# 	Direct Bilirubin (Bilirubin)
# 	ESR (Erythrocyte Sedimentation Rate)
# 	Eosinophils (Eosinophils)
# 	Gamma glutamyl transferase (Gamma Glutamyl Transpeptidase)
# 	Gamma-glutamyl Transferase (Gamma Glutamyl Transpeptidase)
# 	Globulin (Globulin)
# 	Glucose (Glucose)
# 	Glucose, Serum/Plasma (Glucose)
# 	HDL Cholesterol (HDL Cholesterol)
# 	LDL Cholesterol (LDL Cholesterol)
# 	Lactate Dehydrogenase (Lactate Dehydrogenase)
# 	MAGNESIUM (Magnesium)
# 	Magnesium (Magnesium)
# 	PHOSPHORUS (Phosphate)
# 	PROTEIN, TOTAL SERUM (Protein)
# 	Phosphate (Phosphate)
# 	Phosphorus (Phosphate)
# 	Potassium (Potassium)
# 	Potassium, Serum/Plasma (Potassium)
# 	Protein (Protein)
# 	Protein, Total, Serum/Plasma (Protein)
# 	Sodium (Sodium)
# 	Sodium, Serum/Plasma (Sodium)
# 	TOTAL BILIRUBIN (Bilirubin)
# 	TOTAL CO2 (Carbon Dioxide)
# 	Thyroid Stimulating Hormone (Thyrotropin)
# 	Thyroxine (Thyroxine)
# 	Total Bilirubin (Bilirubin)
# 	Total CO2 (Carbon Dioxide)
# 	Total Protein (Protein)
# 	Triglycerides (Triglyceride)
# 	Triiodothyronine (Triiodothyronine)
# 	UREA NITROGEN (Blood Urea Nitrogen)
# 	URIC ACID (Uric Acid)
# 	Urea Nitrogen, Serum/Plasma (Urea Nitrogen, Serum/Plasma)
# 	Uric Acid (Uric Acid)
# 	alb (Albumin)
# 	alk (Alkaline Phosphatase)
# 	alt (Alanine Aminotransferase)
# 	ast (Aspartate Aminotransferase)
# 	bili (Bilirubin)
# 	bun (BUN)
# 	calc (Calcium)
# 	carb (Bicarbonate)
# 	chlo (Chloride)
# 	creat (Creatinine)
# 	gluc (Glucose)
# 	magn (Magnesium)
# 	phos (Phosphate)
# 	pot (Potassium)
# 	sod (Sodium)
#
# Creatinine test (Protein or Enzyme Type Measurement)
# 	Creatinine test (Creatinine)
#
# DIFFERENTIAL (Blood Cell Count with Differential)
# 	BASO (BASOCE) (Basophils)
# 	EOS (EOSCE) (Eosinophils)
# 	LYMPH (LYMCE) (Lymphocyte)
# 	MONO (MONOCYECE) (Monocytes)
# 	NEUT (NEUTCE) (Neutrophil)
# 	OBASO1 (BASOCE) (Basophils)
# 	OBASO2 (BASOCE) (Basophils)
# 	OBASO3 (BASOCE) (Basophils)
# 	OBASO4 (BASOCE) (Basophils)
# 	OBASO5 (BASOCE) (Basophils)
# 	OBASO6 (BASOCE) (Basophils)
# 	OBASO7 (BASOCE) (Basophils)
# 	OBASO8 (BASOCE) (Basophils)
# 	OBASOP (BASOCE) (Basophils)
# 	OEOSIN1 (EOSCE) (Eosinophils)
# 	OEOSIN2 (EOSCE) (Eosinophils)
# 	OEOSIN3 (EOSCE) (Eosinophils)
# 	OEOSIN4 (EOSCE) (Eosinophils)
# 	OEOSIN5 (EOSCE) (Eosinophils)
# 	OEOSIN6 (EOSCE) (Eosinophils)
# 	OEOSIN7 (EOSCE) (Eosinophils)
# 	OEOSIN8 (EOSCE) (Eosinophils)
# 	OEOSINP (EOSCE) (Eosinophils)
# 	OLYMPH1 (LYMCE) (Lymphocyte)
# 	OLYMPH2 (LYMCE) (Lymphocyte)
# 	OLYMPH3 (LYMCE) (Lymphocyte)
# 	OLYMPH4 (LYMCE) (Lymphocyte)
# 	OLYMPH5 (LYMCE) (Lymphocyte)
# 	OLYMPH6 (LYMCE) (Lymphocyte)
# 	OLYMPH7 (LYMCE) (Lymphocyte)
# 	OLYMPH8 (LYMCE) (Lymphocyte)
# 	OLYMPHP (LYMCE) (Lymphocyte)
# 	OMONOC1 (MONOCYECE) (Monocytes)
# 	OMONOC2 (MONOCYECE) (Monocytes)
# 	OMONOC3 (MONOCYECE) (Monocytes)
# 	OMONOC4 (MONOCYECE) (Monocytes)
# 	OMONOC5 (MONOCYECE) (Monocytes)
# 	OMONOC6 (MONOCYECE) (Monocytes)
# 	OMONOC7 (MONOCYECE) (Monocytes)
# 	OMONOC8 (MONOCYECE) (Monocytes)
# 	OMONOCP (MONOCYECE) (Monocytes)
# 	ONEUTR1 (NEUTCE) (Neutrophil)
# 	ONEUTR2 (NEUTCE) (Neutrophil)
# 	ONEUTR3 (NEUTCE) (Neutrophil)
# 	ONEUTR4 (NEUTCE) (Neutrophil)
# 	ONEUTR5 (NEUTCE) (Neutrophil)
# 	ONEUTR6 (NEUTCE) (Neutrophil)
# 	ONEUTR7 (NEUTCE) (Neutrophil)
# 	ONEUTR8 (NEUTCE) (Neutrophil)
# 	ONEUTRP (NEUTCE) (Neutrophil)
# 	TBASO1 (BASOCE) (Basophils)
# 	TBASO2 (BASOCE) (Basophils)
# 	TBASO3 (BASOCE) (Basophils)
# 	TBASO4 (BASOCE) (Basophils)
# 	TBASO5 (BASOCE) (Basophils)
# 	TBASO6 (BASOCE) (Basophils)
# 	TBASOP (BASOCE) (Basophils)
# 	TEOSIN1 (EOSCE) (Eosinophils)
# 	TEOSIN2 (EOSCE) (Eosinophils)
# 	TEOSIN3 (EOSCE) (Eosinophils)
# 	TEOSIN4 (EOSCE) (Eosinophils)
# 	TEOSIN5 (EOSCE) (Eosinophils)
# 	TEOSIN6 (EOSCE) (Eosinophils)
# 	TEOSINP (EOSCE) (Eosinophils)
# 	TLYMPH1 (LYMCE) (Lymphocyte)
# 	TLYMPH2 (LYMCE) (Lymphocyte)
# 	TLYMPH3 (LYMCE) (Lymphocyte)
# 	TLYMPH4 (LYMCE) (Lymphocyte)
# 	TLYMPH5 (LYMCE) (Lymphocyte)
# 	TLYMPH6 (LYMCE) (Lymphocyte)
# 	TLYMPHP (LYMCE) (Lymphocyte)
# 	TMONOC1 (MONOCYECE) (Monocytes)
# 	TMONOC2 (MONOCYECE) (Monocytes)
# 	TMONOC3 (MONOCYECE) (Monocytes)
# 	TMONOC4 (MONOCYECE) (Monocytes)
# 	TMONOC5 (MONOCYECE) (Monocytes)
# 	TMONOC6 (MONOCYECE) (Monocytes)
# 	TMONOCP (MONOCYECE) (Monocytes)
# 	TNEUTR1 (NEUTCE) (Neutrophil)
# 	TNEUTR2 (NEUTCE) (Neutrophil)
# 	TNEUTR3 (NEUTCE) (Neutrophil)
# 	TNEUTR4 (NEUTCE) (Neutrophil)
# 	TNEUTR5 (NEUTCE) (Neutrophil)
# 	TNEUTR6 (NEUTCE) (Neutrophil)
# 	TNEUTRP (NEUTCE) (Neutrophil)
# 	WBC (WBC) (White Blood Cell Count)
#
# Diagnostic Immunology (nan)
# 	HIV-1/2 Antibody (HIV-1/2 Antibody)
# 	HIV-2 (nan)
# 	Hepatitis B Core Antibody (Hepatitis B Virus Core Antibody)
# 	Hepatitis B Virus Surface Antigen (Hepatitis B Virus Surface Antigen)
# 	Hepatitis C Virus Antibody (Hepatitis C Virus Antibody)
# 	SS-A Antibody (Anti-SS-A antibody)
# 	SS-B Antibody (Anti-SS-B antibody)
#
# Diagnostic laboratory data (Protein or Enzyme Type Measurement)
# 	Aspergillus (nan)
# 	Aspergillus CAP-Klasse (nan)
# 	Birch (nan)
# 	Birch CAP-Klasse (nan)
# 	Candida albicans (nan)
# 	Candida albicans CAP-Klasse (nan)
# 	Cat dander (nan)
# 	Cat dander CAP-Klasse (nan)
# 	Cod Fish (nan)
# 	Cod Fish CAP-Klasse (nan)
# 	D. farinae (nan)
# 	D. farinae CAP-Klasse (nan)
# 	D. pteron. (nan)
# 	D. pteron. CAP-Klasse (nan)
# 	Egg (nan)
# 	Egg CAP-Klasse (nan)
# 	Enterotoxin A (nan)
# 	Enterotoxin A CAP-Klasse (nan)
# 	Enterotoxin B (nan)
# 	Enterotoxin B CAP-Klasse (nan)
# 	Green Apple (nan)
# 	Green Apple CAP-Klasse (nan)
# 	Hazelnut (nan)
# 	Hazelnut CAP-Klasse (nan)
# 	Milk protein (Milk protein)
# 	Milk protein CAP-Klasse (Milk protein CAP-Klasse)
# 	Peanut (nan)
# 	Peanut CAP-Klasse (nan)
# 	Pityrosporum ovale (nan)
# 	Pityrosporum ovale CAP-Klasse (nan)
# 	Timothy (grass pollen) (nan)
# 	Timothy (grass pollen) CAP-Klasse (nan)
# 	Total IgE (Immunoglobulin E)
# 	Wheat (nan)
# 	Wheat CAP-Klasse (nan)
#
# Endocrinology (nan)
# 	Thyrotropin (Thyrotropin)
#
# Enzyme measurement (Protein or Enzyme Type Measurement)
# 	CPK (blood creatine kinase activity level)
#
# FASTING_BLOOD_CHEMISTRY (Chemistry Test)
# 	BC_CHOL (CHOL) (blood chloride level)
# 	BC_GLUC (GLUC) (BC_GLUC (GLUC))
# 	BC_HDL (HDL) (blood high density lipoprotein cholesterol level)
# 	BC_LDL (LDL) (blood low density lipoprotein cholesterol level)
# 	BC_TRIG (TRIG) (blood triglyceride level)
#
# Fasting Lipid Panel (nan)
# 	HDL (HDL Cholesterol)
# 	LDL (LDL Cholesterol)
# 	Total Cholesterol (Cholesterol)
# 	Triglycerides (Triglyceride)
#
# Fasting Lipid Profile (Fasting Lipid Profile)
# 	Apolipoprotein A1 (Apolipoprotein A1)
# 	Apolipoprotein B (Apolipoprotein B)
# 	CHOL (Cholesterol)
# 	CHOLESTEROL, TOTAL (Cholesterol)
# 	C_H (Cholesterol/HDL-Cholesterol)
# 	Cholesterol (Cholesterol)
# 	Cholesterol/HDL Ratio (Cholesterol/HDL-Cholesterol)
# 	Fasting Cholesterol (Cholesterol)
# 	HDL (HDL Cholesterol)
# 	HDL Cholesterol (HDL Cholesterol)
# 	LDL (LDL Cholesterol)
# 	LDL Cholesterol (LDL Cholesterol)
# 	LDL/HDL Ratio (LDL Cholesterol)
# 	Non-HDL Cholesterol, calc (Non-HDL Cholesterol, calc)
# 	Protein (Protein)
# 	TRIG (Triglyceride)
# 	Total Cholesterol (Cholesterol)
# 	Triglyceride (Triglyceride)
# 	Triglycerides (Triglyceride)
#
# Fasting Lipids (nan)
# 	HDL (HDL Cholesterol)
# 	LDL (LDL Cholesterol)
# 	Total Cholesterol (Cholesterol)
# 	Triglycerides (Triglyceride)
#
# HBV/HCV Infection Status (nan)
# 	HBV/HCV Infection Status (nan)
#
# HEMATOLOGY (Blood Cell Count)
# 	H_BASOP (BASOCE) (Basophils)
# 	H_EOSIN (EOSCE) (Eosinophils)
# 	H_HEMA1C (HBA1C) (Glycosylated Hemoglobin)
# 	H_HEMAT (HCT) (Hematocrit)
# 	H_HEMO (HGB) (Hemoglobin)
# 	H_LYMPH (LYMCE) (Lymphocyte)
# 	H_MONO (MONOCYECE) (Monocytes)
# 	H_NEUT (NEUTCE) (Neutrophil)
# 	H_PLAT (PLAT) (Platelet)
# 	H_RBC (RBC) (Erythrocytes)
# 	H_WBC (WBC) (White Blood Cell Count)
#
# HIV serology (nan)
# 	HIV serology (nan)
#
# HRV PCR (nan)
# 	HRV PCR (nan)
#
# Hb type by BioRad D-10 (nan)
# 	Hemoglobin type (nan)
#
# Hematology (Blood Cell Count)
# 	ALT (Alanine Aminotransferase)
# 	AST (Aspartate Aminotransferase)
# 	Alkaline Phosphatase (Alkaline Phosphatase)
# 	BANDS (Neutrophils Band Form)
# 	BASOPHILS (Basophils)
# 	BUN (BUN)
# 	Basophil count (Basophils)
# 	Basophil percent (Basophil % of WBC)
# 	Basophils (Basophils)
# 	Basophils/Leukocytes (Basophils/Leukocytes)
# 	Calcium (Calcium)
# 	Creatinine (Creatinine)
# 	EOSINOPHILS (Eosinophils)
# 	Eosinophil (Eosinophil)
# 	Eosinophil count (Eosinophil)
# 	Eosinophil percent (Eosinophil % of WBC)
# 	Eosinophils (Eosinophils)
# 	Eosinophils/Leukocytes (Eosinophils/Leukocytes)
# 	Ery. Mean Corpuscular HGB Concentration (Mean Corpuscular Hemoglobin)
# 	Ery. Mean Corpuscular Hemoglobin (Mean Corpuscular Hemoglobin)
# 	Ery. Mean Corpuscular Volume (Mean Corpuscular Volume)
# 	Erythrocytes (Erythrocytes)
# 	Erythrocytes Distribution Width (Erythrocytes Distribution Width)
# 	Glucose (Glucose)
# 	HCT (Hematocrit)
# 	HCT/HGB Ratio (nan)
# 	HEMATOCRIT (Hematocrit)
# 	HEMOGLOBIN (Hemoglobin)
# 	HGB (Hemoglobin)
# 	Hematocrit (Hematocrit)
# 	Hemoglobin (Hemoglobin)
# 	IgA Total (Immunoglobulin A)
# 	IgE Total (Immunoglobulin E)
# 	IgG Total (Immunoglobulin G)
# 	IgG1 (IgG1)
# 	IgG2 (IgG2)
# 	IgG3 (nan)
# 	IgG4 (nan)
# 	IgM Total (Immunoglobulin M)
# 	LARGE UNCLASSIFIED CELLS (Large Unstained Cells)
# 	LYMPHOCYTES (Lymphocyte)
# 	Leukocytes (Leukocytes)
# 	Lymphocyte count (Lymphocyte count)
# 	Lymphocyte percent (Lymphocyte % of WBC)
# 	Lymphocytes (Lymphocyte)
# 	Lymphocytes/Leukocytes (Lymphocytes/Leukocytes)
# 	MCH (mean corpuscular hemoglobin level)
# 	MCHC (mean corpuscular hemoglobin concentration)
# 	MCV (Mean Corpuscular Volume)
# 	METAMYELOCYTE (Metamyelocytes)
# 	MONOCYTES (Monocytes)
# 	MYELOCYTE (Myelocytes)
# 	Mean platelet volume (Mean Platelet Volume)
# 	Monocyte count (Monocytes)
# 	Monocyte percent (Monocyte % of WBC)
# 	Monocytes (Monocytes)
# 	Monocytes/Leukocytes (Monocytes/Leukocytes)
# 	Neutrophil count (Neutrophil)
# 	Neutrophil percent (Neutrophil % of WBC)
# 	Neutrophils (Neutrophil)
# 	Neutrophils/Granulocytes (nan)
# 	Neutrophils/Leukocytes (Neutrophils/Leukocytes)
# 	PLATELET COUNT (Platelet count)
# 	Platelet (Platelet)
# 	Platelet count (Platelet count)
# 	Platelets (Platelet)
# 	Potassium (Potassium)
# 	RBC (Erythrocytes)
# 	RDW (Erythrocytes Distribution Width)
# 	REACTIVE LYMPH (Reactive Lymphocytes)
# 	REACTIVE LYMPH X (Reactive Lymphocytes)
# 	REACTIVE LYMPHOCYTES (Reactive Lymphocytes)
# 	REACTIVE LYMPHS (Reactive Lymphocytes)
# 	SEGMENTED NEUTROPHILS (Neutrophils, Segmented)
# 	SGOT (SGOT)
# 	SGPT (SGPT)
# 	Sodium (Sodium)
# 	Total Bilirubin (Bilirubin)
# 	Total Protein (Protein)
# 	Uric Acid (Uric Acid)
# 	WBC (White Blood Cell Count)
# 	White blood cell (White Blood Cell Count)
#
# Hematology test (Blood Cell Count with Differential)
# 	Bands (Neutrophils Band Form)
# 	Basophils (Basophils)
# 	Eosinophils (Eosinophils)
# 	Ery. Mean Corpuscular HGB Concentration (Mean Corpuscular Hemoglobin)
# 	Ery. Mean Corpuscular Hemoglobin (Mean Corpuscular Hemoglobin)
# 	Ery. Mean Corpuscular Volume (Mean Corpuscular Volume)
# 	Erythrocytes (Erythrocytes)
# 	Erythrocytes Distribution Width (Erythrocytes Distribution Width)
# 	Glycosylated hemoglobin (Glycosylated Hemoglobin)
# 	Hematocrit (Hematocrit)
# 	Hematocrit Count (Hematocrit)
# 	Hemoglobin (Hemoglobin)
# 	Hemoglobin Count (Hemoglobin)
# 	Leukocytes (Leukocytes)
# 	Lymphocytes (Lymphocyte)
# 	MCH (mean corpuscular hemoglobin level)
# 	MCHC (mean corpuscular hemoglobin concentration)
# 	MCV (Mean Corpuscular Volume)
# 	Mean Corpuscular Hemoglobin (Mean Corpuscular Hemoglobin)
# 	Mean Corpuscular Hemoglobin Concentration (mean corpuscular hemoglobin concentration)
# 	Mean Corpuscular Volume (Mean Corpuscular Volume)
# 	Mean Platelet Volume (Mean Platelet Volume)
# 	Mean Platelets Volume (Platelet)
# 	Monocytes (Monocytes)
# 	Neutrophils (Neutrophil)
# 	PT (Prothrombin time)
# 	PTT (Activated Partial Thromboplastin Time)
# 	Platelets (Platelet)
# 	Platelets Count (Platelet)
# 	Polys (Polymorphonuclear leukocyte count)
# 	Prothrombin time (Prothrombin time)
# 	RBC (Erythrocytes)
# 	RDW (Erythrocytes Distribution Width)
# 	Red Blood Cell count (Erythrocytes)
# 	Red Cell Distribution Width - Standard Deviation (Erythrocytes Distribution Width)
# 	Reticulocytes (Reticulocytes)
# 	Segs (Neutrophils, Segmented)
# 	WBC (White Blood Cell Count)
# 	White Blood Cell count (White Blood Cell Count)
# 	basophil count (Basophils)
# 	basophil percentage (Basophil % of WBC)
# 	eosonophil count (Eosinophil)
# 	eosonophil percentage (Eosinophil % of WBC)
# 	lymphocyte count (Lymphocyte count)
# 	lymphocyte percentage (Lymphocyte % of WBC)
# 	monocyte count (Monocytes)
# 	monocyte percentage (Monocyte % of WBC)
# 	neutrophil count (Neutrophil)
# 	neutrophil percentage (Neutrophil % of WBC)
#
# Hemoglobin from blood (nan)
# 	Hemoglobin (Hemoglobin)
#
# Hormone measurement (Hormone measurement)
# 	Parathyroid Hormone (Parathyroid Hormone, Intact)
# 	TSH (Thyrotropin)
#
# IgE (nan)
# 	Alternaria (m6) IgE Result (nan)
# 	American Cockroach (i206) IgE Result (nan)
# 	Aspergillus (m3) IgE Result (nan)
# 	Birch (t3) IgE Result (nan)
# 	Cat (e1) IgE Result (nan)
# 	Cladosporium (m2) IgE Result (nan)
# 	Der f (d2) IgE Result (nan)
# 	Der p (d1) IgE Result (nan)
# 	Dog (e5) IgE Result (nan)
# 	Egg white (f1) IgE Result (nan)
# 	German Cockroach (i6) IgE Result (nan)
# 	Maple - Box Elder (t1) IgE Result (nan)
# 	Milk (f2) IgE Result (nan)
# 	Mouse (e72) IgE Result (nan)
# 	Oak (t7) IgE Result (nan)
# 	Peanut (f13) IgE Result (nan)
# 	Pecan (t22) IgE Result (nan)
# 	Ragweed (w1) IgE Result (nan)
# 	Rat (e74) IgE Result (nan)
# 	Timothy grass (g6) IgE Result (nan)
# 	Total IgE Result (Immunoglobulin E)
#
# IgE/RAST (Protein or Enzyme Type Measurement)
# 	ALTERNARIA ALTERNATA (nan)
# 	ASPERGILLUS FUMIGATUS (nan)
# 	CLADOSPORIUM HERBARUM (nan)
# 	Cat Dander and Epithelium (nan)
# 	Cockroach (German) (nan)
# 	D. Farinae (nan)
# 	D. Pteronyssinus (nan)
# 	Dog Dander (nan)
# 	Egg white (nan)
# 	IgE to Animal Dander (EX2) (nan)
# 	IgE to Food(FX5E) (nan)
# 	IgE to Grass (GX2) (nan)
# 	IgE to Mite-roach (HX2) (nan)
# 	IgE to Mold (MX2) (nan)
# 	IgE to Staph (AM80) (nan)
# 	IgE to Staph (BM81) (nan)
# 	IgE to Staph (RM226) (nan)
# 	IgE to Tree (RTX10) (nan)
# 	IgE to Tree (TX3) (nan)
# 	IgE to Weed (WX1) (nan)
# 	Milk (nan)
# 	Mouse Urine Protein (nan)
# 	PENICILLIUM CHRYSOGENUM (nan)
# 	PHAD (IATOP) (nan)
# 	Peanut (nan)
# 	Rat Urine Protein (nan)
# 	Total IgE (Immunoglobulin E)
#
# Immune System Measurement (nan)
# 	Anti-CCP (nan)
# 	Anti-CCP2 (nan)
# 	Anti-CCP3 (nan)
# 	C Reactive Protein (C Reactive Protein)
# 	C-reactive protein (CRP) (C Reactive Protein)
# 	ESR (Erythrocyte Sedimentation Rate)
# 	Erythrocyte Sedimenttion rate (ESR) (Erythrocyte Sedimentation Rate)
# 	RF (RF)
# 	RF result (RF)
#
# Immunology (nan)
# 	Immunoglobulin-A (Immunoglobulin A)
# 	Immunoglobulin-G (Immunoglobulin G)
# 	Immunoglobulin-M (Immunoglobulin M)
#
# Immunology Test (Immunology Test)
# 	ARAH1 (nan)
# 	ARAH2 (nan)
# 	ARAH3 (nan)
# 	ARAH8 (nan)
# 	ARAH9 (nan)
# 	Absolute Lymphocyte Count (Lymphocyte)
# 	Almond Immunoglobulin (nan)
# 	Anti-Beta2 Glycoprotein 1 IgG (Beta-2 Glycoprotein Antibody)
# 	Anti-Beta2 Glycoprotein 1 IgM (Beta-2 Glycoprotein Antibody)
# 	Anti-Double Stranded DNA (Anti-Double Stranded DNA)
# 	Anti-RNP (Anti-Ribonucleoprotein Antibody)
# 	Anti-SS-A (Anti-SS-A antibody)
# 	Anti-SS-B (Anti-SS-B antibody)
# 	Anti-Smith (Anti-Smith Antibody)
# 	Anticardiolipin Antibody IgG (Anticardiolipin IgG Antibody)
# 	Anticardiolipin Antibody IgM (Anticardiolipin IgM Antibody)
# 	Antinuclear Antibodies (Antinuclear Antibodies)
# 	Antiphospholipid Antibodies (nan)
# 	Birch Tree Pollen IgE (nan)
# 	Brazil Nut Immunoglobulin (nan)
# 	C Reactive Protein (C Reactive Protein)
# 	C4D Immunohistochemistry (nan)
# 	CMV Ab (serum anti-cytomegalovirus (CMV) antibody level)
# 	Cashew Immunoglobulin (nan)
# 	Cat Dander IgE (nan)
# 	Cockroach (i6) IgE (nan)
# 	Cockroach (i6) IgG (nan)
# 	Cockroach (i6) IgG4 (nan)
# 	Complement C3 (Complement C3)
# 	Complement C4 (Complement C4)
# 	Coombs Direct (Antiglobulin Test, Direct)
# 	Coombs Indirect (Indirect Antiglobulin Test)
# 	Cow's Milk Immunoglobulin (nan)
# 	Cytomegalovirus Serostatus (nan)
# 	Dog Dander IgE (nan)
# 	Dust Mite IgE (nan)
# 	EBV Ab (serum anti-Epstein-Barr virus (EBV) antibody level)
# 	GAD (Glutamic Acid Decarboxylase Antibody)
# 	Grass Pollen IgE (nan)
# 	HACA test (nan)
# 	Hazel Nut Immunoglobulin (nan)
# 	Hen's Egg Immunoglobulin (nan)
# 	IAA (Insulin Autoantibody)
# 	ICA512 (Islet Cell 512 Antibody)
# 	IgE (Immunoglobulin E)
# 	IgG (Immunoglobulin G)
# 	IgG4 (nan)
# 	Immunoglobulin A (Immunoglobulin A)
# 	Immunoglobulin D (Immunoglobulin D)
# 	Immunoglobulin E (Immunoglobulin E)
# 	Immunoglobulin G (Immunoglobulin G)
# 	Immunoglobulin M (Immunoglobulin M)
# 	Mold IgE (nan)
# 	Panel A ESAT-6 (nan)
# 	Panel B CFP 10 (nan)
# 	Panel Reactive Antibody (Panel Reactive Antibody)
# 	Peanut Immunoglobulin (nan)
# 	Peanut-specific IgA (nan)
# 	Peanut-specific IgG (nan)
# 	Peanut-specific IgG4 (nan)
# 	RF (RF)
# 	Rheumatoid Factor (Rheumatoid Factor)
# 	Ribonucleoprotein Smith Complex Antibody (nan)
# 	Ribosomal P Protein Antibody (nan)
# 	SSA (Anti-SS-A antibody)
# 	SSB (Anti-SS-B antibody)
# 	Sedimentation Rate (Erythrocyte Sedimentation Rate)
# 	Sesame Immunoglobulin (nan)
# 	Sjogrens SS-A Antibody (nan)
# 	Sjogrens SS-B Antibody (nan)
# 	Smith Antibody (nan)
# 	T.SPOT result (nan)
# 	TB microbiologic confirmation test (nan)
# 	Total IgE (Immunoglobulin E)
# 	Walnut Immunoglobulin (nan)
#
# Immunology laboratory test (Immunology Test)
# 	Anti-Double Stranded DNA (Anti-Double Stranded DNA)
# 	CRP (C Reactive Protein)
# 	Complement C3 (Complement C3)
# 	Complement C4 (Complement C4)
#
# LIVER_FUNCTION (nan)
# 	H_BILI (BILI) (Bilirubin)
# 	H_SGOT (AST) (Aspartate Aminotransferase)
# 	H_SGPT (ALT) (Alanine Aminotransferase)
#
# LIVER_PANEL (Comprehensive Metabolic Panel)
# 	OALBUM1 (ALB) (Albumin)
# 	OALBUM2 (ALB) (Albumin)
# 	OALBUM3 (ALB) (Albumin)
# 	OALBUM4 (ALB) (Albumin)
# 	OALBUM5 (ALB) (Albumin)
# 	OALBUM6 (ALB) (Albumin)
# 	OALBUM7 (ALB) (Albumin)
# 	OALBUM8 (ALB) (Albumin)
# 	OALBUMP (ALB) (Albumin)
# 	ODBILI1 (BILDIR) (Bilirubin)
# 	ODBILI2 (BILDIR) (Bilirubin)
# 	ODBILI3 (BILDIR) (Bilirubin)
# 	ODBILI4 (BILDIR) (Bilirubin)
# 	ODBILI5 (BILDIR) (Bilirubin)
# 	ODBILI6 (BILDIR) (Bilirubin)
# 	ODBILI7 (BILDIR) (Bilirubin)
# 	ODBILI8 (BILDIR) (Bilirubin)
# 	ODBILIP (BILDIR) (Bilirubin)
# 	OGGT1 (GGT) (Gamma Glutamyl Transpeptidase)
# 	OGGT2 (GGT) (Gamma Glutamyl Transpeptidase)
# 	OGGT3 (GGT) (Gamma Glutamyl Transpeptidase)
# 	OGGT4 (GGT) (Gamma Glutamyl Transpeptidase)
# 	OGGT5 (GGT) (Gamma Glutamyl Transpeptidase)
# 	OGGT6 (GGT) (Gamma Glutamyl Transpeptidase)
# 	OGGT7 (GGT) (Gamma Glutamyl Transpeptidase)
# 	OGGTP (GGT) (Gamma Glutamyl Transpeptidase)
# 	OSGOT1 (AST) (Aspartate Aminotransferase)
# 	OSGOT2 (AST) (Aspartate Aminotransferase)
# 	OSGOT3 (AST) (Aspartate Aminotransferase)
# 	OSGOT4 (AST) (Aspartate Aminotransferase)
# 	OSGOT5 (AST) (Aspartate Aminotransferase)
# 	OSGOT6 (AST) (Aspartate Aminotransferase)
# 	OSGOT7 (AST) (Aspartate Aminotransferase)
# 	OSGOT8 (AST) (Aspartate Aminotransferase)
# 	OSGOTP (AST) (Aspartate Aminotransferase)
# 	OSGPT1 (ALT) (Alanine Aminotransferase)
# 	OSGPT2 (ALT) (Alanine Aminotransferase)
# 	OSGPT3 (ALT) (Alanine Aminotransferase)
# 	OSGPT4 (ALT) (Alanine Aminotransferase)
# 	OSGPT5 (ALT) (Alanine Aminotransferase)
# 	OSGPT6 (ALT) (Alanine Aminotransferase)
# 	OSGPT7 (ALT) (Alanine Aminotransferase)
# 	OSGPT8 (ALT) (Alanine Aminotransferase)
# 	OSGPTP (ALT) (Alanine Aminotransferase)
# 	OTBILI1 (BILI) (Bilirubin)
# 	OTBILI2 (BILI) (Bilirubin)
# 	OTBILI3 (BILI) (Bilirubin)
# 	OTBILI4 (BILI) (Bilirubin)
# 	OTBILI5 (BILI) (Bilirubin)
# 	OTBILI6 (BILI) (Bilirubin)
# 	OTBILI7 (BILI) (Bilirubin)
# 	OTBILI8 (BILI) (Bilirubin)
# 	OTBILIP (BILI) (Bilirubin)
# 	TALBUM1 (ALB) (Albumin)
# 	TALBUM2 (ALB) (Albumin)
# 	TALBUM3 (ALB) (Albumin)
# 	TALBUM4 (ALB) (Albumin)
# 	TALBUM5 (ALB) (Albumin)
# 	TALBUM6 (ALB) (Albumin)
# 	TALBUMP (ALB) (Albumin)
# 	TDBILI1 (BILDIR) (Bilirubin)
# 	TDBILI2 (BILDIR) (Bilirubin)
# 	TDBILI3 (BILDIR) (Bilirubin)
# 	TDBILI4 (BILDIR) (Bilirubin)
# 	TDBILI5 (BILDIR) (Bilirubin)
# 	TDBILI6 (BILDIR) (Bilirubin)
# 	TDBILIP (BILDIR) (Bilirubin)
# 	TGGT1 (GGT) (Gamma Glutamyl Transpeptidase)
# 	TGGT2 (GGT) (Gamma Glutamyl Transpeptidase)
# 	TGGT3 (GGT) (Gamma Glutamyl Transpeptidase)
# 	TGGT4 (GGT) (Gamma Glutamyl Transpeptidase)
# 	TGGT5 (GGT) (Gamma Glutamyl Transpeptidase)
# 	TGGT6 (GGT) (Gamma Glutamyl Transpeptidase)
# 	TGGTP (GGT) (Gamma Glutamyl Transpeptidase)
# 	TSGOT1 (AST) (Aspartate Aminotransferase)
# 	TSGOT2 (AST) (Aspartate Aminotransferase)
# 	TSGOT3 (AST) (Aspartate Aminotransferase)
# 	TSGOT4 (AST) (Aspartate Aminotransferase)
# 	TSGOT5 (AST) (Aspartate Aminotransferase)
# 	TSGOT6 (AST) (Aspartate Aminotransferase)
# 	TSGOTP (AST) (Aspartate Aminotransferase)
# 	TSGPT1 (ALT) (Alanine Aminotransferase)
# 	TSGPT2 (ALT) (Alanine Aminotransferase)
# 	TSGPT3 (ALT) (Alanine Aminotransferase)
# 	TSGPT4 (ALT) (Alanine Aminotransferase)
# 	TSGPT5 (ALT) (Alanine Aminotransferase)
# 	TSGPT6 (ALT) (Alanine Aminotransferase)
# 	TSGPTP (ALT) (Alanine Aminotransferase)
# 	TTBILI1 (BILI) (Bilirubin)
# 	TTBILI2 (BILI) (Bilirubin)
# 	TTBILI3 (BILI) (Bilirubin)
# 	TTBILI4 (BILI) (Bilirubin)
# 	TTBILI5 (BILI) (Bilirubin)
# 	TTBILI6 (BILI) (Bilirubin)
# 	TTBILIP (BILI) (Bilirubin)
#
# LPS quantification (nan)
# 	LPS (nan)
#
# Lab Test for Blood Samples (Protein or Enzyme Type Measurement)
# 	HSV 1/2 IgG(ELISA) Absolute Result (nan)
# 	HSV 1/2 IgG(ELISA) Result (nan)
# 	HSV 1/2 IgM(ELISA) Absolute Result (nan)
# 	HSV 1/2 IgM(ELISA) Result (nan)
# 	HSV Antibody Result (nan)
#
# Laboratory test related to hemostasis (Laboratory test related to hemostasis)
# 	Erythrocyte Sedimentation Rate (Erythrocyte Sedimentation Rate)
# 	Partial thromboplastin time (Partial thromboplastin time)
# 	Prothrombin time (Prothrombin time)
#
# Malaria Infection (nan)
# 	Malaria Infection Status (nan)
#
# Metabolic Assessments (Protein or Enzyme Type Measurement)
# 	Glycosylated Hemoglobin (Glycosylated Hemoglobin)
# 	HbA1c (Glycosylated Hemoglobin)
#
# Metabolic Panel (nan)
# 	Alanine Aminotransferase (Alanine Aminotransferase)
# 	Alkaline Phosphatase (Alkaline Phosphatase)
# 	Aspartate Aminotransferase (Aspartate Aminotransferase)
# 	PT/PTT (nan)
#
# Microbial Evaluation (nan)
# 	Microbial Evaluation (nan)
#
# Mixed-Meal Tolerance Test (Chemistry Test)
# 	C-PEPTIDE (C-peptide)
# 	C-peptide (C-peptide)
# 	Creatinine (Creatinine)
# 	Creatinine Ratio (Creatinine)
# 	Glucose (Glucose)
#
# Molecular Diagnostics (nan)
# 	Hepatitis C Viral RNA (nan)
#
# Nasal Lavage Fluid Cell Counts (nan)
# 	NLF Cell Counts % Epithelial cells (nan)
# 	NLF Cell Counts %Eos (nan)
# 	NLF Cell Counts %Lym (nan)
# 	NLF Cell Counts %Mac (nan)
# 	NLF Cell Counts %PMN (nan)
# 	NLF Cell Counts %Squamous cells (nan)
# 	NLF Cell Counts %WBC (nan)
# 	NLF Cell Counts.WBC# 0090.NLFVisit 1 (nan)
# 	NLF Cell Counts.WBC# 0090.NLFVisit 1a (nan)
# 	NLF Cell Counts.WBC# 0090.NLFVisit 2 (nan)
# 	NLF Cell Counts.WBC# 0090.NLFVisit 3 (nan)
# 	NLF Cell Counts.WBC# 0090.NLFVisit 5 (nan)
# 	NLF Cell Counts.WBC# 0090.NLFVisit 6 (nan)
# 	NLF Cell Counts.WBC#0001.NLFVisit 1 (nan)
# 	NLF Cell Counts.WBC#0001.NLFVisit 1a (nan)
# 	NLF Cell Counts.WBC#0001.NLFVisit 2 (nan)
# 	NLF Cell Counts.WBC#0001.NLFVisit 3 (nan)
# 	NLF Cell Counts.WBC#0001.NLFVisit 5 (nan)
# 	NLF Cell Counts.WBC#0001.NLFVisit 6 (nan)
# 	NLF Cell Counts.WBC#0007.NLFVisit 1 (nan)
# 	NLF Cell Counts.WBC#0007.NLFVisit 1a (nan)
# 	NLF Cell Counts.WBC#0007.NLFVisit 2 (nan)
# 	NLF Cell Counts.WBC#0007.NLFVisit 3 (nan)
# 	NLF Cell Counts.WBC#0007.NLFVisit 5 (nan)
# 	NLF Cell Counts.WBC#0007.NLFVisit 6 (nan)
# 	NLF Cell Counts.WBC#0008.NLFVisit 1 (nan)
# ...
# 	NLF Cell Counts.WBC#0038.NLFVisit 5 (nan)
# 	NLF Cell Counts.WBC#0038.NLFVisit 6 (nan)
# 	NLF Cell Counts.WBC#0049.NLFVisit 1 (nan)
# 	NLF Cell Counts.WBC#0049.NLFVisit 1a (nan)
# 	NLF Cell Counts.WBC#0049.NLFVisit 2 (nan)
# 	NLF Cell Counts.WBC#0049.NLFVisit 3 (nan)
# 	NLF Cell Counts.WBC#0049.NLFVisit 5 (nan)
# 	NLF Cell Counts.WBC#0049.NLFVisit 6 (nan)
# 	NLF Cell Counts.WBC#0051.NLFVisit 1 (nan)
# 	NLF Cell Counts.WBC#0051.NLFVisit 1a (nan)
# 	NLF Cell Counts.WBC#0051.NLFVisit 2 (nan)
# 	NLF Cell Counts.WBC#0051.NLFVisit 3 (nan)
# 	NLF Cell Counts.WBC#0051.NLFVisit 5 (nan)
# 	NLF Cell Counts.WBC#0051.NLFVisit 6 (nan)
# 	NLF Cell Counts.WBC#0054.NLFVisit 1 (nan)
# 	NLF Cell Counts.WBC#0054.NLFVisit 1a (nan)
# 	NLF Cell Counts.WBC#0054.NLFVisit 2 (nan)
# 	NLF Cell Counts.WBC#0054.NLFVisit 3 (nan)
# 	NLF Cell Counts.WBC#0054.NLFVisit 5 (nan)
# 	NLF Cell Counts.WBC#0054.NLFVisit 6 (nan)
# 	NLF Cell Counts.WBC#0055.NLFVisit 1 (nan)
# 	NLF Cell Counts.WBC#0055.NLFVisit 1a (nan)
# 	NLF Cell Counts.WBC#0055.NLFVisit 2 (nan)
# 	NLF Cell Counts.WBC#0055.NLFVisit 3 (nan)
# 	NLF Cell Counts.WBC#0055.NLFVisit 5 (nan)
# 	NLF Cell Counts.WBC#0055.NLFVisit 6 (nan)
# 	NLF Cell Counts.WBC#0058.NLFVisit 1 (nan)
# 	NLF Cell Counts.WBC#0058.NLFVisit 1a (nan)
# 	NLF Cell Counts.WBC#0058.NLFVisit 2 (nan)
# 	NLF Cell Counts.WBC#0058.NLFVisit 3 (nan)
# 	NLF Cell Counts.WBC#0058.NLFVisit 5 (nan)
# 	NLF Cell Counts.WBC#0058.NLFVisit 6 (nan)
# 	NLF Cell Counts.WBC#0060.NLFVisit 1 (nan)
# 	NLF Cell Counts.WBC#0060.NLFVisit 1a (nan)
# 	NLF Cell Counts.WBC#0060.NLFVisit 2 (nan)
# 	NLF Cell Counts.WBC#0060.NLFVisit 3 (nan)
# 	NLF Cell Counts.WBC#0060.NLFVisit 5 (nan)
# 	NLF Cell Counts.WBC#0060.NLFVisit 6 (nan)
# 	NLF Cell Counts.WBC#0064.NLFVisit 1 (nan)
# 	NLF Cell Counts.WBC#0064.NLFVisit 1a (nan)
# 	NLF Cell Counts.WBC#0064.NLFVisit 2 (nan)
# 	NLF Cell Counts.WBC#0064.NLFVisit 3 (nan)
# 	NLF Cell Counts.WBC#0064.NLFVisit 5 (nan)
# 	NLF Cell Counts.WBC#0064.NLFVisit 6 (nan)
# 	NLF Cell Counts.WBC#0067.NLFVisit 1 (nan)
# 	NLF Cell Counts.WBC#0067.NLFVisit 1a (nan)
# 	NLF Cell Counts.WBC#0067.NLFVisit 2 (nan)
# 	NLF Cell Counts.WBC#0067.NLFVisit 3 (nan)
# 	NLF Cell Counts.WBC#0067.NLFVisit 5 (nan)
# 	NLF Cell Counts.WBC#0067.NLFVisit 6 (nan)
# 	NLF Cell Counts.WBC#0069.NLFVisit 1 (nan)
# 	NLF Cell Counts.WBC#0069.NLFVisit 1a (nan)
# 	NLF Cell Counts.WBC#0069.NLFVisit 2 (nan)
# 	NLF Cell Counts.WBC#0069.NLFVisit 3 (nan)
# 	NLF Cell Counts.WBC#0069.NLFVisit 5 (nan)
# 	NLF Cell Counts.WBC#0069.NLFVisit 6 (nan)
# 	NLF Cell Counts.WBC#0072.NLFVisit 1 (nan)
# 	NLF Cell Counts.WBC#0072.NLFVisit 1a (nan)
# 	NLF Cell Counts.WBC#0072.NLFVisit 2 (nan)
# 	NLF Cell Counts.WBC#0072.NLFVisit 3 (nan)
# 	NLF Cell Counts.WBC#0072.NLFVisit 5 (nan)
# 	NLF Cell Counts.WBC#0072.NLFVisit 6 (nan)
# 	NLF Cell Counts.WBC#0073.NLFVisit 1 (nan)
# 	NLF Cell Counts.WBC#0073.NLFVisit 1a (nan)
# 	NLF Cell Counts.WBC#0073.NLFVisit 2 (nan)
# 	NLF Cell Counts.WBC#0073.NLFVisit 3 (nan)
# 	NLF Cell Counts.WBC#0073.NLFVisit 5 (nan)
# 	NLF Cell Counts.WBC#0073.NLFVisit 6 (nan)
# 	NLF Cell Counts.WBC#0076.NLFVisit 1 (nan)
# 	NLF Cell Counts.WBC#0076.NLFVisit 1a (nan)
# 	NLF Cell Counts.WBC#0076.NLFVisit 2 (nan)
# 	NLF Cell Counts.WBC#0076.NLFVisit 3 (nan)
# 	NLF Cell Counts.WBC#0076.NLFVisit 5 (nan)
# 	NLF Cell Counts.WBC#0076.NLFVisit 6 (nan)
# 	NLF Cell Counts.WBC#0078*.NLFVisit 1 (nan)
# 	NLF Cell Counts.WBC#0078*.NLFVisit 1a (nan)
# 	NLF Cell Counts.WBC#0078*.NLFVisit 2 (nan)
# 	NLF Cell Counts.WBC#0078*.NLFVisit 3 (nan)
# 	NLF Cell Counts.WBC#0078*.NLFVisit 5 (nan)
# 	NLF Cell Counts.WBC#0078*.NLFVisit 6 (nan)
# 	NLF Cell Counts.WBC#0081.NLFVisit 1 (nan)
# 	NLF Cell Counts.WBC#0081.NLFVisit 1a (nan)
# 	NLF Cell Counts.WBC#0081.NLFVisit 2 (nan)
# 	NLF Cell Counts.WBC#0081.NLFVisit 3 (nan)
# 	NLF Cell Counts.WBC#0081.NLFVisit 5 (nan)
# 	NLF Cell Counts.WBC#0081.NLFVisit 6 (nan)
# 	NLF Cell Counts.WBC#0084.NLFVisit 1 (nan)
# 	NLF Cell Counts.WBC#0084.NLFVisit 1a (nan)
# 	NLF Cell Counts.WBC#0084.NLFVisit 2 (nan)
# 	NLF Cell Counts.WBC#0084.NLFVisit 3 (nan)
# 	NLF Cell Counts.WBC#0084.NLFVisit 5 (nan)
# 	NLF Cell Counts.WBC#0084.NLFVisit 6 (nan)
# 	NLF Cell Counts.WBC#0085*.NLFVisit 1 (nan)
# 	NLF Cell Counts.WBC#0085*.NLFVisit 1a (nan)
# 	NLF Cell Counts.WBC#0085*.NLFVisit 2 (nan)
# 	NLF Cell Counts.WBC#0085*.NLFVisit 3 (nan)
# 	NLF Cell Counts.WBC#0085*.NLFVisit 5 (nan)
# 	NLF Cell Counts.WBC#0085*.NLFVisit 6 (nan)
# 	NLF Cell Counts.WBC#0096.NLFVisit 1 (nan)
# 	NLF Cell Counts.WBC#0096.NLFVisit 1a (nan)
# 	NLF Cell Counts.WBC#0096.NLFVisit 2 (nan)
# 	NLF Cell Counts.WBC#0096.NLFVisit 3 (nan)
# 	NLF Cell Counts.WBC#0096.NLFVisit 5 (nan)
# 	NLF Cell Counts.WBC#0096.NLFVisit 6 (nan)
# 	NLF Cell Counts.WBC#0099.NLFVisit 1 (nan)
# 	NLF Cell Counts.WBC#0099.NLFVisit 1a (nan)
# 	NLF Cell Counts.WBC#0099.NLFVisit 2 (nan)
# 	NLF Cell Counts.WBC#0099.NLFVisit 3 (nan)
# 	NLF Cell Counts.WBC#0099.NLFVisit 5 (nan)
# 	NLF Cell Counts.WBC#0099.NLFVisit 6 (nan)
# 	NLF Cell Counts.WBC#0105.NLFVisit 1 (nan)
# 	NLF Cell Counts.WBC#0105.NLFVisit 1a (nan)
# 	NLF Cell Counts.WBC#0105.NLFVisit 2 (nan)
# 	NLF Cell Counts.WBC#0105.NLFVisit 3 (nan)
# 	NLF Cell Counts.WBC#0105.NLFVisit 5 (nan)
# 	NLF Cell Counts.WBC#0105.NLFVisit 6 (nan)
# 	NLF Cell Counts.WBC#0112.NLFVisit 1 (nan)
# 	NLF Cell Counts.WBC#0112.NLFVisit 1a (nan)
# 	NLF Cell Counts.WBC#0112.NLFVisit 2 (nan)
# 	NLF Cell Counts.WBC#0112.NLFVisit 3 (nan)
# 	NLF Cell Counts.WBC#0112.NLFVisit 5 (nan)
# 	NLF Cell Counts.WBC#0112.NLFVisit 6 (nan)
# 	NLF Cell Counts.WBC#0138.NLFVisit 1 (nan)
# 	NLF Cell Counts.WBC#0138.NLFVisit 1a (nan)
# 	NLF Cell Counts.WBC#0138.NLFVisit 2 (nan)
# 	NLF Cell Counts.WBC#0138.NLFVisit 3 (nan)
# 	NLF Cell Counts.WBC#0138.NLFVisit 5 (nan)
# 	NLF Cell Counts.WBC#0138.NLFVisit 6 (nan)
# 	NLF Cell Counts.WBC#0147.NLFVisit 1 (nan)
# 	NLF Cell Counts.WBC#0147.NLFVisit 1a (nan)
# 	NLF Cell Counts.WBC#0147.NLFVisit 2 (nan)
# 	NLF Cell Counts.WBC#0147.NLFVisit 3 (nan)
# 	NLF Cell Counts.WBC#0147.NLFVisit 5 (nan)
# 	NLF Cell Counts.WBC#0147.NLFVisit 6 (nan)
# 	NLF Cell Counts.WBC#0156.NLFVisit 1 (nan)
# 	NLF Cell Counts.WBC#0156.NLFVisit 1a (nan)
# 	NLF Cell Counts.WBC#0156.NLFVisit 2 (nan)
# 	NLF Cell Counts.WBC#0156.NLFVisit 3 (nan)
# 	NLF Cell Counts.WBC#0156.NLFVisit 5 (nan)
# 	NLF Cell Counts.WBC#0156.NLFVisit 6 (nan)
# 	NLF Cell Counts.WBC#0162.NLFVisit 1 (nan)
# 	NLF Cell Counts.WBC#0162.NLFVisit 1a (nan)
# 	NLF Cell Counts.WBC#0162.NLFVisit 2 (nan)
# 	NLF Cell Counts.WBC#0162.NLFVisit 3 (nan)
# 	NLF Cell Counts.WBC#0162.NLFVisit 5 (nan)
# 	NLF Cell Counts.WBC#0162.NLFVisit 6 (nan)
# 	NLF Cell Counts.WBC#0166.NLFVisit 1 (nan)
# 	NLF Cell Counts.WBC#0166.NLFVisit 1a (nan)
# 	NLF Cell Counts.WBC#0166.NLFVisit 2 (nan)
# 	NLF Cell Counts.WBC#0166.NLFVisit 3 (nan)
# 	NLF Cell Counts.WBC#0166.NLFVisit 5 (nan)
# 	NLF Cell Counts.WBC#0166.NLFVisit 6 (nan)
# 	NLF Cell Counts.WBC#0169.NLFVisit 1 (nan)
# 	NLF Cell Counts.WBC#0169.NLFVisit 1a (nan)
# 	NLF Cell Counts.WBC#0169.NLFVisit 2 (nan)
# 	NLF Cell Counts.WBC#0169.NLFVisit 3 (nan)
# 	NLF Cell Counts.WBC#0169.NLFVisit 5 (nan)
# 	NLF Cell Counts.WBC#0169.NLFVisit 6 (nan)
#
# Parathyroid test (Hormone measurement)
# 	Parathyroid test (Parathyroid Hormone, Intact)
#
# Pf Density by microscopy blood smear (nan)
# 	Pf Density Microscopy (nan)
#
# Pf Density by qPCR of blood (nan)
# 	Pf Density qPCR (nan)
#
# Pf presence by blood PCR (nan)
# 	Pf Presence PCR (nan)
#
# Pregnancy test (nan)
# 	Pregnancy test (nan)
#
# Previous staphylococcus aureus culture (nan)
# 	Previous Methicillin resistant S. aureus result (nan)
# 	Previous Methicillin sensitive S. aureus result (nan)
# 	Previous staphylococcus aureus negative culture result (nan)
# 	Previous staphylococcus aureus positive culture result (nan)
#
# Protein measurement (Protein or Enzyme Type Measurement)
# 	Albumin/Creatinine (Albumin/Creatinine)
# 	C-peptide AUC (C-peptide)
# 	C-peptide AUC 2 hour (C-peptide)
# 	C-peptide AUC Change from Baseline (C-peptide)
# 	C-peptide AUC Change from Baseline 2 Hour (C-peptide)
# 	C-peptide AUC Month 24 (C-peptide)
# 	C-peptide AUC baseline 2 hour (C-peptide)
# 	C-peptide Baseline AUC (C-peptide)
# 	C-peptide Baseline Log AUC (C-peptide)
# 	C-peptide Log AUC (C-peptide)
# 	C-peptide Peak (C-peptide)
# 	C-peptide Peak Baseline (nan)
# 	Protein/Creatinine (Protein/Creatinine)
#
# Protein or Enzyme Type Measurement (Protein or Enzyme Type Measurement)
# 	A/G RATIO (A/G RATIO)
# 	AMYLASE, SERUM (nan)
# 	Anti-cyclic citrullinated peptide (nan)
# 	BLyS (nan)
# 	C Reactive Protein (C Reactive Protein)
# 	C-Reactive Protein (C Reactive Protein)
# 	C-reactive protein (C Reactive Protein)
# 	CPK, TOTAL (blood creatine kinase activity level)
# 	CXCL13 (nan)
# 	Complement C3 (Complement C3)
# 	Complement C4 (Complement C4)
# 	Creatinine (Creatinine)
# 	Creatinine Clearance (Creatinine clearance)
# 	Creatinine clearance (Creatinine clearance)
# 	Egg-Specific IgE (nan)
# 	Ferritin (nan)
# 	G CSF (nan)
# 	GGT (Gamma Glutamyl Transpeptidase)
# 	GLOBULIN (Globulin)
# 	GM CSF (nan)
# 	Gamma-glutamyl transpeptidase (Gamma Glutamyl Transpeptidase)
# 	HBA1C (Glycosylated Hemoglobin)
# 	High Sensitivity C Reactive Protein (nan)
# 	IFNG (Interferon Gamma)
# 	IL10 (Interleukin 10)
# 	IL12 (Interleukin 12)
# 	IL13 (Interleukin 13)
# 	IL17 (Interleukin 17)
# 	IL1b (Interleukin 1)
# 	IL2 (Interleukin 2)
# 	IL4 (Interleukin 4)
# 	IL5 (Interleukin 5)
# 	IL6 (Interleukin 6)
# 	IL7 (Interleukin 7)
# 	IL8 (Interleukin 8)
# 	IP-10 (nan)
# 	LACTIC DEHYDROGENASE (Lactate Dehydrogenase)
# 	LDH (Lactate Dehydrogenase)
# 	LIGHT (nan)
# 	LIPASE, SERUM (nan)
# 	MCP1 (nan)
# 	MIP1B (nan)
# 	Peanut-Specific IgE (nan)
# 	Protein (Protein)
# 	Rheumatoid Factor (Rheumatoid Factor)
# 	Sesame-Specific IgE (nan)
# 	TNFA (TNFA)
# 	TOTAL LDH (Lactate Dehydrogenase)
# 	anti-KLH IgG (nan)
# 	anti-KLH IgM (nan)
# 	anti-double stranded DNA antibody (Anti-Double Stranded DNA)
#
# RA_Lab_Panel (nan)
# 	Binucleate plasma cells (nan)
# 	CCP (nan)
# 	CPR (nan)
# 	Detritus (nan)
# 	ESR (Erythrocyte Sedimentation Rate)
# 	Fibrin (blood fibrinogen level)
# 	Lining Hyperplasia (nan)
# 	Lmphocytes (Lymphocyte)
# 	Mucin (nan)
# 	Neutrophils (Neutrophil)
# 	Plasma Cells (nan)
# 	RF (RF)
# 	Raw CCP value (nan)
# 	Raw RF value (RF)
# 	Russell bodies (nan)
# 	Synovial Giant Cells (nan)
#
# RENAL_PANEL (Renal Function Test)
# 	OBUN1 (BUN) (BUN)
# 	OBUN2 (BUN) (BUN)
# 	OBUN3 (BUN) (BUN)
# 	OBUN4 (BUN) (BUN)
# 	OBUN5 (BUN) (BUN)
# 	OBUN6 (BUN) (BUN)
# 	OBUN7 (BUN) (BUN)
# 	OBUN8 (BUN) (BUN)
# 	OBUNP (BUN) (BUN)
# 	OCREAT1 (CREAT) (Creatinine)
# 	OCREAT2 (CREAT) (Creatinine)
# 	OCREAT3 (CREAT) (Creatinine)
# 	OCREAT4 (CREAT) (Creatinine)
# 	OCREAT5 (CREAT) (Creatinine)
# 	OCREAT6 (CREAT) (Creatinine)
# 	OCREAT7 (CREAT) (Creatinine)
# 	OCREAT8 (CREAT) (Creatinine)
# 	OCREATP (CREAT) (Creatinine)
# 	TBUN1 (BUN) (BUN)
# 	TBUN14 (BUN) (BUN)
# 	TBUN18 (BUN) (BUN)
# 	TBUN2 (BUN) (BUN)
# 	TBUN3 (BUN) (BUN)
# 	TBUN4 (BUN) (BUN)
# 	TBUN5 (BUN) (BUN)
# 	TBUN6 (BUN) (BUN)
# 	TBUN9 (BUN) (BUN)
# 	TBUNP (BUN) (BUN)
# 	TCREAT1 (CREAT) (Creatinine)
# 	TCREAT14 (CREAT) (Creatinine)
# 	TCREAT18 (CREAT) (Creatinine)
# 	TCREAT2 (CREAT) (Creatinine)
# 	TCREAT3 (CREAT) (Creatinine)
# 	TCREAT4 (CREAT) (Creatinine)
# 	TCREAT5 (CREAT) (Creatinine)
# 	TCREAT6 (CREAT) (Creatinine)
# 	TCREAT9 (CREAT) (Creatinine)
# 	TCREATP (CREAT) (Creatinine)
#
# RV16 QPCR  (RV1A16 P&P) (nan)
# 	RV1A16 QPCR (nan)
#
# Radiation exposure (nan)
# 	Binucleate (nan)
# 	Corrected Mni Yield (nan)
# 	Dic_Yield (nan)
# 	Dicentric (nan)
# 	Micronuclei (nan)
# 	Mni Yield (nan)
# 	Monocentric (nan)
# 	Mononucleate (nan)
#
# Recipient CMV and EBV Serologies (nan)
# 	CMV IgG (Cytomegalovirus Viral Load Measurement)
# 	CMV IgG VCA (Cytomegalovirus Viral Load Measurement)
# 	CMV IgM (nan)
# 	EBV IgG (nan)
# 	EBV IgG EBNA (nan)
# 	EBV IgM (nan)
#
# Recipient CMV, EBV, BKV by PCR (nan)
# 	BKV (nan)
# 	CMV (Cytomegalovirus Viral Load Measurement)
# 	EBV (nan)
#
# Renal Function Test (Renal Function Test)
# 	Estimated GFR by Cockcroft-Gault (Estimated GFR by Cockcroft-Gault)
# 	Estimated GFR by MDRD (Estimated GFR by MDRD)
#
# Respiratory Viral Panel (nan)
# 	Respiratory Viral Panel FAST v2 (nan)
#
# SARS-CoV-2 PCR (nan)
# 	SARS-CoV-2 PCR (nan)
#
# SERUM_CREATININE (Protein or Enzyme Type Measurement)
# 	CREAT (CREAT) (Creatinine)
# 	R_CREA1 (CREAT) (Creatinine)
# 	R_CREA14 (CREAT) (Creatinine)
# 	R_CREA2 (CREAT) (Creatinine)
# 	R_CREA28 (CREAT) (Creatinine)
# 	R_CREA3 (CREAT) (Creatinine)
# 	R_CREA4 (CREAT) (Creatinine)
# 	R_CREA5 (CREAT) (Creatinine)
# 	R_CREA6 (CREAT) (Creatinine)
# 	T_24CREA (CREAT) (Creatinine)
# 	T_PCREAT (CREAT) (Creatinine)
# 	XCREAT2 (CREAT) (Creatinine)
#
# Serology (nan)
# 	Streptococcus pneumoniae IgG Serotype 1 (nan)
# 	Streptococcus pneumoniae IgG Serotype 12 (nan)
# 	Streptococcus pneumoniae IgG Serotype 14 (nan)
# 	Streptococcus pneumoniae IgG Serotype 19 (nan)
# 	Streptococcus pneumoniae IgG Serotype 23 (nan)
# 	Streptococcus pneumoniae IgG Serotype 26 (nan)
# 	Streptococcus pneumoniae IgG Serotype 3 (nan)
# 	Streptococcus pneumoniae IgG Serotype 4 (nan)
# 	Streptococcus pneumoniae IgG Serotype 5 (nan)
# 	Streptococcus pneumoniae IgG Serotype 51 (nan)
# 	Streptococcus pneumoniae IgG Serotype 56 (nan)
# 	Streptococcus pneumoniae IgG Serotype 68 (nan)
# 	Streptococcus pneumoniae IgG Serotype 8 (nan)
# 	Streptococcus pneumoniae IgG Serotype 9 (nan)
#
# Serum Chemistries (nan)
# 	BUN (BUN)
# 	Creatinine (Creatinine)
#
# Serum Chemistry (Comprehensive Metabolic Panel)
# 	ALT (Alanine Aminotransferase)
# 	ALT(SGPT) (SGPT)
# 	AST (Aspartate Aminotransferase)
# 	AST(SGOT) (SGOT)
# 	Albumin (Albumin)
# 	Alk Phosphatase (Alkaline Phosphatase)
# 	Alkaline Phosphatase (Alkaline Phosphatase)
# 	BUN (BUN)
# 	Bilirubin (Bilirubin)
# 	CO2 (Carbon Dioxide)
# 	Calcium (Calcium)
# 	Chloride (Chloride)
# 	Creatinine (Creatinine)
# 	GammaGT (Gamma Glutamyl Transpeptidase)
# 	Glucose (Glucose)
# 	Magnesium (Magnesium)
# 	Phosphate (Phosphate)
# 	Phosphorus (Phosphate)
# 	Potassium (Potassium)
# 	Sodium (Sodium)
#
# Serum Protein Electrophoresis (Serum protein electrophoresis)
# 	Antinuclear Antibodies (Antinuclear Antibodies)
# 	IgG Anti-cardiolipin Antibody (Anticardiolipin IgG Antibody)
# 	Immunoglobulin A (Immunoglobulin A)
# 	Immunoglobulin G (Immunoglobulin G)
# 	Immunoglobulin M (Immunoglobulin M)
# 	Serum Protein Alpha 1 (nan)
# 	Serum Protein Alpha 2 (nan)
# 	Serum Protein Beta (nan)
# 	Serum Protein Gamma (nan)
#
# Thyroid Panel (Hormone measurement)
# 	Thryoxine (Thyroxine)
# 	Thyroid Antimicrosomal Antibodies (Thyroid Antimicrosomal Antibodies)
# 	Thyroid Antithyroglobulin Antibodies (Thyroid Antithyroglobulin Antibodies)
# 	Thyroid Stimulating Hormone (Thyrotropin)
# 	Triiodothryonine (Triiodothyronine)
#
# Total IgE (Protein or Enzyme Type Measurement)
# 	Total IgE (Immunoglobulin E)
#
# Urinalysis (Urinalysis)
# 	Albumin (Albumin)
# 	Aspartate Aminotransferase (Aspartate Aminotransferase)
# 	BACTERIA (Bacteria Count)
# 	BLOOD (nan)
# 	Bilirubin (Bilirubin)
# 	Blood (nan)
# 	CRYSTALS (nan)
# 	Creatinine (Creatinine)
# 	Creatinine clearance (Creatinine clearance)
# 	EPITHELIAL CELLS (Epithelial cells)
# 	Erythrocytes (Erythrocytes)
# 	Glucose (Glucose)
# 	Hematuria (nan)
# 	KETONES (Ketones)
# 	Ketones (Ketones)
# 	LEUKOCYTE ESTERASE (Leukocyte esterase)
# 	Leukocyte esterase (Leukocyte esterase)
# 	Leukocytes (Leukocytes)
# 	NITRITE (Nitrite)
# 	Nitrite (Nitrite)
# 	OTHER ABNORMAL FINDINGS (nan)
# 	OVERALL RESULT (nan)
# 	PH (pH)
# 	Protein (Protein)
# 	Protein/Creatinine (Protein/Creatinine)
# 	RBC (Erythrocytes)
# 	RDW (Erythrocytes Distribution Width)
# 	SEGMENTED NEUTROPHILS (Neutrophils, Segmented)
# 	SPECIFIC GRAVITY (Specific Gravity)
# 	STREPTOCOCCUS (nan)
# 	Sodium (Sodium)
# 	Specific Gravity (Specific Gravity)
# 	TOTAL BILIRUBIN (Bilirubin)
# 	TOTAL PROTEIN (Protein)
# 	UROBILINOGEN (Urobilinogen)
# 	WBC (White Blood Cell Count)
# 	pH (pH)
#
# Urine (nan)
# 	Urine creatinine (calculated urine creatinine level)
# 	Urine microalbumin (nan)
#
# Vaccine Antibody Titers (nan)
# 	Diphtheria (nan)
# 	Pneumoniae Type 1 IgG (nan)
# 	Pneumoniae Type 12F IgG (nan)
# 	Pneumoniae Type 14 IgG (nan)
# 	Pneumoniae Type 18C IgG (nan)
# 	Pneumoniae Type 19F IgG (nan)
# 	Pneumoniae Type 3 IgG (nan)
# 	Pneumoniae Type 4 IgG (nan)
# 	Pneumoniae Type 6B IgG (nan)
# 	Pneumoniae Type 7F IgG (nan)
# 	Pneumoniae Type 8 IgG (nan)
# 	Pneumoniae Type 9N IgG (nan)
# 	PneumoniaeType 23F IgG (nan)
# 	Tetanus (nan)
#
# Vitamin D test (Vitamin measurement)
# 	Vitamin D test (25-Hydroxyvitamin D Measurement)
#
# Vitamin measurement (Vitamin measurement)
# 	25-Hydroxyvitamin D (25-Hydroxyvitamin D Measurement)
# 	25-Hydroxyvitamin D Measurement (25-Hydroxyvitamin D Measurement)
#
# serum antibody level (serum antibody level)
# 	Immunoglobulin E (Immunoglobulin E)
#
# urine microscopy (nan)
# 	Schistosoma haematobium (nan)

# %%
### manually assigned by oreferred names -> macht kein sinn weil da extrem viele nans sind-..
#### ASSIGNEMENT BY PANEL_NAMES

### cell types
cell_type_PANEL_NAMEs = [
    'Blood Cell Count: ',
    'Blood Cell Count with Differential: ',
    'Blood cell counts: ',
    'CBC: ',
    'CBC/Differential Results: ',
    'CBC_DIFFERENTIAL: ',
    'CBC_Results: ',
    'Complete Blood Cell Count: ',
    'Complete blood count: ',
    'DIFFERENTIAL: ',
    'HEMATOLOGY: ',
    'Hematology',
    'Hematology test: ',
]

### biomarkers
biomarker_PANEL_NAMEs = [
    'Blood Flow Cytometry: ',
    'Protein or Enzyme Type Measurement: ',
    ]

# ### Fasting
# FASTING_BLOOD_CHEMISTRY
# Fasting Lipid Panel: 
# Fasting Lipid Profile: 
# Fasting Lipids: 


# ### antigens
# Basophil
# Immunology Test: 
# Serum Protein Electrophoresis: 


# ### chemistry
# BASIC_CHEMISTRY
# BLOOD_CHEMISTRY
# Blood Chemistry: 
# Blood Chemistry Measurement: 
# Blood Chemistry Test: 
# Chemistry Test: 
# Clinical Chemistry: 
# Comprehensive Metabolic Panel: 
# Hematology
# Serum Chemistry: 


# ### creatinin
# Creatinine test: 
# Protein or Enzyme Type Measurement: 

# SERUM_CREATININE: 


# ### other

# ### urea
# Urinalysis: 
# Urine

# ### liver
# LIVER_PANEL:

# %%
### Next step: Get all Study accessions related to the biomarker and cell type bins
### Then: Get the subject
biomarker_PANEL_NAMEs_trimmed = [x[:-2] for x in biomarker_PANEL_NAMEs]
biomarker_all_tests = lab_tests[lab_tests['PANEL_NAME'].isin(biomarker_PANEL_NAMEs_trimmed)]
biomarker_all_tests.head()
# Out:
#        LAB_TEST_PANEL_ACCESSION                    NAME_PREFERRED_x  \
# 443504                  LP29065  Protein or Enzyme Type Measurement
# 443505                  LP29065  Protein or Enzyme Type Measurement
# 443506                  LP29065  Protein or Enzyme Type Measurement
# 443507                  LP29065  Protein or Enzyme Type Measurement
# 443508                  LP29065  Protein or Enzyme Type Measurement
#
#                                 PANEL_NAME STUDY_ACCESSION  WORKSPACE_ID_x  \
# 443504  Protein or Enzyme Type Measurement          SDY625            4345
# 443505  Protein or Enzyme Type Measurement          SDY625            4345
# 443506  Protein or Enzyme Type Measurement          SDY625            4345
# 443507  Protein or Enzyme Type Measurement          SDY625            4345
# 443508  Protein or Enzyme Type Measurement          SDY625            4345
#
#        LAB_TEST_ACCESSION BIOSAMPLE_ACCESSION      NAME_PREFERRED_y  \
# 443504           LT594351            BS843065               Protein
# 443505           LT594352            BS843065            Creatinine
# 443506           LT594353            BS843065  Creatinine clearance
# 443507           LT594354            BS843066               Protein
# 443508           LT594355            BS843066            Creatinine
#
#                LAB_TEST_NAME REFERENCE_RANGE_ACCESSION RESULT_UNIT_PREFERRED  \
# 443504               Protein                       NaN                   NaN
# 443505            Creatinine                       NaN                   NaN
# 443506  Creatinine Clearance                       NaN                   NaN
# 443507               Protein                       NaN                   NaN
# 443508            Creatinine                       NaN                   NaN
#
#        RESULT_UNIT_REPORTED  RESULT_VALUE_PREFERRED RESULT_VALUE_REPORTED  \
# 443504               mg/day                     7.0                     7
# 443505               mg/day                    63.6                  63.6
# 443506       mL/min/1.72m^2                   107.0                   107
# 443507               mg/day                     9.0                     9
# 443508               mg/day                    75.3                  75.3
#
#         WORKSPACE_ID_y
# 443504            4345
# 443505            4345
# 443506            4345
# 443507            4345
# 443508            4345

# %%
PANEL_NAMEs_uniquebiomarker_all_studies_array = biomarker_all_tests['STUDY_ACCESSION'].unique()
biomarker_all_studies = study[study['STUDY_ACCESSION'].isin(biomarker_all_studies_array)]
biomarker_all_studies.head()
# Out:
#     STUDY_ACCESSION ACTUAL_COMPLETION_DATE  ACTUAL_ENROLLMENT  \
# 141         SDY1475    2018-10-01 00:00:00               64.0
# 147           SDY15    2016-12-30 00:00:00               82.0
# 306         SDY1886                    NaN             2170.0
# 366         SDY2015                    NaN               36.0
# 696          SDY547                    NaN               83.0
#
#        ACTUAL_START_DATE AGE_UNIT  \
# 141  2014-09-24 00:00:00    Years
# 147  2008-08-01 00:00:00    Years
# 306  2020-04-01 00:00:00    Years
# 366                  NaN    Years
# 696  2005-05-01 00:00:00    Years
#
#                                      BRIEF_DESCRIPTION  \
# 141  Evaluate the T cell populations altered in the...
# 147  The purpose of this study is to determine the ...
# 306  Multiscale PHATE is a machine learning novel t...
# 366  In this study, we performed mass cytometry on ...
# 696  Patients who have been diagnosed with clinical...
#
#                                            BRIEF_TITLE CLINICAL_TRIAL  \
# 141  Expanded PD-1hi CXCR5- T peripheral helper cel...              N
# 147  Immune Response to Yellow Fever Vaccination in...              Y
# 306  Multiscale PHATE identifies multimodal signatu...              N
# 366  Mass cytometry analysis of PBMCs from peanut-s...              N
# 696  STAyCIS ITN020AI:  Atorvastatin (Lipitor) Ther...              Y
#
#                       CONDITION_STUDIED  DCL_ID  ... LATEST_DATA_RELEASE_DATE  \
# 141  Systemic lupus erythematosus (SLE)       0  ...      2020-01-29 00:00:00
# 147                                YFEV       2  ...      2017-09-29 00:00:00
# 306                                 NaN       2  ...      2022-03-21 00:00:00
# 366                                 NaN       2  ...      2022-09-02 00:00:00
# 696                  Multiple Sclerosis       2  ...      2015-12-14 00:00:00
#
#     LATEST_DATA_RELEASE_VERSION MAXIMUM_AGE MINIMUM_AGE  \
# 141                        DR33       59.00       26.00
# 147                        DR23       43.70       26.90
# 306                        DR43       90.00        1.00
# 366                        DR45        1.00        1.00
# 696                        DR16          55          18
#
#                                             OBJECTIVES  \
# 141  Find cell populations in SLE that stimulate pa...
# 147  The primary objective of this study is to gain...
# 306  Employ Multiscale PHATE to reanalyze existing ...
# 366  To use mass cytometry-based immune profiling o...
# 696  Determine if clinically isolated syndrome (CIS...
#
#                                         OFFICIAL_TITLE SHARED_STUDY  \
# 141  Expanded PD-1hi CXCR5- T peripheral helper cel...            Y
# 147  A Study of the Systemic and Cutaneous Immune R...            Y
# 306  Multiscale PHATE identifies multimodal signatu...            Y
# 366  Mass cytometry analysis of PBMCs from non-sens...            Y
# 696  A Randomized, Double-Blind, Placebo-Controlled...            Y
#
#                                SPONSORING_ORGANIZATION TARGET_ENROLLMENT  \
# 141  AMP RA/SLE, NIAMS, Lupus Research Alliance, Rh...              16.0
# 147                                              NIAID               NaN
# 306                                      Not available             130.0
# 366  NIH, NHMRC, FARE, Sean N. Parker Center for Al...               NaN
# 696                                              NIAID              82.0
#
#     WORKSPACE_ID
# 141         5290
# 147         1089
# 306         6512
# 366         6689
# 696         4117
#
# [5 rows x 28 columns]

# %%
subject_w_age.columns
# Out:
# Index(['ARM_ACCESSION', 'SUBJECT_ACCESSION', 'AGE_EVENT', 'AGE_EVENT_SPECIFY',
#        'AGE_UNIT', 'MAX_SUBJECT_AGE', 'MIN_SUBJECT_AGE', 'SUBJECT_PHENOTYPE',
#        'SUBJECT_LOCATION', 'MAX_SUBJECT_AGE_IN_YEARS',
#        'MIN_SUBJECT_AGE_IN_YEARS', 'ANCESTRAL_POPULATION', 'DESCRIPTION',
#        'ETHNICITY', 'GENDER', 'RACE', 'RACE_SPECIFY', 'SPECIES', 'STRAIN',
#        'STRAIN_CHARACTERISTICS', 'WORKSPACE_ID'],
#       dtype='object')

# %%
arm_or_cohort.columns
# Out:
# Index(['ARM_ACCESSION', 'DESCRIPTION', 'NAME', 'STUDY_ACCESSION',
#        'TYPE_REPORTED', 'TYPE_PREFERRED', 'WORKSPACE_ID'],
#       dtype='object')

# %%
biomarker_subject_study = pd.merge(subject_w_age, arm_or_cohort, left_on='ARM_ACCESSION',right_on='ARM_ACCESSION')
biomarker_subject_study.head()
# Out:
#   ARM_ACCESSION SUBJECT_ACCESSION          AGE_EVENT AGE_EVENT_SPECIFY  \
# 0          ARM1          SUB73369  Age at enrollment               NaN
# 1          ARM1          SUB73372  Age at enrollment               NaN
# 2          ARM1          SUB73374  Age at enrollment               NaN
# 3          ARM1          SUB73381  Age at enrollment               NaN
# 4          ARM1          SUB73382  Age at enrollment               NaN
#
#   AGE_UNIT  MAX_SUBJECT_AGE  MIN_SUBJECT_AGE  \
# 0    Years             49.0             49.0
# 1    Years             43.0             43.0
# 2    Years             43.0             43.0
# 3    Years             37.0             37.0
# 4    Years             34.0             34.0
#
#                             SUBJECT_PHENOTYPE SUBJECT_LOCATION  \
# 0  Ragweed-induced seasonal allergic rhinitis              NaN
# 1  Ragweed-induced seasonal allergic rhinitis              NaN
# 2  Ragweed-induced seasonal allergic rhinitis              NaN
# 3  Ragweed-induced seasonal allergic rhinitis              NaN
# 4  Ragweed-induced seasonal allergic rhinitis              NaN
#
#    MAX_SUBJECT_AGE_IN_YEARS  ...       SPECIES STRAIN STRAIN_CHARACTERISTICS  \
# 0                      49.0  ...  Homo sapiens    NaN                    NaN
# 1                      43.0  ...  Homo sapiens    NaN                    NaN
# 2                      43.0  ...  Homo sapiens    NaN                    NaN
# 3                      37.0  ...  Homo sapiens    NaN                    NaN
# 4                      34.0  ...  Homo sapiens    NaN                    NaN
#
#   WORKSPACE_ID_x                                      DESCRIPTION_y  \
# 0            990  Placebo omalizumab pre-treatment, placebo RIT,...
# 1            990  Placebo omalizumab pre-treatment, placebo RIT,...
# 2            990  Placebo omalizumab pre-treatment, placebo RIT,...
# 3            990  Placebo omalizumab pre-treatment, placebo RIT,...
# 4            990  Placebo omalizumab pre-treatment, placebo RIT,...
#
#                                           NAME STUDY_ACCESSION  \
# 0  Placebo Immunotherapy with placebo anti-IgE            SDY1
# 1  Placebo Immunotherapy with placebo anti-IgE            SDY1
# 2  Placebo Immunotherapy with placebo anti-IgE            SDY1
# 3  Placebo Immunotherapy with placebo anti-IgE            SDY1
# 4  Placebo Immunotherapy with placebo anti-IgE            SDY1
#
#         TYPE_REPORTED          TYPE_PREFERRED WORKSPACE_ID_y
# 0  Placebo Comparator  Placebo Comparator Arm            990
# 1  Placebo Comparator  Placebo Comparator Arm            990
# 2  Placebo Comparator  Placebo Comparator Arm            990
# 3  Placebo Comparator  Placebo Comparator Arm            990
# 4  Placebo Comparator  Placebo Comparator Arm            990
#
# [5 rows x 27 columns]

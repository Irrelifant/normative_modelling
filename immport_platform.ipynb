# %%
## imports
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
immport_prefix="/var/datasets/ImmPort/immune_RNAseq/ALLSTUDIES/ALLSTUDIES-DR49.2_Tab/Tab/"


print("WORKSPACE")
print("============================================================")
workspace = pd.read_table(f"{immport_prefix}/workspace.txt",sep="\t")
print(workspace.columns)
print(workspace.shape)


### contains elinks
print("lk_exp_measurement_tech")
print("============================================================")
lk_exp_measurement_tech = pd.read_table(f"{immport_prefix}/lk_exp_measurement_tech.txt",sep="\t")
print(lk_exp_measurement_tech.columns)
print(lk_exp_measurement_tech.shape)

print("EXPERIMENT")
print("============================================================")
experiment = pd.read_table(f"{immport_prefix}/experiment.txt",sep="\t")
print(experiment.columns)
print(experiment.shape)
experiment.head()

lk_exp_measurement_tech.head()
# Out:
# WORKSPACE
# ============================================================
# Index(['WORKSPACE_ID', 'CATEGORY', 'NAME', 'TYPE'], dtype='object')
# (163, 4)
# lk_exp_measurement_tech
# ============================================================
# Index(['NAME', 'DESCRIPTION', 'LINK'], dtype='object')
# (92, 3)
# EXPERIMENT
# ============================================================
# Index(['EXPERIMENT_ACCESSION', 'DESCRIPTION', 'MEASUREMENT_TECHNIQUE', 'NAME',
#        'STUDY_ACCESSION', 'WORKSPACE_ID'],
#       dtype='object')
# (3047, 6)
#                              NAME  \
# 0  Fluorescent Antibody Procedure
# 1  Neuraminidase Inhibition Assay
# 2       Microneutralization Assay
# 3              Bulk RNA-seq assay
# 4                          1D Gel
#
#                                          DESCRIPTION  \
# 0  An immunological procedure in which the antibo...
# 1  A type of enzyme-based assay that assesses neu...
# 2  An in vitro assay that is used to determine wh...
# 3  An RNA-seq assay in which the sample that is s...
# 4  One dimensional gels are used to separate an a...
#
#                                           LINK
# 0   http://purl.obolibrary.org/obo/NCIT_C17370
# 1  http://purl.obolibrary.org/obo/NCIT_C120696
# 2  http://purl.obolibrary.org/obo/NCIT_C120695
# 3   http://purl.obolibrary.org/obo/OBI_0003090
# 4   http://purl.obolibrary.org/obo/OBI_0001121

# %%
print("EXPSAMPLE_PLUBLIC_REPOSITORY")
print("============================================================")
gene_expression = pd.read_table(f"{immport_prefix}/expsample_public_repository.txt",sep="\t")
print(gene_expression.columns)
print(gene_expression.shape)

print("EXPSAMPLE")
print("============================================================")
expsample = pd.read_table(f"{immport_prefix}/expsample.txt",sep="\t")
print(expsample.columns)
print(expsample.shape)

print("EXPERIMENT")
print("============================================================")
experiment = pd.read_table(f"{immport_prefix}/experiment.txt",sep="\t")
print(experiment.columns)
print(experiment.shape)
# Out:
# EXPSAMPLE_PLUBLIC_REPOSITORY
# ============================================================
# Index(['RESULT_ID', 'EXPSAMPLE_ACCESSION', 'REPOSITORY_ACCESSION',
#        'REPOSITORY_NAME'],
#       dtype='object')
# (52404, 4)
# EXPSAMPLE
# ============================================================
# Index(['EXPSAMPLE_ACCESSION', 'DESCRIPTION', 'EXPERIMENT_ACCESSION', 'NAME',
#        'RESULT_SCHEMA', 'UPLOAD_RESULT_STATUS', 'WORKSPACE_ID'],
#       dtype='object')
# (850798, 7)
# EXPERIMENT
# ============================================================
# Index(['EXPERIMENT_ACCESSION', 'DESCRIPTION', 'MEASUREMENT_TECHNIQUE', 'NAME',
#        'STUDY_ACCESSION', 'WORKSPACE_ID'],
#       dtype='object')
# (3047, 6)

# %%
expsample[expsample['EXPSAMPLE_ACCESSION']=='ES769464']
# Out:
#        EXPSAMPLE_ACCESSION DESCRIPTION EXPERIMENT_ACCESSION NAME  \
# 674909            ES769464         NaN             EXP13591  NaN
#
#        RESULT_SCHEMA UPLOAD_RESULT_STATUS  WORKSPACE_ID
# 674909         OTHER           Not_Parsed          2799

# %%
experiment[experiment['EXPERIMENT_ACCESSION']=='EXP13591']
# Out:
#     EXPERIMENT_ACCESSION DESCRIPTION             MEASUREMENT_TECHNIQUE  \
# 262             EXP13591         NaN  Transcription profiling by array
#
#                                                   NAME STUDY_ACCESSION  \
# 262  Compare whole blood (Tempus tube) to PBMC gene...          SDY690
#
#      WORKSPACE_ID
# 262          2799

# %%
expsample_gene_expr = pd.merge(gene_expression, expsample, on='EXPSAMPLE_ACCESSION', how='inner')
experiment_sample_gene_expr = pd.merge(expsample_gene_expr, experiment, on='EXPERIMENT_ACCESSION', how='left')
print(experiment_sample_gene_expr.shape)
experiment_sample_gene_expr.head()
# Out:
# (52404, 15)
#    RESULT_ID EXPSAMPLE_ACCESSION REPOSITORY_ACCESSION REPOSITORY_NAME  \
# 0          1            ES776590           GSM1422023             GEO
# 1          2            ES776602           GSM1422046             GEO
# 2          3            ES776615           GSM1422059             GEO
# 3          4            ES776617           GSM1422061             GEO
# 4          5            ES776625           GSM1422069             GEO
#
#                         DESCRIPTION_x EXPERIMENT_ACCESSION        NAME_x  \
# 0  cRNA27760 Positive for globin peak             EXP13635  5920711019_C
# 1  cRNA27783 Positive for globin peak             EXP13635  5920834001_E
# 2  cRNA27796 Positive for globin peak             EXP13635  5920666013_E
# 3  cRNA27798 Positive for globin peak             EXP13635  5920666014_C
# 4  cRNA27806 Positive for globin peak             EXP13635  5920666014_K
#
#        RESULT_SCHEMA UPLOAD_RESULT_STATUS  WORKSPACE_ID_x  \
# 0  PUBLIC REPOSITORY               Parsed            2883
# 1  PUBLIC REPOSITORY               Parsed            2883
# 2  PUBLIC REPOSITORY               Parsed            2883
# 3  PUBLIC REPOSITORY               Parsed            2883
# 4  PUBLIC REPOSITORY               Parsed            2883
#
#                                        DESCRIPTION_y  \
# 0  Raw (non-normalized) Illumina data; mapping be...
# 1  Raw (non-normalized) Illumina data; mapping be...
# 2  Raw (non-normalized) Illumina data; mapping be...
# 3  Raw (non-normalized) Illumina data; mapping be...
# 4  Raw (non-normalized) Illumina data; mapping be...
#
#               MEASUREMENT_TECHNIQUE  \
# 0  Transcription profiling by array
# 1  Transcription profiling by array
# 2  Transcription profiling by array
# 3  Transcription profiling by array
# 4  Transcription profiling by array
#
#                                               NAME_y STUDY_ACCESSION  \
# 0  Gene expression measurement on 2010 subjects a...          SDY311
# 1  Gene expression measurement on 2010 subjects a...          SDY311
# 2  Gene expression measurement on 2010 subjects a...          SDY311
# 3  Gene expression measurement on 2010 subjects a...          SDY311
# 4  Gene expression measurement on 2010 subjects a...          SDY311
#
#    WORKSPACE_ID_y
# 0            2883
# 1            2883
# 2            2883
# 3            2883
# 4            2883

# %%
experiment_sample_gene_expr['STUDY_ACCESSION'].unique()
# Out:
# array(['SDY311', 'SDY350', 'SDY296', 'SDY305', 'SDY315', 'SDY404',
#        'SDY400', 'SDY691', 'SDY406', 'SDY113', 'SDY313', 'SDY212',
#        'SDY111', 'SDY224', 'SDY180', 'SDY63', 'SDY269', 'SDY56', 'SDY460',
#        'SDY773', 'SDY301', 'SDY508', 'SDY183', 'SDY522', 'SDY144',
#        'SDY587', 'SDY299', 'SDY622', 'SDY80', 'SDY420', 'SDY720', 'SDY58',
#        'SDY675', 'SDY789', 'SDY788', 'SDY546', 'SDY1324', 'SDY823',
#        'SDY984', 'SDY1064', 'SDY1079', 'SDY1085', 'SDY1092', 'SDY1093',
#        'SDY1099', 'SDY1043', 'SDY951', 'SDY1119', 'SDY1148', 'SDY1155',
#        'SDY1027', 'SDY1162', 'SDY1157', 'SDY888', 'SDY1185', 'SDY1190',
#        'SDY997', 'SDY1217', 'SDY903', 'SDY520', 'SDY640', 'SDY998',
#        'SDY1172', 'SDY1249', 'SDY1298', 'SDY1289', 'SDY1293', 'SDY1276',
#        'SDY1302', 'SDY1260', 'SDY1294', 'SDY1206', 'SDY1328', 'SDY1264',
#        'SDY1288', 'SDY1256', 'SDY1364', 'SDY1291', 'SDY1325', 'SDY1370',
#        'SDY787', 'SDY1373', 'SDY1343', 'SDY270', 'SDY61', 'SDY1368',
#        'SDY820', 'SDY1230', 'SDY1086', 'SDY1401', 'SDY1402', 'SDY1389',
#        'SDY616', 'SDY1412', 'SDY1341', 'SDY1267', 'SDY1387', 'SDY1490',
#        'SDY1439', 'SDY1529', 'SDY1039', 'SDY1536', 'SDY1396', 'SDY1397',
#        'SDY1381', 'SDY1613', 'SDY1630', 'SDY1654', 'SDY1697', 'SDY1722',
#        'SDY1723', 'SDY1725', 'SDY1726', 'SDY1600', 'SDY1395', 'SDY1768',
#        'SDY1393', 'SDY1773', 'SDY1885', 'SDY1912', 'SDY1880', 'SDY1924',
#        'SDY1928', 'SDY1971', 'SDY1980', 'SDY1991', 'SDY1995', 'SDY1669',
#        'SDY1903', 'SDY1644', 'SDY2107'], dtype=object)

# %%
### RNAseq whole blood
# experiment_sample_gene_expr[experiment_sample_gene_expr['STUDY_ACCESSION']=='SDY1412']['REPOSITORY_ACCESSION'].unique() ###GPL16791	Illumina HiSeq 2500 (Homo sapiens)
#experiment_sample_gene_expr[experiment_sample_gene_expr['STUDY_ACCESSION']=='SDY1092']['REPOSITORY_ACCESSION'].unique() ###GPL11154	Illumina HiSeq 2000 (Homo sapiens)
#experiment_sample_gene_expr[experiment_sample_gene_expr['STUDY_ACCESSION']=='SDY1172']['REPOSITORY_ACCESSION'].unique() ###GPL11154	Illumina HiSeq 2000 (Homo sapiens)
#experiment_sample_gene_expr[experiment_sample_gene_expr['STUDY_ACCESSION']=='SDY1381']['REPOSITORY_ACCESSION'].unique() ###GPL11154	Illumina HiSeq 2000 (Homo sapiens)
### RNAseq PBMC -> TODO hat keine Repository ID ? wtf... 
### fokus auf whole blood... 
#experiment_sample_gene_expr[experiment_sample_gene_expr['STUDY_ACCESSION']=='SDY67']['REPOSITORY_ACCESSION'].unique() ### 
experiment_sample_gene_expr[experiment_sample_gene_expr['EXPSAMPLE_ACCESSION']=='ES769464']['REPOSITORY_ACCESSION'].unique() ### 
### nope, but in immport NGS.PTL5892.docx    -> Illumina HiSeq 2000 (Homo sapiens)
#### Microarray whole blood:
# Out:
# array([], dtype=object)

# %%
exp

# %%
#### Function that gives me the platform info for my study. 
from Bio import Entrez

def get_platform_info(accession_numbers):
    Entrez.email = 'elias.schreiner@uni-tuebingen.de'
    for accession in accession_numbers:
        handle = Entrez.esearch(db="gds", term=accession)
        record = Entrez.read(handle)
        if record["IdList"]:
            gds_id = record["IdList"][0]
            handle = Entrez.efetch(db="gds", id=gds_id, retmode="xml")
            records = Entrez.read(handle)
            for record in records:
                platform = record["Platform_id"]
                title = record["title"]
                print(f"Accession: {accession}, Platform: {platform}, Title: {title}")
        else:
            print(f"No information found for accession: {accession}")

# Example usage:
accession_numbers = ["GSM1234567", "GSM9876543"]
get_platform_info(accession_numbers)
# Out:
# ---------------------------------------------------------------------------
# StreamModeError                           Traceback (most recent call last)
# Cell In[7], line 22
#      20 # Example usage:
#      21 accession_numbers = ["GSM1234567", "GSM9876543"]
# ---> 22 get_platform_info(accession_numbers)
#
# Cell In[7], line 12, in get_platform_info(accession_numbers)
#      10 gds_id = record["IdList"][0]
#      11 handle = Entrez.efetch(db="gds", id=gds_id, retmode="xml")
# ---> 12 records = Entrez.read(handle)
#      13 for record in records:
#      14     platform = record["Platform_id"]
#
# File ~/micromamba/envs/merge_env/lib/python3.12/site-packages/Bio/Entrez/__init__.py:518, in read(source, validate, escape, ignore_errors)
#     515 from .Parser import DataHandler
#     517 handler = DataHandler(validate, escape, ignore_errors)
# --> 518 record = handler.read(source)
#     519 return record
#
# File ~/micromamba/envs/merge_env/lib/python3.12/site-packages/Bio/Entrez/Parser.py:396, in DataHandler.read(self, source)
#     394 except TypeError:  # not a path, assume we received a stream
#     395     if source.read(0) != b"":
# --> 396         raise StreamModeError(
#     397             "the XML file must be opened in binary mode."
#     398         ) from None
#     399     stream = source
#     400 if stream.read(0) != b"":
#
# StreamModeError: the XML file must be opened in binary mode.
